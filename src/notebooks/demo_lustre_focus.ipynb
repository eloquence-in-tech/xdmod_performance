# %% [markdown]
# ## Dependencies

# %%
# System dependencies
from os import listdir
#import time as clock
#from IPython.display import clear_output

# %%
# Data Management
import pickle
#import datetime as dt

# %%
# Data manipulation dependencies
#import math
import statistics
import scipy.stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Custom data handling methods
import prep_IO

# %%
# Directory of pre-determined lustre failed jobs
src = './lustre_set.pkl'

# %% [markdown]
# # Setup

# %%
# read in search_out from saved dict in src_file
test_out = pickle.load( open( src, "rb" ) )
len(test_out)

# %% [markdown]
# ## Data

# %% [markdown]
# - first level keys: search labels
# - second level keys: ['Acct Info', 'Host Info', 'Source Files']
# - 'Host Info' keys: ['Timely Data', 'Schemas', 'Specs']

# %%
sample = test_out[-10:]
search_out = prep_IO.deep_search_host( sample, jobids=True )
search_out
# Out:
# {('comet-07-47',
#   '2019-10-14T23:57:48',
#   '2019-10-14T23:58:21',
#   '27362828'): {'Source': ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-07-47.sdsc.edu/1571079341.gz'], 'Single JobID': False},
#  ('comet-07-66',
#   '2019-10-14T23:57:48',
#   '2019-10-14T23:57:59',
#   '27362829'): {'Source': ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-07-66.sdsc.edu/1571079499.gz'], 'Single JobID': False},
#  ('comet-07-66',
#   '2019-10-14T23:57:48',
#   '2019-10-14T23:57:57',
#   '27362831'): {'Source': ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-07-66.sdsc.edu/1571079499.gz'], 'Single JobID': False},
#  ('comet-07-66',
#   '2019-10-14T23:57:48',
#   '2019-10-14T23:57:55',
#   '27362833'): {'Source': ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-07-66.sdsc.edu/1571079499.gz'], 'Single JobID': False},
#  ('comet-07-66',
#   '2019-10-14T23:57:48',
#   '2019-10-14T23:57:57',
#   '27362835'): {'Source': ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-07-66.sdsc.edu/1571079499.gz'], 'Single JobID': False},
#  ('comet-29-09',
#   '2019-10-14T23:57:48',
#   '2019-10-14T23:59:54',
#   '27362836'): {'Source': ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-29-09.sdsc.edu/1571087468.gz'], 'Single JobID': False},
#  ('comet-29-10',
#   '2019-10-14T23:57:48',
#   '2019-10-14T23:59:54',
#   '27362836'): {'Source': ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-29-10.sdsc.edu/1571087470.gz'], 'Single JobID': False},
#  ('comet-04-67',
#   '2019-10-14T23:59:05',
#   '2019-10-14T23:59:10',
#   '27362845'): {'Source': ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-04-67.sdsc.edu/1571078260.gz'], 'Single JobID': False},
#  ('comet-01-07',
#   '2019-10-14T23:59:43',
#   '2019-10-14T23:59:50',
#   '27362852'): {'Source': []},
#  ('comet-01-18',
#   '2019-10-14T23:59:43',
#   '2019-10-14T23:59:52',
#   '27362853'): {'Source': ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-01-18.sdsc.edu/1571076903.gz'],
#   'Single JobID': False}}

# %%
tester = host_to_info_dict('/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-01-18.sdsc.edu/1571076903.gz')
tester.keys()
# Out:
# dict_keys(['Schemas', 'Specs', 'Data', 'Jobid(s)'])

# %%
tester['Data']
# Out:
# [('block', 'md0', 'rd_ios', '10375', '1571076903.839997', '-'),
#  ('block', 'md0', 'rd_merges', '0', '1571076903.839997', '-'),
#  ('block', 'md0', 'rd_sectors(U=512B)', '23864', '1571076903.839997', '-'),
#  ('block', 'md0', 'rd_ticks(U=ms)', '0', '1571076903.839997', '-'),
#  ('block', 'md0', 'wr_ios', '16', '1571076903.839997', '-'),
#  ('block', 'md0', 'wr_merges', '0', '1571076903.839997', '-'),
#  ('block', 'md0', 'wr_sectors(U=512B)', '40', '1571076903.839997', '-'),
#  ('block', 'md0', 'wr_ticks(U=ms)', '0', '1571076903.839997', '-'),
#  ('block', 'md0', 'in_flight', '0', '1571076903.839997', '-'),
#  ('block', 'md0', 'io_ticks(U=ms)', '0', '1571076903.839997', '-'),
#  ('block', 'md1', 'rd_ios', '581064', '1571076903.839997', '-'),
#  ('block', 'md1', 'rd_merges', '0', '1571076903.839997', '-'),
#  ('block', 'md1', 'rd_sectors(U=512B)', '17530472', '1571076903.839997', '-'),
#  ('block', 'md1', 'rd_ticks(U=ms)', '0', '1571076903.839997', '-'),
#  ('block', 'md1', 'wr_ios', '444276635', '1571076903.839997', '-'),
#  ('block', 'md1', 'wr_merges', '0', '1571076903.839997', '-'),
#  ('block',
#   'md1',
#   'wr_sectors(U=512B)',
#   '3341811064',
#   '1571076903.839997',
#   '-'),
#  ('block', 'md1', 'wr_ticks(U=ms)', '0', '1571076903.839997', '-'),
#  ('block', 'md1', 'in_flight', '0', '1571076903.839997', '-'),
#  ('block', 'md1', 'io_ticks(U=ms)', '0', '1571076903.839997', '-'),
#  ('block', 'sda', 'rd_ios', '781940', '1571076903.839997', '-'),
#  ('block', 'sda', 'rd_merges', '154726', '1571076903.839997', '-'),
#  ('block', 'sda', 'rd_sectors(U=512B)', '146356228', '1571076903.839997', '-'),
#  ('block', 'sda', 'rd_ticks(U=ms)', '834772', '1571076903.839997', '-'),
#  ('block', 'sda', 'wr_ios', '278059237', '1571076903.839997', '-'),
#  ('block', 'sda', 'wr_merges', '150871846', '1571076903.839997', '-'),
#  ('block',
#   'sda',
#   'wr_sectors(U=512B)',
#   '33341216486',
#   '1571076903.839997',
#   '-'),
#  ('block', 'sda', 'wr_ticks(U=ms)', '342193015', '1571076903.839997', '-'),
#  ('block', 'sda', 'in_flight', '0', '1571076903.839997', '-'),
#  ('block', 'sda', 'io_ticks(U=ms)', '91504516', '1571076903.839997', '-'),
#  ('block', 'sdb', 'rd_ios', '785423', '1571076903.839997', '-'),
#  ('block', 'sdb', 'rd_merges', '124024', '1571076903.839997', '-'),
#  ('block', 'sdb', 'rd_sectors(U=512B)', '148595816', '1571076903.839997', '-'),
#  ('block', 'sdb', 'rd_ticks(U=ms)', '807388', '1571076903.839997', '-'),
#  ('block', 'sdb', 'wr_ios', '269233477', '1571076903.839997', '-'),
#  ('block', 'sdb', 'wr_merges', '147540202', '1571076903.839997', '-'),
#  ('block',
#   'sdb',
#   'wr_sectors(U=512B)',
#   '32843982206',
#   '1571076903.839997',
#   '-'),
#  ('block', 'sdb', 'wr_ticks(U=ms)', '338652112', '1571076903.839997', '-'),
#  ('block', 'sdb', 'in_flight', '0', '1571076903.839997', '-'),
#  ('block', 'sdb', 'io_ticks(U=ms)', '91431778', '1571076903.839997', '-'),
#  ('cpu', '22', 'user(U=cs)', '300362646', '1571076903.839997', '-'),
#  ('cpu', '22', 'nice(U=cs)', '480', '1571076903.839997', '-'),
#  ('cpu', '22', 'system(U=cs)', '8587554', '1571076903.839997', '-'),
#  ('cpu', '22', 'idle(U=cs)', '220478888', '1571076903.839997', '-'),
#  ('cpu', '22', 'iowait(U=cs)', '5654466', '1571076903.839997', '-'),
#  ('cpu', '22', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '20', 'user(U=cs)', '347335669', '1571076903.839997', '-'),
#  ('cpu', '20', 'nice(U=cs)', '370', '1571076903.839997', '-'),
#  ('cpu', '20', 'system(U=cs)', '6461174', '1571076903.839997', '-'),
#  ('cpu', '20', 'idle(U=cs)', '180414442', '1571076903.839997', '-'),
#  ('cpu', '20', 'iowait(U=cs)', '1270280', '1571076903.839997', '-'),
#  ('cpu', '20', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '21', 'user(U=cs)', '321367870', '1571076903.839997', '-'),
#  ('cpu', '21', 'nice(U=cs)', '1315', '1571076903.839997', '-'),
#  ('cpu', '21', 'system(U=cs)', '5716376', '1571076903.839997', '-'),
#  ('cpu', '21', 'idle(U=cs)', '207583926', '1571076903.839997', '-'),
#  ('cpu', '21', 'iowait(U=cs)', '741719', '1571076903.839997', '-'),
#  ('cpu', '21', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '11', 'user(U=cs)', '318425487', '1571076903.839997', '-'),
#  ('cpu', '11', 'nice(U=cs)', '1348', '1571076903.839997', '-'),
#  ('cpu', '11', 'system(U=cs)', '7743423', '1571076903.839997', '-'),
#  ('cpu', '11', 'idle(U=cs)', '208137622', '1571076903.839997', '-'),
#  ('cpu', '11', 'iowait(U=cs)', '801424', '1571076903.839997', '-'),
#  ('cpu', '11', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '10', 'user(U=cs)', '349338080', '1571076903.839997', '-'),
#  ('cpu', '10', 'nice(U=cs)', '1796', '1571076903.839997', '-'),
#  ('cpu', '10', 'system(U=cs)', '6912902', '1571076903.839997', '-'),
#  ('cpu', '10', 'idle(U=cs)', '171466798', '1571076903.839997', '-'),
#  ('cpu', '10', 'iowait(U=cs)', '7641856', '1571076903.839997', '-'),
#  ('cpu', '10', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '13', 'user(U=cs)', '380689983', '1571076903.839997', '-'),
#  ('cpu', '13', 'nice(U=cs)', '469', '1571076903.839997', '-'),
#  ('cpu', '13', 'system(U=cs)', '5925745', '1571076903.839997', '-'),
#  ('cpu', '13', 'idle(U=cs)', '148167964', '1571076903.839997', '-'),
#  ('cpu', '13', 'iowait(U=cs)', '682906', '1571076903.839997', '-'),
#  ('cpu', '13', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '12', 'user(U=cs)', '371511775', '1571076903.839997', '-'),
#  ('cpu', '12', 'nice(U=cs)', '1658', '1571076903.839997', '-'),
#  ('cpu', '12', 'system(U=cs)', '10995316', '1571076903.839997', '-'),
#  ('cpu', '12', 'idle(U=cs)', '147846967', '1571076903.839997', '-'),
#  ('cpu', '12', 'iowait(U=cs)', '4768744', '1571076903.839997', '-'),
#  ('cpu', '12', 'irq(U=cs)', '7', '1571076903.839997', '-'),
#  ('cpu', '15', 'user(U=cs)', '421413359', '1571076903.839997', '-'),
#  ('cpu', '15', 'nice(U=cs)', '773', '1571076903.839997', '-'),
#  ('cpu', '15', 'system(U=cs)', '7165492', '1571076903.839997', '-'),
#  ('cpu', '15', 'idle(U=cs)', '105773501', '1571076903.839997', '-'),
#  ('cpu', '15', 'iowait(U=cs)', '1138214', '1571076903.839997', '-'),
#  ('cpu', '15', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '14', 'user(U=cs)', '362151828', '1571076903.839997', '-'),
#  ('cpu', '14', 'nice(U=cs)', '7491', '1571076903.839997', '-'),
#  ('cpu', '14', 'system(U=cs)', '8758024', '1571076903.839997', '-'),
#  ('cpu', '14', 'idle(U=cs)', '163348044', '1571076903.839997', '-'),
#  ('cpu', '14', 'iowait(U=cs)', '718723', '1571076903.839997', '-'),
#  ('cpu', '14', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '17', 'user(U=cs)', '365510545', '1571076903.839997', '-'),
#  ('cpu', '17', 'nice(U=cs)', '657', '1571076903.839997', '-'),
#  ('cpu', '17', 'system(U=cs)', '6479816', '1571076903.839997', '-'),
#  ('cpu', '17', 'idle(U=cs)', '162650387', '1571076903.839997', '-'),
#  ('cpu', '17', 'iowait(U=cs)', '840786', '1571076903.839997', '-'),
#  ('cpu', '17', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '16', 'user(U=cs)', '404213852', '1571076903.839997', '-'),
#  ('cpu', '16', 'nice(U=cs)', '498', '1571076903.839997', '-'),
#  ('cpu', '16', 'system(U=cs)', '4613126', '1571076903.839997', '-'),
#  ('cpu', '16', 'idle(U=cs)', '124626570', '1571076903.839997', '-'),
#  ('cpu', '16', 'iowait(U=cs)', '2041770', '1571076903.839997', '-'),
#  ('cpu', '16', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '19', 'user(U=cs)', '336730722', '1571076903.839997', '-'),
#  ('cpu', '19', 'nice(U=cs)', '563', '1571076903.839997', '-'),
#  ('cpu', '19', 'system(U=cs)', '8898478', '1571076903.839997', '-'),
#  ('cpu', '19', 'idle(U=cs)', '189027239', '1571076903.839997', '-'),
#  ('cpu', '19', 'iowait(U=cs)', '835859', '1571076903.839997', '-'),
#  ('cpu', '19', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '18', 'user(U=cs)', '349303161', '1571076903.839997', '-'),
#  ('cpu', '18', 'nice(U=cs)', '535', '1571076903.839997', '-'),
#  ('cpu', '18', 'system(U=cs)', '9689858', '1571076903.839997', '-'),
#  ('cpu', '18', 'idle(U=cs)', '173886968', '1571076903.839997', '-'),
#  ('cpu', '18', 'iowait(U=cs)', '2550482', '1571076903.839997', '-'),
#  ('cpu', '18', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '23', 'user(U=cs)', '333763200', '1571076903.839997', '-'),
#  ('cpu', '23', 'nice(U=cs)', '815', '1571076903.839997', '-'),
#  ('cpu', '23', 'system(U=cs)', '5739039', '1571076903.839997', '-'),
#  ('cpu', '23', 'idle(U=cs)', '194965967', '1571076903.839997', '-'),
#  ('cpu', '23', 'iowait(U=cs)', '1026692', '1571076903.839997', '-'),
#  ('cpu', '23', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '1', 'user(U=cs)', '379592704', '1571076903.839997', '-'),
#  ('cpu', '1', 'nice(U=cs)', '375', '1571076903.839997', '-'),
#  ('cpu', '1', 'system(U=cs)', '8277326', '1571076903.839997', '-'),
#  ('cpu', '1', 'idle(U=cs)', '136624521', '1571076903.839997', '-'),
#  ('cpu', '1', 'iowait(U=cs)', '10965673', '1571076903.839997', '-'),
#  ('cpu', '1', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '0', 'user(U=cs)', '358760652', '1571076903.839997', '-'),
#  ('cpu', '0', 'nice(U=cs)', '1154', '1571076903.839997', '-'),
#  ('cpu', '0', 'system(U=cs)', '7576381', '1571076903.839997', '-'),
#  ('cpu', '0', 'idle(U=cs)', '154302508', '1571076903.839997', '-'),
#  ('cpu', '0', 'iowait(U=cs)', '10530053', '1571076903.839997', '-'),
#  ('cpu', '0', 'irq(U=cs)', '17758', '1571076903.839997', '-'),
#  ('cpu', '3', 'user(U=cs)', '401370413', '1571076903.839997', '-'),
#  ('cpu', '3', 'nice(U=cs)', '615', '1571076903.839997', '-'),
#  ('cpu', '3', 'system(U=cs)', '10634260', '1571076903.839997', '-'),
#  ('cpu', '3', 'idle(U=cs)', '114645732', '1571076903.839997', '-'),
#  ('cpu', '3', 'iowait(U=cs)', '8849298', '1571076903.839997', '-'),
#  ('cpu', '3', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '2', 'user(U=cs)', '370408549', '1571076903.839997', '-'),
#  ('cpu', '2', 'nice(U=cs)', '1065', '1571076903.839997', '-'),
#  ('cpu', '2', 'system(U=cs)', '11330261', '1571076903.839997', '-'),
#  ('cpu', '2', 'idle(U=cs)', '145545272', '1571076903.839997', '-'),
#  ('cpu', '2', 'iowait(U=cs)', '7859424', '1571076903.839997', '-'),
#  ('cpu', '2', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '5', 'user(U=cs)', '315422135', '1571076903.839997', '-'),
#  ('cpu', '5', 'nice(U=cs)', '662', '1571076903.839997', '-'),
#  ('cpu', '5', 'system(U=cs)', '9925070', '1571076903.839997', '-'),
#  ('cpu', '5', 'idle(U=cs)', '208046006', '1571076903.839997', '-'),
#  ('cpu', '5', 'iowait(U=cs)', '1576103', '1571076903.839997', '-'),
#  ('cpu', '5', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '4', 'user(U=cs)', '352499938', '1571076903.839997', '-'),
#  ('cpu', '4', 'nice(U=cs)', '408', '1571076903.839997', '-'),
#  ('cpu', '4', 'system(U=cs)', '10605212', '1571076903.839997', '-'),
#  ('cpu', '4', 'idle(U=cs)', '161941502', '1571076903.839997', '-'),
#  ('cpu', '4', 'iowait(U=cs)', '10140367', '1571076903.839997', '-'),
#  ('cpu', '4', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '7', 'user(U=cs)', '359662285', '1571076903.839997', '-'),
#  ('cpu', '7', 'nice(U=cs)', '329', '1571076903.839997', '-'),
#  ('cpu', '7', 'system(U=cs)', '7108203', '1571076903.839997', '-'),
#  ('cpu', '7', 'idle(U=cs)', '158169649', '1571076903.839997', '-'),
#  ('cpu', '7', 'iowait(U=cs)', '10560212', '1571076903.839997', '-'),
#  ('cpu', '7', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '6', 'user(U=cs)', '358896921', '1571076903.839997', '-'),
#  ('cpu', '6', 'nice(U=cs)', '385', '1571076903.839997', '-'),
#  ('cpu', '6', 'system(U=cs)', '7436695', '1571076903.839997', '-'),
#  ('cpu', '6', 'idle(U=cs)', '167710209', '1571076903.839997', '-'),
#  ('cpu', '6', 'iowait(U=cs)', '1421071', '1571076903.839997', '-'),
#  ('cpu', '6', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '9', 'user(U=cs)', '363331648', '1571076903.839997', '-'),
#  ('cpu', '9', 'nice(U=cs)', '163', '1571076903.839997', '-'),
#  ('cpu', '9', 'system(U=cs)', '8007665', '1571076903.839997', '-'),
#  ('cpu', '9', 'idle(U=cs)', '162744408', '1571076903.839997', '-'),
#  ('cpu', '9', 'iowait(U=cs)', '1089779', '1571076903.839997', '-'),
#  ('cpu', '9', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('cpu', '8', 'user(U=cs)', '348471277', '1571076903.839997', '-'),
#  ('cpu', '8', 'nice(U=cs)', '1274', '1571076903.839997', '-'),
#  ('cpu', '8', 'system(U=cs)', '7741970', '1571076903.839997', '-'),
#  ('cpu', '8', 'idle(U=cs)', '178508962', '1571076903.839997', '-'),
#  ('cpu', '8', 'iowait(U=cs)', '510052', '1571076903.839997', '-'),
#  ('cpu', '8', 'irq(U=cs)', '0', '1571076903.839997', '-'),
#  ('ib',
#   'mlx4_0.1',
#   'excessive_buffer_overrun_errors(W=32)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('ib', 'mlx4_0.1', 'link_downed(W=32)', '0', '1571076903.839997', '-'),
#  ('ib',
#   'mlx4_0.1',
#   'link_error_recovery(W=32)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('ib',
#   'mlx4_0.1',
#   'local_link_integrity_errors(W=32)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('ib',
#   'mlx4_0.1',
#   'port_rcv_constraint_errors(W=32)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('ib',
#   'mlx4_0.1',
#   'port_rcv_data(U=4B(W=32)',
#   '3076016474690',
#   '1571076903.839997',
#   '-'),
#  ('ib', 'mlx4_0.1', 'port_rcv_errors(W=32)', '0', '1571076903.839997', '-'),
#  ('ib',
#   'mlx4_0.1',
#   'port_rcv_packets(W=32)',
#   '6121188383',
#   '1571076903.839997',
#   '-'),
#  ('ib',
#   'mlx4_0.1',
#   'port_rcv_remote_physical_errors(W=32)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('ib',
#   'mlx4_0.1',
#   'port_rcv_switch_relay_errors(W=32)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('ib',
#   'mlx4_0.1',
#   'port_xmit_constraint_errors(W=32)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('ib',
#   'mlx4_0.1',
#   'port_xmit_data(U=4B(W=32)',
#   '1674290407592',
#   '1571076903.839997',
#   '-'),
#  ('ib', 'mlx4_0.1', 'port_xmit_discards(W=32)', '4', '1571076903.839997', '-'),
#  ('ib',
#   'mlx4_0.1',
#   'port_xmit_packets(W=32)',
#   '5618807828',
#   '1571076903.839997',
#   '-'),
#  ('ib',
#   'mlx4_0.1',
#   'port_xmit_wait(U=ms(W=32)',
#   '1579479526',
#   '1571076903.839997',
#   '-'),
#  ('ib', 'mlx4_0.1', 'symbol_error(W=32)', '0', '1571076903.839997', '-'),
#  ('ib_ext', 'mlx4_0/1', 'port_select', '1', '1571076903.839997', '-'),
#  ('ib_ext', 'mlx4_0/1', 'counter_select', '0', '1571076903.839997', '-'),
#  ('ib_ext',
#   'mlx4_0/1',
#   'port_xmit_data(U=4B)',
#   '1674290407592',
#   '1571076903.839997',
#   '-'),
#  ('ib_ext',
#   'mlx4_0/1',
#   'port_rcv_data(U=4B)',
#   '3076016474690',
#   '1571076903.839997',
#   '-'),
#  ('ib_ext',
#   'mlx4_0/1',
#   'port_xmit_pkts',
#   '5618807828',
#   '1571076903.839997',
#   '-'),
#  ('ib_ext',
#   'mlx4_0/1',
#   'port_rcv_pkts',
#   '6121188383',
#   '1571076903.839997',
#   '-'),
#  ('ib_ext',
#   'mlx4_0/1',
#   'port_unicast_xmit_pkts',
#   '5618883135',
#   '1571076903.839997',
#   '-'),
#  ('ib_ext',
#   'mlx4_0/1',
#   'port_unicast_rcv_pkts',
#   '6111229299',
#   '1571076903.839997',
#   '-'),
#  ('ib_ext',
#   'mlx4_0/1',
#   'port_multicast_xmit_pkts',
#   '130',
#   '1571076903.839997',
#   '-'),
#  ('ib_sw',
#   'mlx4_0/1',
#   'rx_bytes(U=4B)',
#   '279979808065386',
#   '1571076903.839997',
#   '-'),
#  ('ib_sw',
#   'mlx4_0/1',
#   'rx_packets',
#   '1019724973109',
#   '1571076903.839997',
#   '-'),
#  ('ib_sw',
#   'mlx4_0/1',
#   'tx_bytes(U=4B)',
#   '277059965288015',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '22', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '22', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '22', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '22', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '22', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '22', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '22', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '22', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '22',
#   'CTR0(W=48)',
#   '281077945748617',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '22', 'CTR1(W=48)', '97647454928836', '1571076903.839997', '-'),
#  ('intel_hsw', '22', 'CTR2(W=48)', '66086262003454', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '22',
#   'CTR3(W=48)',
#   '279751391802262',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '22', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '22', 'CTR5(W=48)', '2217668570456', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '22',
#   'CTR6(W=48)',
#   '140986438500495',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '22',
#   'CTR7(W=48)',
#   '186187091144296',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '22',
#   'FIXED_CTR0(W=48)',
#   '257065011525406',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '22',
#   'FIXED_CTR1(W=48)',
#   '54169338446609',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '20', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTR0(W=48)', '15750142438946', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTR1(W=48)', '95446695215321', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTR2(W=48)', '88332381703994', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '20',
#   'CTR3(W=48)',
#   '272173312076305',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '20', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '20', 'CTR5(W=48)', '1805225213262', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '20',
#   'CTR6(W=48)',
#   '214619013012389',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '20',
#   'CTR7(W=48)',
#   '141115753389737',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '20',
#   'FIXED_CTR0(W=48)',
#   '24045270934592',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '20',
#   'FIXED_CTR1(W=48)',
#   '57662132988421',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '21', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTR0(W=48)', '12142986250381', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTR1(W=48)', '96285976192082', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTR2(W=48)', '78775186637584', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '21',
#   'CTR3(W=48)',
#   '270830261580519',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '21', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTR5(W=48)', '1606566732122', '1571076903.839997', '-'),
#  ('intel_hsw', '21', 'CTR6(W=48)', '57678060435314', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '21',
#   'CTR7(W=48)',
#   '147193747334991',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '21',
#   'FIXED_CTR0(W=48)',
#   '256434220625834',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '21',
#   'FIXED_CTR1(W=48)',
#   '56392357277887',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '11', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '11',
#   'CTR0(W=48)',
#   '217369623105209',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '11',
#   'CTR1(W=48)',
#   '266200930142108',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '11', 'CTR2(W=48)', '63027229671010', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTR3(W=48)', '2605053780245', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '11', 'CTR5(W=48)', '1363702255739', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '11',
#   'CTR6(W=48)',
#   '268996005298880',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '11',
#   'CTR7(W=48)',
#   '176120694772662',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '11',
#   'FIXED_CTR0(W=48)',
#   '174270115453216',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '11',
#   'FIXED_CTR1(W=48)',
#   '6239622556540',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '10', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '10',
#   'CTR0(W=48)',
#   '271183533816187',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '10', 'CTR1(W=48)', '7694646983396', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTR2(W=48)', '85306564996249', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTR3(W=48)', '41504897466348', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTR5(W=48)', '1439807425016', '1571076903.839997', '-'),
#  ('intel_hsw', '10', 'CTR6(W=48)', '33754903412061', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '10',
#   'CTR7(W=48)',
#   '184668935743073',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '10',
#   'FIXED_CTR0(W=48)',
#   '215714346091844',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '10',
#   'FIXED_CTR1(W=48)',
#   '11423212642273',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '13', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '13', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '13', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '13', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '13', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '13', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '13', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '13', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '13',
#   'CTR0(W=48)',
#   '117421596314972',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '13', 'CTR1(W=48)', '62780903472238', '1571076903.839997', '-'),
#  ('intel_hsw', '13', 'CTR2(W=48)', '88093954894717', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '13',
#   'CTR3(W=48)',
#   '177778320772002',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '13', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '13', 'CTR5(W=48)', '2299224597864', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '13',
#   'CTR6(W=48)',
#   '231386218531555',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '13', 'CTR7(W=48)', '14237723778655', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '13',
#   'FIXED_CTR0(W=48)',
#   '204632953095535',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '13',
#   'FIXED_CTR1(W=48)',
#   '56148182963207',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '12', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '12',
#   'CTR0(W=48)',
#   '275357848992267',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '12', 'CTR1(W=48)', '1887214469927', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTR2(W=48)', '83711567256708', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTR3(W=48)', '77057334659610', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '12', 'CTR5(W=48)', '3047961091570', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '12',
#   'CTR6(W=48)',
#   '237628508593821',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '12',
#   'CTR7(W=48)',
#   '205005020741252',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '12',
#   'FIXED_CTR0(W=48)',
#   '158607865875160',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '12',
#   'FIXED_CTR1(W=48)',
#   '56456245007918',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '15', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '15', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '15', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '15', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '15', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '15', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '15', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '15', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '15',
#   'CTR0(W=48)',
#   '263056303642067',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '15',
#   'CTR1(W=48)',
#   '153977056962545',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '15',
#   'CTR2(W=48)',
#   '110868161110863',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '15',
#   'CTR3(W=48)',
#   '197319869401410',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '15', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '15', 'CTR5(W=48)', '2517092493060', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '15',
#   'CTR6(W=48)',
#   '236709363694436',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '15',
#   'CTR7(W=48)',
#   '263526212980915',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '15',
#   'FIXED_CTR0(W=48)',
#   '97670948544608',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '15',
#   'FIXED_CTR1(W=48)',
#   '56485833509001',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '14', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '14', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '14', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '14', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '14', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '14', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '14', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '14', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '14',
#   'CTR0(W=48)',
#   '226873155438260',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '14',
#   'CTR1(W=48)',
#   '150270171759002',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '14', 'CTR2(W=48)', '81163570299147', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '14',
#   'CTR3(W=48)',
#   '166633812360353',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '14', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '14', 'CTR5(W=48)', '2126761571944', '1571076903.839997', '-'),
#  ('intel_hsw', '14', 'CTR6(W=48)', '69753086671571', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '14',
#   'CTR7(W=48)',
#   '275344434617317',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '14',
#   'FIXED_CTR0(W=48)',
#   '108993734111724',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '14',
#   'FIXED_CTR1(W=48)',
#   '53540450966241',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '17', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTR0(W=48)', '35924510998337', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTR1(W=48)', '77573361183181', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTR2(W=48)', '95500189324788', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTR3(W=48)', '42861089231265', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '17', 'CTR5(W=48)', '2027323577088', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '17',
#   'CTR6(W=48)',
#   '107995195096501',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '17',
#   'CTR7(W=48)',
#   '179468006716162',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '17',
#   'FIXED_CTR0(W=48)',
#   '1994511276339',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '17',
#   'FIXED_CTR1(W=48)',
#   '54520410129025',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '16', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '16', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '16', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '16', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '16', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '16', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '16', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '16', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '16',
#   'CTR0(W=48)',
#   '258474394202203',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '16',
#   'CTR1(W=48)',
#   '233810307501524',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '16',
#   'CTR2(W=48)',
#   '101353200591231',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '16',
#   'CTR3(W=48)',
#   '114002426749303',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '16', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '16', 'CTR5(W=48)', '1411498269142', '1571076903.839997', '-'),
#  ('intel_hsw', '16', 'CTR6(W=48)', '67579408792912', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '16',
#   'CTR7(W=48)',
#   '232197641578709',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '16',
#   'FIXED_CTR0(W=48)',
#   '95108874844798',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '16',
#   'FIXED_CTR1(W=48)',
#   '56117257269737',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '19', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTR0(W=48)', '79325909438369', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '19',
#   'CTR1(W=48)',
#   '140044508200665',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '19',
#   'CTR2(W=48)',
#   '100326625692936',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '19', 'CTR3(W=48)', '15242296820937', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '19', 'CTR5(W=48)', '2773812873778', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '19',
#   'CTR6(W=48)',
#   '125773754908307',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '19',
#   'CTR7(W=48)',
#   '155215249880561',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '19',
#   'FIXED_CTR0(W=48)',
#   '180509708211894',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '19',
#   'FIXED_CTR1(W=48)',
#   '58103800776123',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '18', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '18',
#   'CTR0(W=48)',
#   '177799367240577',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '18',
#   'CTR1(W=48)',
#   '217413907358186',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '18',
#   'CTR2(W=48)',
#   '108830870046675',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '18', 'CTR3(W=48)', '36555781223074', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTR5(W=48)', '3009140426836', '1571076903.839997', '-'),
#  ('intel_hsw', '18', 'CTR6(W=48)', '23113911690787', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '18',
#   'CTR7(W=48)',
#   '157929521993798',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '18',
#   'FIXED_CTR0(W=48)',
#   '110735390650058',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '18',
#   'FIXED_CTR1(W=48)',
#   '57532968700857',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '23', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTR0(W=48)', '94464011896290', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '23',
#   'CTR1(W=48)',
#   '175437533372521',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '23', 'CTR2(W=48)', '75351644670840', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTR3(W=48)', '14686581566515', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '23', 'CTR5(W=48)', '1167549859573', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '23',
#   'CTR6(W=48)',
#   '115501593820132',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '23',
#   'CTR7(W=48)',
#   '193032725782985',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '23',
#   'FIXED_CTR0(W=48)',
#   '230097528626269',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '23',
#   'FIXED_CTR1(W=48)',
#   '52702336909065',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '1', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTR0(W=48)', '206019939559355', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTR1(W=48)', '97568849259488', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTR2(W=48)', '118122766251114', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTR3(W=48)', '181785671750816', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTR5(W=48)', '1703350772699', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTR6(W=48)', '234345539095592', '1571076903.839997', '-'),
#  ('intel_hsw', '1', 'CTR7(W=48)', '233649994348772', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '1',
#   'FIXED_CTR0(W=48)',
#   '119154916946520',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '1',
#   'FIXED_CTR1(W=48)',
#   '11678720830940',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '0', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTR0(W=48)', '55315734906890', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTR1(W=48)', '272353302709470', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTR2(W=48)', '115540741281446', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTR3(W=48)', '153854634120072', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTR5(W=48)', '1865027745738', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTR6(W=48)', '78542615896132', '1571076903.839997', '-'),
#  ('intel_hsw', '0', 'CTR7(W=48)', '223555827230062', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '0',
#   'FIXED_CTR0(W=48)',
#   '89053829882582',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '0',
#   'FIXED_CTR1(W=48)',
#   '13354349983076',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '3', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTR0(W=48)', '69397075789206', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTR1(W=48)', '204369163590995', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTR2(W=48)', '113482227334861', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTR3(W=48)', '222043348737745', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTR5(W=48)', '3011117059924', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTR6(W=48)', '272518423109564', '1571076903.839997', '-'),
#  ('intel_hsw', '3', 'CTR7(W=48)', '259556793274746', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '3',
#   'FIXED_CTR0(W=48)',
#   '147640254509947',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '3',
#   'FIXED_CTR1(W=48)',
#   '13779344028008',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '2', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTR0(W=48)', '11383983899043', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTR1(W=48)', '181971501794604', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTR2(W=48)', '92191467174937', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTR3(W=48)', '171807009874512', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTR5(W=48)', '2416811409241', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTR6(W=48)', '96732722560459', '1571076903.839997', '-'),
#  ('intel_hsw', '2', 'CTR7(W=48)', '247284717705347', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '2',
#   'FIXED_CTR0(W=48)',
#   '247216976794385',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '2',
#   'FIXED_CTR1(W=48)',
#   '8854722045379',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '5', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTR0(W=48)', '178384804612009', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTR1(W=48)', '178300013128579', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTR2(W=48)', '79169032498039', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTR3(W=48)', '71989664012597', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTR5(W=48)', '2128374804465', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTR6(W=48)', '27218038433956', '1571076903.839997', '-'),
#  ('intel_hsw', '5', 'CTR7(W=48)', '209263162157364', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '5',
#   'FIXED_CTR0(W=48)',
#   '10702761612184',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '5',
#   'FIXED_CTR1(W=48)',
#   '4896430179504',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '4', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTR0(W=48)', '177137705871307', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTR1(W=48)', '121656205652674', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTR2(W=48)', '79773568721353', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTR3(W=48)', '133336576985663', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTR5(W=48)', '2497411450477', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTR6(W=48)', '63923954934580', '1571076903.839997', '-'),
#  ('intel_hsw', '4', 'CTR7(W=48)', '240496249839528', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '4',
#   'FIXED_CTR0(W=48)',
#   '28160612541489',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '4',
#   'FIXED_CTR1(W=48)',
#   '7989313523590',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '7', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTR0(W=48)', '271888419555602', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTR1(W=48)', '233800686088011', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTR2(W=48)', '100838890238046', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTR3(W=48)', '133759669491179', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTR5(W=48)', '1313182001025', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTR6(W=48)', '42329868546378', '1571076903.839997', '-'),
#  ('intel_hsw', '7', 'CTR7(W=48)', '234497019032884', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '7',
#   'FIXED_CTR0(W=48)',
#   '196195115287447',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '7',
#   'FIXED_CTR1(W=48)',
#   '10812385740048',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '6', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTR0(W=48)', '44632952927399', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTR1(W=48)', '37134537742337', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTR2(W=48)', '93047079615377', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTR3(W=48)', '121195877806649', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTR5(W=48)', '1822897316601', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTR6(W=48)', '131327484460972', '1571076903.839997', '-'),
#  ('intel_hsw', '6', 'CTR7(W=48)', '224978852459968', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '6',
#   'FIXED_CTR0(W=48)',
#   '211571122586915',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '6',
#   'FIXED_CTR1(W=48)',
#   '11934257295343',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '9', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTR0(W=48)', '231811270307836', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTR1(W=48)', '268933900243744', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTR2(W=48)', '71718811856859', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTR3(W=48)', '98054659559345', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTR5(W=48)', '1644443664969', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTR6(W=48)', '107623014172874', '1571076903.839997', '-'),
#  ('intel_hsw', '9', 'CTR7(W=48)', '245593052352416', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '9',
#   'FIXED_CTR0(W=48)',
#   '182395429381465',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '9',
#   'FIXED_CTR1(W=48)',
#   '11716319891639',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw', '8', 'CTL0', '6521296', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTL1', '6488529', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTL2', '6488785', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTL3', '6488401', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTL4', '6489297', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTL5', '6488328', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTL6', '6488482', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTL7', '6490097', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTR0(W=48)', '13458503138345', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTR1(W=48)', '54953240648723', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTR2(W=48)', '62058886715009', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTR3(W=48)', '51217933306989', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTR4(W=48)', '0', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTR5(W=48)', '1311936784910', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTR6(W=48)', '239692027194589', '1571076903.839997', '-'),
#  ('intel_hsw', '8', 'CTR7(W=48)', '210247424877478', '1571076903.839997', '-'),
#  ('intel_hsw',
#   '8',
#   'FIXED_CTR0(W=48)',
#   '118779837890734',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw',
#   '8',
#   'FIXED_CTR1(W=48)',
#   '8321978348762',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_cbo', '1/7', 'CTL0', '20971793', '1571076903.839997', '-'),
# ...
#  ('intel_hsw_hau', 'ff/12.5', 'CTL1', '20974593', '1571076903.839997', '-'),
#  ('intel_hsw_hau', 'ff/12.5', 'CTL2', '20971520', '1571076903.839997', '-'),
#  ('intel_hsw_hau', 'ff/12.5', 'CTL3', '20975386', '1571076903.839997', '-'),
#  ('intel_hsw_hau',
#   'ff/12.5',
#   'CTR0(W=48)',
#   '83724910461561',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau',
#   'ff/12.5',
#   'CTR1(W=48)',
#   '149246083923291',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau',
#   'ff/12.5',
#   'CTR2(W=48)',
#   '118008904161477',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau', '7f/12.1', 'CTL0', '20972289', '1571076903.839997', '-'),
#  ('intel_hsw_hau', '7f/12.1', 'CTL1', '20974593', '1571076903.839997', '-'),
#  ('intel_hsw_hau', '7f/12.1', 'CTL2', '20971520', '1571076903.839997', '-'),
#  ('intel_hsw_hau', '7f/12.1', 'CTL3', '20975386', '1571076903.839997', '-'),
#  ('intel_hsw_hau',
#   '7f/12.1',
#   'CTR0(W=48)',
#   '241304596032000',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau',
#   '7f/12.1',
#   'CTR1(W=48)',
#   '128877210599614',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau',
#   '7f/12.1',
#   'CTR2(W=48)',
#   '15576515853782',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau', 'ff/12.1', 'CTL0', '20972289', '1571076903.839997', '-'),
#  ('intel_hsw_hau', 'ff/12.1', 'CTL1', '20974593', '1571076903.839997', '-'),
#  ('intel_hsw_hau', 'ff/12.1', 'CTL2', '20971520', '1571076903.839997', '-'),
#  ('intel_hsw_hau', 'ff/12.1', 'CTL3', '20975386', '1571076903.839997', '-'),
#  ('intel_hsw_hau',
#   'ff/12.1',
#   'CTR0(W=48)',
#   '83763908426182',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau',
#   'ff/12.1',
#   'CTR1(W=48)',
#   '149257240902683',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau',
#   'ff/12.1',
#   'CTR2(W=48)',
#   '118008904320327',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau', '7f/12.5', 'CTL0', '20972289', '1571076903.839997', '-'),
#  ('intel_hsw_hau', '7f/12.5', 'CTL1', '20974593', '1571076903.839997', '-'),
#  ('intel_hsw_hau', '7f/12.5', 'CTL2', '20971520', '1571076903.839997', '-'),
#  ('intel_hsw_hau', '7f/12.5', 'CTL3', '20975386', '1571076903.839997', '-'),
#  ('intel_hsw_hau',
#   '7f/12.5',
#   'CTR0(W=48)',
#   '241419717625096',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau',
#   '7f/12.5',
#   'CTR1(W=48)',
#   '128868323427154',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_hau',
#   '7f/12.5',
#   'CTR2(W=48)',
#   '15576511376322',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc', 'ff/14.1', 'CTL0', '20972292', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/14.1', 'CTL1', '20974596', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/14.1', 'CTL2', '20974337', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/14.1', 'CTL3', '20971778', '1571076903.839997', '-'),
#  ('intel_hsw_imc',
#   'ff/14.1',
#   'CTR0(W=48)',
#   '182416304284807',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/14.1',
#   'CTR1(W=48)',
#   '74986213367551',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/14.1',
#   'CTR2(W=48)',
#   '217629519549109',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/14.1',
#   'CTR3(W=48)',
#   '103581751529662',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc', 'ff/14.0', 'CTL0', '20972292', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/14.0', 'CTL1', '20974596', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/14.0', 'CTL2', '20974337', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/14.0', 'CTL3', '20971778', '1571076903.839997', '-'),
#  ('intel_hsw_imc',
#   'ff/14.0',
#   'CTR0(W=48)',
#   '182311975362304',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/14.0',
#   'CTR1(W=48)',
#   '74972531367527',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/14.0',
#   'CTR2(W=48)',
#   '217541916997420',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/14.0',
#   'CTR3(W=48)',
#   '103557223297482',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc', '7f/17.1', 'CTL0', '20972292', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/17.1', 'CTL1', '20974596', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/17.1', 'CTL2', '20974337', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/17.1', 'CTL3', '20971778', '1571076903.839997', '-'),
#  ('intel_hsw_imc',
#   '7f/17.1',
#   'CTR0(W=48)',
#   '120619896478249',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/17.1',
#   'CTR1(W=48)',
#   '64142465512174',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/17.1',
#   'CTR2(W=48)',
#   '146206254924500',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/17.1',
#   'CTR3(W=48)',
#   '53970916796672',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc', '7f/17.0', 'CTL0', '20972292', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/17.0', 'CTL1', '20974596', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/17.0', 'CTL2', '20974337', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/17.0', 'CTL3', '20971778', '1571076903.839997', '-'),
#  ('intel_hsw_imc',
#   '7f/17.0',
#   'CTR0(W=48)',
#   '120833550795967',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/17.0',
#   'CTR1(W=48)',
#   '64175648678318',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/17.0',
#   'CTR2(W=48)',
#   '146673548279184',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/17.0',
#   'CTR3(W=48)',
#   '54826023441142',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc', '7f/14.0', 'CTL0', '20972292', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/14.0', 'CTL1', '20974596', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/14.0', 'CTL2', '20974337', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/14.0', 'CTL3', '20971778', '1571076903.839997', '-'),
#  ('intel_hsw_imc',
#   '7f/14.0',
#   'CTR0(W=48)',
#   '120647328755885',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/14.0',
#   'CTR1(W=48)',
#   '64083136575079',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/14.0',
#   'CTR2(W=48)',
#   '146628986866690',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/14.0',
#   'CTR3(W=48)',
#   '54729670119305',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc', '7f/14.1', 'CTL0', '20972292', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/14.1', 'CTL1', '20974596', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/14.1', 'CTL2', '20974337', '1571076903.839997', '-'),
#  ('intel_hsw_imc', '7f/14.1', 'CTL3', '20971778', '1571076903.839997', '-'),
#  ('intel_hsw_imc',
#   '7f/14.1',
#   'CTR0(W=48)',
#   '120704371530756',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/14.1',
#   'CTR1(W=48)',
#   '64129802476930',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/14.1',
#   'CTR2(W=48)',
#   '146379372812605',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   '7f/14.1',
#   'CTR3(W=48)',
#   '53989056699272',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc', 'ff/17.0', 'CTL0', '20972292', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/17.0', 'CTL1', '20974596', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/17.0', 'CTL2', '20974337', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/17.0', 'CTL3', '20971778', '1571076903.839997', '-'),
#  ('intel_hsw_imc',
#   'ff/17.0',
#   'CTR0(W=48)',
#   '182347322709838',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/17.0',
#   'CTR1(W=48)',
#   '74992696747004',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/17.0',
#   'CTR2(W=48)',
#   '216223472116327',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/17.0',
#   'CTR3(W=48)',
#   '103480336305198',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc', 'ff/17.1', 'CTL0', '20972292', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/17.1', 'CTL1', '20974596', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/17.1', 'CTL2', '20974337', '1571076903.839997', '-'),
#  ('intel_hsw_imc', 'ff/17.1', 'CTL3', '20971778', '1571076903.839997', '-'),
#  ('intel_hsw_imc',
#   'ff/17.1',
#   'CTR0(W=48)',
#   '182298459068431',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/17.1',
#   'CTR1(W=48)',
#   '74983892700331',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/17.1',
#   'CTR2(W=48)',
#   '216753319359002',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_imc',
#   'ff/17.1',
#   'CTR3(W=48)',
#   '103247860616681',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_pcu', '1', 'CTL0', '20971524', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '1', 'CTL1', '20971525', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '1', 'CTL2', '20971649', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '1', 'CTL3', '20971650', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '1', 'CTR0(W=48)', '17561', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '1', 'CTR1(W=48)', '390490', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '1', 'CTR2(W=48)', '4', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '1', 'CTR3(W=48)', '4', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '1', 'FIXED_CTR0(W=64)', '0', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '0', 'CTL0', '20971524', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '0', 'CTL1', '20971525', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '0', 'CTL2', '20971649', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '0', 'CTL3', '20971650', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '0', 'CTR0(W=48)', '4', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '0', 'CTR1(W=48)', '4', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '0', 'CTR2(W=48)', '4', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '0', 'CTR3(W=48)', '4', '1571076903.839997', '-'),
#  ('intel_hsw_pcu', '0', 'FIXED_CTR0(W=64)', '0', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', 'ff/08.2', 'CTL0', '6291712', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', 'ff/08.2', 'CTL1', '6292480', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', 'ff/08.2', 'CTL2', '6293506', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', 'ff/08.2', 'CTL3', '6292483', '1571076903.839997', '-'),
#  ('intel_hsw_qpi',
#   'ff/08.2',
#   'CTR0(U=flt(W=48)',
#   '13779873322143',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi',
#   'ff/08.2',
#   'CTR1(U=flt(W=48)',
#   '224193428785931',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi',
#   'ff/08.2',
#   'CTR2(U=flt(W=48)',
#   '48185649567996',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi', '7f/08.2', 'CTL0', '6291712', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', '7f/08.2', 'CTL1', '6292480', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', '7f/08.2', 'CTL2', '6293506', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', '7f/08.2', 'CTL3', '6292483', '1571076903.839997', '-'),
#  ('intel_hsw_qpi',
#   '7f/08.2',
#   'CTR0(U=flt(W=48)',
#   '224216341811685',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi',
#   '7f/08.2',
#   'CTR1(U=flt(W=48)',
#   '13832690497308',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi',
#   '7f/08.2',
#   'CTR2(U=flt(W=48)',
#   '86045217830264',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi', '7f/09.2', 'CTL0', '6291712', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', '7f/09.2', 'CTL1', '6292480', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', '7f/09.2', 'CTL2', '6293506', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', '7f/09.2', 'CTL3', '6292483', '1571076903.839997', '-'),
#  ('intel_hsw_qpi',
#   '7f/09.2',
#   'CTR0(U=flt(W=48)',
#   '224155215217044',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi',
#   '7f/09.2',
#   'CTR1(U=flt(W=48)',
#   '13808337326067',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi',
#   '7f/09.2',
#   'CTR2(U=flt(W=48)',
#   '87303166478948',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi', 'ff/09.2', 'CTL0', '6291712', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', 'ff/09.2', 'CTL1', '6292480', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', 'ff/09.2', 'CTL2', '6293506', '1571076903.839997', '-'),
#  ('intel_hsw_qpi', 'ff/09.2', 'CTL3', '6292483', '1571076903.839997', '-'),
#  ('intel_hsw_qpi',
#   'ff/09.2',
#   'CTR0(U=flt(W=48)',
#   '13803528127869',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi',
#   'ff/09.2',
#   'CTR1(U=flt(W=48)',
#   '224275873345753',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_qpi',
#   'ff/09.2',
#   'CTR2(U=flt(W=48)',
#   '41970460241019',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_r2pci', '7f/10.1', 'CTL0', '20972580', '1571076903.839997', '-'),
#  ('intel_hsw_r2pci', '7f/10.1', 'CTL1', '20975369', '1571076903.839997', '-'),
#  ('intel_hsw_r2pci', '7f/10.1', 'CTL2', '20975367', '1571076903.839997', '-'),
#  ('intel_hsw_r2pci', '7f/10.1', 'CTL3', '20975368', '1571076903.839997', '-'),
#  ('intel_hsw_r2pci',
#   '7f/10.1',
#   'CTR0(W=44)',
#   '423295647008',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_r2pci',
#   '7f/10.1',
#   'CTR1(W=44)',
#   '63991471403799',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_r2pci',
#   '7f/10.1',
#   'CTR2(W=44)',
#   '240500469646802',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_r2pci', 'ff/10.1', 'CTL0', '20972580', '1571076903.839997', '-'),
#  ('intel_hsw_r2pci', 'ff/10.1', 'CTL1', '20975369', '1571076903.839997', '-'),
#  ('intel_hsw_r2pci', 'ff/10.1', 'CTL2', '20975367', '1571076903.839997', '-'),
#  ('intel_hsw_r2pci', 'ff/10.1', 'CTL3', '20975368', '1571076903.839997', '-'),
#  ('intel_hsw_r2pci',
#   'ff/10.1',
#   'CTR0(W=44)',
#   '9092646302',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_r2pci',
#   'ff/10.1',
#   'CTR1(W=44)',
#   '207573493941406',
#   '1571076903.839997',
#   '-'),
#  ('intel_hsw_r2pci',
#   'ff/10.1',
#   'CTR2(W=44)',
#   '67808557093218',
#   '1571076903.839997',
#   '-'),
#  ('intel_rapl',
#   '1',
#   'MSR_PKG_ENERGY_STATUS(U=mJ(W=32)',
#   '185003126',
#   '1571076903.839997',
#   '-'),
#  ('intel_rapl',
#   '1',
#   'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('intel_rapl',
#   '0',
#   'MSR_PKG_ENERGY_STATUS(U=mJ(W=32)',
#   '81545584',
#   '1571076903.839997',
#   '-'),
#  ('intel_rapl',
#   '0',
#   'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('llite',
#   'wombat-clilov',
#   'read_bytes(U=B)',
#   '17225788119951',
#   '1571076903.839997',
#   '-'),
#  ('llite',
#   'wombat-clilov',
#   'write_bytes(U=B)',
#   '316646117314',
#   '1571076903.839997',
#   '-'),
#  ('llite', 'wombat-clilov', 'direct_read(U=B)', '0', '1571076903.839997', '-'),
#  ('llite',
#   'wombat-clilov',
#   'direct_write(U=B)',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('llite', 'wombat-clilov', 'osc_read(U=B)', '0', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'osc_write(U=B)', '0', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'dirty_pages_hits', '0', '1571076903.839997', '-'),
#  ('llite',
#   'wombat-clilov',
#   'dirty_pages_misses',
#   '0',
#   '1571076903.839997',
#   '-'),
#  ('llite', 'wombat-clilov', 'ioctl', '2638069', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'open', '6044407', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'close', '6044389', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'mmap', '57088', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'seek', '98899190', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'fsync', '7732', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'setattr', '45704', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'truncate', '340164', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'flock', '231885', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'getattr', '10859913', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'statfs', '68100', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'alloc_inode', '342330', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'setxattr', '41703', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'getxattr', '709760663', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'listxattr', '129', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'removexattr', '0', '1571076903.839997', '-'),
#  ('llite',
#   'wombat-clilov',
#   'inode_permission',
#   '261962122',
#   '1571076903.839997',
#   '-'),
#  ('llite', 'wombat-clilov', 'readdir', '23239', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'create', '259109', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'lookup', '0', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'link', '0', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'unlink', '79114', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'symlink', '266', '1571076903.839997', '-'),
#  ('llite', 'wombat-clilov', 'mkdir', '400', '1571076903.839997', '-'),
#  ...]

# %%
filled_set = { key:{} for key in search_out.keys() }

for key in search_out.keys():
    if "Single JobID" in search_out[key]:
        for j in range(len( search_out[key]["Source"])):
            f = search_out[key]["Source"][ j ]
            
            filled_set[key].update( host_to_info_dict( f ) )

filled_set
# Out:
# {('comet-07-47', '2019-10-14T23:57:48', '2019-10-14T23:58:21', '27362828'): 0,
#  ('comet-07-66', '2019-10-14T23:57:48', '2019-10-14T23:57:59', '27362829'): 0,
#  ('comet-07-66', '2019-10-14T23:57:48', '2019-10-14T23:57:57', '27362831'): 0,
#  ('comet-07-66', '2019-10-14T23:57:48', '2019-10-14T23:57:55', '27362833'): 0,
#  ('comet-07-66', '2019-10-14T23:57:48', '2019-10-14T23:57:57', '27362835'): 0,
#  ('comet-29-09', '2019-10-14T23:57:48', '2019-10-14T23:59:54', '27362836'): 0,
#  ('comet-29-10', '2019-10-14T23:57:48', '2019-10-14T23:59:54', '27362836'): 0,
#  ('comet-04-67', '2019-10-14T23:59:05', '2019-10-14T23:59:10', '27362845'): 0,
#  ('comet-01-07', '2019-10-14T23:59:43', '2019-10-14T23:59:50', '27362852'): 0,
#  ('comet-01-18', '2019-10-14T23:59:43', '2019-10-14T23:59:52', '27362853'): 0}

# %%
filtered_set = { key:[] }

# %% [markdown]
# ## Temp A

# %%
def get_stats( data ):         
    stats = {
        'Count' : len(data),
        'Min' : min(data),
        'Max' : max(data),
        'Mode' : statistics.mode(data),
        'Quartiles' : np.percentile(data, [25, 50, 75] ),
        'Mean' : np.mean(data),
        'Std. Dev' : np.std(data),
        'Skew' : scipy.stats.skew(data)
    }
    return stats

def get_cov_matrix( x_list, y_list ):
    x_arr,y_arr = np.array( x_list ), np.array( y_list )
    
    return np.cov( x_arr, y_arr )

def get_corr_matrix( x_list, y_list ):
    x_arr,y_arr = np.array( x_list ), np.array( y_list )
    
    return np.corrcoef( x_arr, y_arr ) #r = corrcoef_matrix[0, 1]

def corr_w_pval( x_list, y_list ):
    x_arr,y_arr = np.array( x_list ), np.array( y_list )

    return scipy.stats.pearsonr( x_arr, y_arr )

def linear_reg( x_list, y_list ):
    x_arr,y_arr = np.array( x_list ), np.array( y_list )

    #LinregressResult has .slope, .intercept, .rvalue, .pvalue, .stderr
    return scipy.stats.linregress( x_arr, y_arr )

def norm_df( df ):
    return (df-df.mean())/df.std()

def minmax_df( df ):
    return (df-df.min())/(df.max()-df.min())

# %% [markdown]
# plot templates

# %%
# Histogram
#hist, bin_edges = np.histogram(x, bins=10)
fig, ax = plt.subplots()
ax.hist(x, bin_edges, cumulative=False)
ax.set_xlabel('x')
ax.set_ylabel('Frequency')
plt.show()

# Pie Chart
# x, y, z = 128, 256, 1024
fig, ax = plt.subplots()
ax.pie((x, y, z), labels=('x', 'y', 'z'), autopct='%1.1f%%')
plt.show()

# Horizontal Bar Chart
#x = np.arange(21)
#y = np.random.randint(21, size=21)
#err = np.random.randn(21)
fig, ax = plt.subplots())
ax.bar(x, y, yerr=err)
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# Scatterplot w/ Line
#x = np.arange(21)
#y = 5 + 2 * x + 2 * np.random.randn(21)
#slope, intercept, r, *__ = scipy.stats.linregress(x, y)
#line = f'Regression line: y={intercept:.2f}+{slope:.2f}x, r={r:.2f}'
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='s', label='Data points')
ax.plot(x, intercept + slope * x, label=line)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(facecolor='white')
plt.show()

# Seaborn heatmap w/ 2 var
#Index= ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
#Cols = ['A', 'B', 'C', 'D']
#data = abs(np.random.randn(5, 4))
#df = DataFrame(data, index=Index, columns=Cols)
sns.heatmap(df, annot=True)

# %%
# SAVE template
save_thing = test_dict
f = open("save_thing_name.pkl","wb")
pickle.dump( save_thing,f )
f.close()

# read in search_out from saved dict in src_file
#save_thing = pickle.load( open( "save_thing_name.pkl", "rb" ) )
#keys = list(save_thing.keys())
#len(keys)

# %% [markdown]
# # Analysis

# %% [markdown]
# #### Setup Structures

# %%
# All valid 'Timely Data' occurences in dataset
list_of_timelys = []
dropped = []

for i in range(len(keys)):
    try:
        key = keys[i]
        list_of_timelys.append( search_out[key]['Host Info']['Timely Data'] )
    except:
        host_file = search_out[key]['Host Info']
        dropped.append( ( key, host_file ) )
    
len(list_of_timelys)
# Out:
# 50

# %%
# data points organized by label reported
timedata_by_label = {}

for i in range(len( list_of_timelys )):
    timely_i = list_of_timelys[i]
    
    for j in range(len( timely_i )):
        tup_j = timely_i[j]
        label = ( tup_j[:3] )
        
        if label in timedata_by_label:
            timedata_by_label[label].append( ( tup_j[4], tup_j[3] ) )
        else:
            timedata_by_label[label] = [ ( tup_j[4], tup_j[3] ) ]

# %%
# labels of all reported metrics
timedata_keys = list(timedata_by_label.keys())
timedata_keys
# Out:
# [('block', 'io_ticks(U=ms)', 'md0'),
#  ('block', 'io_ticks(U=ms)', 'md1'),
#  ('block', 'io_ticks(U=ms)', 'sda'),
#  ('block', 'io_ticks(U=ms)', 'sdb'),
#  ('cpu', 'irq(U=cs)', '22'),
#  ('cpu', 'irq(U=cs)', '20'),
#  ('cpu', 'irq(U=cs)', '21'),
#  ('cpu', 'irq(U=cs)', '11'),
#  ('cpu', 'irq(U=cs)', '10'),
#  ('cpu', 'irq(U=cs)', '13'),
#  ('cpu', 'irq(U=cs)', '12'),
#  ('cpu', 'irq(U=cs)', '15'),
#  ('cpu', 'irq(U=cs)', '14'),
#  ('cpu', 'irq(U=cs)', '17'),
#  ('cpu', 'irq(U=cs)', '16'),
#  ('cpu', 'irq(U=cs)', '19'),
#  ('cpu', 'irq(U=cs)', '18'),
#  ('cpu', 'irq(U=cs)', '23'),
#  ('cpu', 'irq(U=cs)', '1'),
#  ('cpu', 'irq(U=cs)', '0'),
#  ('cpu', 'irq(U=cs)', '3'),
#  ('cpu', 'irq(U=cs)', '2'),
#  ('cpu', 'irq(U=cs)', '5'),
#  ('cpu', 'irq(U=cs)', '4'),
#  ('cpu', 'irq(U=cs)', '7'),
#  ('cpu', 'irq(U=cs)', '6'),
#  ('cpu', 'irq(U=cs)', '9'),
#  ('cpu', 'irq(U=cs)', '8'),
#  ('ib', 'symbol_error(W=32)', 'mlx4_0.1'),
#  ('ib_ext', 'port_multicast_xmit_pkts', 'mlx4_0/1'),
#  ('ib_sw', 'tx_bytes(U=4B)', 'mlx4_0/1'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '22'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '20'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '21'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '11'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '10'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '13'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '12'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '15'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '14'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '17'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '16'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '19'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '18'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '23'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '1'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '0'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '3'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '2'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '5'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '4'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '7'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '6'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '9'),
#  ('intel_hsw', 'FIXED_CTR1(W=48)', '8'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/7'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/6'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/5'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/4'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/3'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/2'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/1'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/0'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/6'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/7'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/4'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/5'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/2'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/3'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/0'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/1'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/10'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/11'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/9'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/8'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/8'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/9'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/11'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/10'),
#  ('intel_hsw_hau', 'CTR2(W=48)', 'ff/12.5'),
#  ('intel_hsw_hau', 'CTR2(W=48)', '7f/12.1'),
#  ('intel_hsw_hau', 'CTR2(W=48)', 'ff/12.1'),
#  ('intel_hsw_hau', 'CTR2(W=48)', '7f/12.5'),
#  ('intel_hsw_imc', 'CTR3(W=48)', 'ff/14.1'),
#  ('intel_hsw_imc', 'CTR3(W=48)', 'ff/14.0'),
#  ('intel_hsw_imc', 'CTR3(W=48)', '7f/17.1'),
#  ('intel_hsw_imc', 'CTR3(W=48)', '7f/17.0'),
#  ('intel_hsw_imc', 'CTR3(W=48)', '7f/14.0'),
#  ('intel_hsw_imc', 'CTR3(W=48)', '7f/14.1'),
#  ('intel_hsw_imc', 'CTR3(W=48)', 'ff/17.0'),
#  ('intel_hsw_imc', 'CTR3(W=48)', 'ff/17.1'),
#  ('intel_hsw_pcu', 'FIXED_CTR0(W=64)', '1'),
#  ('intel_hsw_pcu', 'FIXED_CTR0(W=64)', '0'),
#  ('intel_hsw_qpi', 'CTR2(U=flt(W=48)', 'ff/08.2'),
#  ('intel_hsw_qpi', 'CTR2(U=flt(W=48)', '7f/08.2'),
#  ('intel_hsw_qpi', 'CTR2(U=flt(W=48)', '7f/09.2'),
#  ('intel_hsw_qpi', 'CTR2(U=flt(W=48)', 'ff/09.2'),
#  ('intel_hsw_r2pci', 'CTR2(W=44)', '7f/10.1'),
#  ('intel_hsw_r2pci', 'CTR2(W=44)', 'ff/10.1'),
#  ('intel_rapl', 'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)', '1'),
#  ('intel_rapl', 'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)', '0'),
#  ('llite', 'mknod', 'wombat-clilov'),
#  ('llite', 'mknod', 'panda-clilov'),
#  ('lnet', 'rx_bytes(U=B)', '-'),
#  ('mdc', 'reqs', 'wombat-clilov'),
#  ('mdc', 'reqs', 'panda-clilov'),
#  ('mem', 'HugePages_Total', '1'),
#  ('mem', 'HugePages_Total', '0'),
#  ('net', 'tx_packets', 'ib0.8447'),
#  ('net', 'tx_packets', 'ib0'),
#  ('net', 'tx_packets', 'lo'),
#  ('net', 'tx_packets', 'ib0.9338'),
#  ('net', 'tx_packets', 'peth0'),
#  ('net', 'tx_packets', 'eth0'),
#  ('numa', 'local_node', '1'),
#  ('numa', 'local_node', '0'),
#  ('osc', 'reqs', 'wombat-clilov'),
#  ('osc', 'reqs', 'panda-clilov'),
#  ('proc', 'Cpus_allowed_list', 'nscd/5546'),
#  ('proc', 'Cpus_allowed_list', 'munged/5638'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4053'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4045'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4051'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4047'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4057'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4041'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4055'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4043'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4063'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/3631'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4061'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4039'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4029'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4035'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4048'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4037'),
#  ('proc', 'Cpus_allowed_list', 'orterun/4018'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4031'),
#  ('proc', 'Cpus_allowed_list', 'hald/5436'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4033'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4021'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4024'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4027'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/5479'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4022'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4023'),
#  ('proc', 'Cpus_allowed_list', 'perl/4015'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4059'),
#  ('proc', 'Cpus_allowed_list', 'mdrun_mpi/4020'),
#  ('ps', 'nr_running', '-'),
#  ('sysv_shm', 'mem_used(U=B)', '-'),
#  ('tmpfs', 'bytes_used(U=B)', '/dev/shm'),
#  ('vfs', 'file_use', '-'),
#  ('vm', 'allocstall', '-'),
#  ('net', 'tx_packets', 'ib0.8446'),
#  ('net', 'tx_packets', 'ib0.9336'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/morad'),
#  ('proc', 'Cpus_allowed_list', 'nscd/5552'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/695'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/711'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/693'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/696'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/705'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/697'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/701'),
#  ('proc', 'Cpus_allowed_list', 'munged/5644'),
#  ('proc', 'Cpus_allowed_list', 'mpirun_rsh/584'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/707'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/694'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/715'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/700'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/709'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/708'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/576'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/699'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/698'),
#  ('proc', 'Cpus_allowed_list', 'hald/5442'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/5485'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/710'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/702'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/716'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/704'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/714'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/706'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/712'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/691'),
#  ('proc', 'Cpus_allowed_list', 'perl/581'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/713'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/703'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/jjakowsk'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17624'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17621'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17620'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17628'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17627'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17609'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17608'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17626'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17607'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17606'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17625'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17612'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17613'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17610'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17611'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17623'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17617'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17614'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17615'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17616'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17618'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17619'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/17604'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17629'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17622'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/ruizm'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/vpaschal'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/share/apps'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/dschaich'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31117'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31103'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31119'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/31097'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31118'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31115'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31116'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31099'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31114'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31106'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31107'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31104'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31105'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31102'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31122'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31100'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31101'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31111'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31110'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31113'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31112'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31120'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31121'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31108'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31109'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/vkotteda'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/pmistani'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/opt/intel/2016.3.210'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1937'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1935'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1934'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1933'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1932'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1931'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1936'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1939'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1938'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1924'),
#  ('proc', 'Cpus_allowed_list', 'pmi_proxy/1913'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1923'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1930'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1925'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1928'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1929'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1926'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1920'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1921'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1922'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1941'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1942'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1943'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1940'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1927'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7094'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7095'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7096'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7097'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7090'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7091'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7092'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7093'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7089'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7088'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7098'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7099'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7080'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/7077'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7081'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7087'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7083'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7086'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7102'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7100'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7101'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7085'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7079'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7084'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7082'),
#  ('proc', 'Cpus_allowed_list', 'roms/29031'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/29011'),
#  ('proc', 'Cpus_allowed_list', 'roms/29036'),
#  ('proc', 'Cpus_allowed_list', 'roms/29013'),
#  ('proc', 'Cpus_allowed_list', 'roms/29034'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/5871'),
#  ('proc', 'Cpus_allowed_list', 'hald/5828'),
#  ('proc', 'Cpus_allowed_list', 'roms/29015'),
#  ('proc', 'Cpus_allowed_list', 'roms/29026'),
#  ('proc', 'Cpus_allowed_list', 'munged/6083'),
#  ('proc', 'Cpus_allowed_list', 'roms/29029'),
#  ('proc', 'Cpus_allowed_list', 'roms/29028'),
#  ('proc', 'Cpus_allowed_list', 'roms/29018'),
#  ('proc', 'Cpus_allowed_list', 'roms/29019'),
#  ('proc', 'Cpus_allowed_list', 'nscd/5964'),
#  ('proc', 'Cpus_allowed_list', 'roms/29032'),
#  ('proc', 'Cpus_allowed_list', 'roms/29033'),
#  ('proc', 'Cpus_allowed_list', 'roms/29016'),
#  ('proc', 'Cpus_allowed_list', 'roms/29022'),
#  ('proc', 'Cpus_allowed_list', 'roms/29025'),
#  ('proc', 'Cpus_allowed_list', 'roms/29024'),
#  ('proc', 'Cpus_allowed_list', 'roms/29027'),
#  ('proc', 'Cpus_allowed_list', 'roms/29035'),
#  ('proc', 'Cpus_allowed_list', 'roms/29021'),
#  ('proc', 'Cpus_allowed_list', 'roms/29020'),
#  ('proc', 'Cpus_allowed_list', 'roms/29014'),
#  ('proc', 'Cpus_allowed_list', 'roms/29023'),
#  ('proc', 'Cpus_allowed_list', 'roms/29017'),
#  ('proc', 'Cpus_allowed_list', 'roms/29030'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20406'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20407'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20405'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20408'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/20403'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20415'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20409'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20411'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20410'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20413'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20412'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20428'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20414'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20417'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20416'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20419'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20425'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20426'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20427'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20420'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20421'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20422'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20423'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20424'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/20319'),
#  ('proc', 'Cpus_allowed_list', 'namd2/20418'),
#  ('proc', 'Cpus_allowed_list', 'mpirun_rsh/20356'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12705'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12715'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12714'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/12690'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12713'),
#  ('proc', 'Cpus_allowed_list', 'mpirun_rsh/12626'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12696'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12697'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12694'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12695'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12692'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12693'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12712'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12711'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12698'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12699'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12700'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12701'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12702'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12703'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12704'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12710'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12706'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12707'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12708'),
#  ('proc', 'Cpus_allowed_list', 'namd2/12709'),
#  ('net', 'tx_packets', 'ib0.9334'),
#  ('proc', 'Cpus_allowed_list', 'srun/28951'),
#  ('proc', 'Cpus_allowed_list', 'srun/28950'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/5737'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/13947'),
#  ('proc', 'Cpus_allowed_list', 'mpirun/28943'),
#  ('proc', 'Cpus_allowed_list', 'python/28877'),
#  ('proc', 'Cpus_allowed_list', 'nscd/5830'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28981'),
#  ('proc', 'Cpus_allowed_list', 'mpiexec.hydra/28949'),
#  ('proc', 'Cpus_allowed_list', 'python/13994'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28973'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28972'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28971'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28970'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28977'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28976'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28975'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28974'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/28923'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28979'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28978'),
#  ('proc', 'Cpus_allowed_list', 'lammps/28980'),
#  ('proc', 'Cpus_allowed_list', 'hald/5694'),
#  ('proc', 'Cpus_allowed_list', 'pmi_proxy/28963'),
#  ('proc', 'Cpus_allowed_list', 'munged/5949'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/28859'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/opt/gaussian'),
#  ('proc', 'Cpus_allowed_list', 'python/15788'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/15725'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/opt/matlab'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/13827'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14045'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14158'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14807'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14806'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14141'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14148'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14824'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14146'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14150'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14144'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14152'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14799'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14154'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14814'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14156'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14160'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14162'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14781'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/14139'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14785'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14773'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14784'),
#  ('proc', 'Cpus_allowed_list', 'MATLAB/13836'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14815'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14779'),
#  ('proc', 'Cpus_allowed_list', 'matlab_helper/14778'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16869'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16878'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16893'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16870'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16871'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16882'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16892'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16879'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16890'),
#  ('proc', 'Cpus_allowed_list', 'hydra_pmi_proxy/16868'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16881'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16880'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16883'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16891'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16885'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16884'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16887'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16886'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16889'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16888'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16873'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16874'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16875'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16876'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/16877'),
#  ('proc', 'Cpus_allowed_list', 'su/15816'),
#  ('proc', 'Cpus_allowed_list', 'ridft/18003'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18313'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18312'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/17988'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18301'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18294'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18295'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18296'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18297'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18298'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18299'),
#  ('proc', 'Cpus_allowed_list', 'mpid/18281'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18315'),
#  ('proc', 'Cpus_allowed_list', 'mpirun/18278'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18293'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18314'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18302'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18303'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18300'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18316'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18311'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18310'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18304'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18305'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18306'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18308'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18309'),
#  ('proc', 'Cpus_allowed_list', 'ridft_mpi/18307'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25120'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25121'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25122'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25123'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25124'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25125'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25118'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25111'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25110'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25113'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25112'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25115'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25114'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25117'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25116'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25106'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25109'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25104'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25119'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/25067'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25105'),
#  ('proc', 'Cpus_allowed_list', 'hydra_pmi_proxy/25098'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25108'),
#  ('proc', 'Cpus_allowed_list', 'srun/25085'),
#  ('proc', 'Cpus_allowed_list', 'srun/25086'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25107'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25102'),
#  ('proc', 'Cpus_allowed_list', 'lmp_mpi/25103'),
#  ('proc', 'Cpus_allowed_list', 'mpirun/25083'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/32269'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/32268'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/32263'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/32262'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/32267'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/32266'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/32265'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/32264'),
#  ('proc', 'Cpus_allowed_list', 'pmi_proxy/32250'),
#  ('net', 'tx_packets', 'ib0.8448'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/6783'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13611'),
#  ('proc', 'Cpus_allowed_list', 'munged/3469'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13610'),
#  ('proc', 'Cpus_allowed_list', 'nscd/6866'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13598'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13599'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13609'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13596'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13614'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13617'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13597'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13616'),
#  ('proc', 'Cpus_allowed_list', 'hald/6740'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13615'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13600'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13601'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13602'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13603'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13604'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13605'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13606'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13607'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13608'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13613'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13618'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/13594'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13619'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/13612'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/26807'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/26870'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26895'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26894'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26891'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26890'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26893'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26892'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26882'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26883'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26880'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26881'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26886'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26887'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26884'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26885'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26888'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26889'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26873'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26872'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26877'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26876'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26875'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26874'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26879'),
#  ('proc', 'Cpus_allowed_list', 'abinit/26878'),
#  ('proc', 'Cpus_allowed_list', 'mpirun_rsh/26819'),
#  ('proc', 'Cpus_allowed_list', 'perl/26815'),
#  ('proc', 'Cpus_allowed_list', 'roms/12818'),
#  ('proc', 'Cpus_allowed_list', 'roms/12820'),
#  ('proc', 'Cpus_allowed_list', 'roms/12816'),
#  ('proc', 'Cpus_allowed_list', 'roms/12811'),
#  ('proc', 'Cpus_allowed_list', 'roms/12817'),
#  ('proc', 'Cpus_allowed_list', 'roms/12814'),
#  ('proc', 'Cpus_allowed_list', 'roms/12815'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/12802'),
#  ('proc', 'Cpus_allowed_list', 'roms/12823'),
#  ('proc', 'Cpus_allowed_list', 'roms/12824'),
#  ('proc', 'Cpus_allowed_list', 'roms/12809'),
#  ('proc', 'Cpus_allowed_list', 'roms/12808'),
#  ('proc', 'Cpus_allowed_list', 'roms/12821'),
#  ('proc', 'Cpus_allowed_list', 'roms/12819'),
#  ('proc', 'Cpus_allowed_list', 'roms/12805'),
#  ('proc', 'Cpus_allowed_list', 'roms/12804'),
#  ('proc', 'Cpus_allowed_list', 'roms/12807'),
#  ('proc', 'Cpus_allowed_list', 'roms/12806'),
#  ('proc', 'Cpus_allowed_list', 'roms/12812'),
#  ('proc', 'Cpus_allowed_list', 'roms/12813'),
#  ('proc', 'Cpus_allowed_list', 'roms/12810'),
#  ('proc', 'Cpus_allowed_list', 'roms/12822'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17436'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17437'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17435'),
#  ('proc', 'Cpus_allowed_list', 'pmi_proxy/17407'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17438'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17439'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17443'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17442'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17441'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17440'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17447'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17446'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17445'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17444'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/17449'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/opt/intel/composer_xe_2015.2.164'),
#  ('proc', 'Cpus_allowed_list', 'nscd/6827'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5097'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5077'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5091'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5075'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5074'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5073'),
#  ('proc', 'Cpus_allowed_list', 'munged/6931'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5090'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5084'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5079'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5078'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/5068'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5092'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5098'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5100'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5099'),
#  ('proc', 'Cpus_allowed_list', 'hald/6701'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5076'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/6744'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5089'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5086'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5087'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5093'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5085'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5082'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5083'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5080'),
#  ('proc', 'Cpus_allowed_list', 'Gadget4_inputdo/5081'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/vvarma'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30412'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30413'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30410'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30411'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30416'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30417'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30414'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30415'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30409'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30408'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30403'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30395'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30394'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30397'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30402'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30405'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30399'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30398'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30404'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30407'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30401'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30406'),
#  ('proc', 'Cpus_allowed_list', 'orted/30388'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30400'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/30396'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31843'),
#  ('proc', 'Cpus_allowed_list', 'orted/31824'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31827'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31828'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31829'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31839'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31838'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31837'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31836'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31835'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31834'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31833'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31832'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31831'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31830'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31848'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31849'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31842'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31850'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31840'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31841'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31846'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31847'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31844'),
#  ('proc', 'Cpus_allowed_list', 'SpEC/31845'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32451'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32450'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32453'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32452'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32455'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32454'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32457'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32456'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32459'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32458'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32448'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32449'),
#  ('proc', 'Cpus_allowed_list', 'nscd/6876'),
#  ('proc', 'Cpus_allowed_list', 'munged/6978'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32446'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32447'),
#  ('proc', 'Cpus_allowed_list', 'pmi_proxy/32442'),
#  ('proc', 'Cpus_allowed_list', 'hald/6748'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/6791'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32468'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32469'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32464'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32465'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32466'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32467'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32460'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32461'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32462'),
#  ('proc', 'Cpus_allowed_list', 'vasp_std/32463'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26908'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26909'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26904'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26919'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26916'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26906'),
#  ('proc', 'Cpus_allowed_list', 'hydra_pmi_proxy/26901'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26914'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26922'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26923'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26920'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26921'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26924'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26913'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26912'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26911'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26910'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26917'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26905'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26915'),
#  ('proc', 'Cpus_allowed_list', 'lmp_ssrbc/26907'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20932'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20933'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20931'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20936'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20934'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20935'),
#  ('proc', 'Cpus_allowed_list', 'srun/20610'),
#  ('proc', 'Cpus_allowed_list', 'srun/20611'),
#  ('proc', 'Cpus_allowed_list', '_batch_command./20628'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20654'),
#  ('proc', 'Cpus_allowed_list', '_batch_command./20627'),
#  ('proc', 'Cpus_allowed_list', '_batch_command./20626'),
#  ('proc', 'Cpus_allowed_list', '_batch_command./20630'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20661'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20644'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20633'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20632'),
#  ('proc', 'Cpus_allowed_list', '_batch_command./20629'),
#  ('proc', 'Cpus_allowed_list', 'raxmlHPC-HYBRID/20634'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/20596'),
#  ('proc', 'Cpus_allowed_list', '_batch_command./20631'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25193'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25192'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/25182'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25191'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25187'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25190'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25185'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25197'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25196'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25203'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25202'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25201'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25200'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25207'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25206'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25205'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25204'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25188'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25189'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25199'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25198'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25195'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25186'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25184'),
#  ('proc', 'Cpus_allowed_list', 'UFMAE_CAC/25194'),
#  ('proc', 'Cpus_allowed_list', 'munged/6973'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/6785'),
#  ('proc', 'Cpus_allowed_list', 'nscd/6870'),
#  ('proc', 'Cpus_allowed_list', 'hald/6742'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/8254'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/8255'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/8256'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/8257'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/8250'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/8251'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/8252'),
#  ('proc', 'Cpus_allowed_list', 'pw.x/8253'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/8248'),
#  ('proc', 'Cpus_allowed_list', 'orted/26150'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26176'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26180'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26181'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26182'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26183'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26166'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26167'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26162'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26163'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26160'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26161'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26179'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26178'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26164'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26165'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26175'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26174'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26177'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26169'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26171'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26170'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26173'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26172'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/26168'),
#  ('proc', 'Cpus_allowed_list', 'pmi_proxy/29450'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29480'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29481'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29482'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29483'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29484'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29485'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29486'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29487'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29488'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29466'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29465'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29467'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29468'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29469'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29479'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29478'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29475'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29474'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29477'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29476'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29471'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29470'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29473'),
#  ('proc', 'Cpus_allowed_list', 'athena_mpi/29472'),
#  ('proc', 'Cpus_allowed_list', 'serial.csh/17884'),
#  ('proc', 'Cpus_allowed_list', 'qchem/17870'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/17507'),
#  ('proc', 'Cpus_allowed_list', 'qcprog.exe/17891'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19508'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19509'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19502'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19503'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19500'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19501'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19506'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19507'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19504'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19505'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19515'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19514'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19517'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19516'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19511'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19510'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19513'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19512'),
#  ('proc', 'Cpus_allowed_list', 'orted/19484'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19498'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19499'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19494'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19495'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19496'),
#  ('proc', 'Cpus_allowed_list', 'nrniv/19497'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21826'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/21817'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21825'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21828'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21829'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21839'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21838'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21840'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21827'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21833'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21832'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21831'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21830'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21837'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21836'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21835'),
#  ('proc', 'Cpus_allowed_list', 'cp2k.popt/21834'),
#  ('proc', 'Cpus_allowed_list', 'nscd/6872'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27917'),
#  ('proc', 'Cpus_allowed_list', 'munged/6975'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27919'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27918'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27940'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27931'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27930'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27933'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27936'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27932'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/6787'),
#  ('proc', 'Cpus_allowed_list', 'hald/6744'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27935'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/27915'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27934'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27939'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27938'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27937'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27928'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27929'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27926'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27927'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27924'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27925'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27922'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27923'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27920'),
#  ('proc', 'Cpus_allowed_list', 'gh3d2m/27921'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/6802'),
#  ('proc', 'Cpus_allowed_list', 'hald/6759'),
#  ('proc', 'Cpus_allowed_list', 'nscd/6887'),
#  ('proc', 'Cpus_allowed_list', 'python/17379'),
#  ('proc', 'Cpus_allowed_list', 'munged/6989'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/30499'),
#  ('proc', 'Cpus_allowed_list', 'python/30528'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/29977'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/8300'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/15696'),
#  ('proc', 'Cpus_allowed_list', 'python/9896'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/22681'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/29801'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/5080'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/12117'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/19027'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/26038'),
#  ('proc', 'Cpus_allowed_list', 'mitsuba/745'),
#  ('proc', 'Cpus_allowed_list', 'java/9791'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/9789'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/19476'),
#  ('proc', 'Cpus_allowed_list', 'java/19478'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/23982'),
#  ('proc', 'Cpus_allowed_list', 'java/23984'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27716'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27717'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27714'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27715'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27712'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27713'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27710'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27711'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/27705'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27709'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27708'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27718'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27719'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27707'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27722'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27721'),
#  ('proc', 'Cpus_allowed_list', 'run1-3rd/27720'),
#  ('proc', 'Cpus_allowed_list', 'mpirun/29854'),
#  ('proc', 'Cpus_allowed_list', 'pmi_proxy/29874'),
#  ('proc', 'Cpus_allowed_list', 'mpiexec.hydra/29860'),
#  ('proc', 'Cpus_allowed_list', 'srun/29862'),
#  ('proc', 'Cpus_allowed_list', 'srun/29861'),
#  ('proc', 'Cpus_allowed_list', 'qchem/29625'),
#  ('proc', 'Cpus_allowed_list', 'sleep/30562'),
#  ('proc', 'Cpus_allowed_list', 'qcprog.exe/29881'),
#  ('proc', 'Cpus_allowed_list', 'slurm_script/29614'),
#  ('proc', 'Cpus_allowed_list', 'sleep/31708'),
#  ('proc', 'Cpus_allowed_list', 'sleep/32537'),
#  ('proc', 'Cpus_allowed_list', 'sleep/1010'),
#  ('net', 'tx_packets', 'peth0.1146'),
#  ('proc', 'Cpus_allowed_list', 'munged/6121'),
#  ('proc', 'Cpus_allowed_list', 'mpispawn/4721'),
#  ('proc', 'Cpus_allowed_list', 'hald/5876'),
#  ('proc', 'Cpus_allowed_list', 'hald-addon-acpi/5919'),
#  ('proc', 'Cpus_allowed_list', 'gene_comet/4738'),
#  ('proc', 'Cpus_allowed_list', 'gene_comet/4739'),
#  ('proc', 'Cpus_allowed_list', 'gene_comet/4729'),
#  ...]

# %%
len(timedata_keys)
# Out:
# 5980

# %% [markdown]
# ### General Descriptive Statistics

# %%
# generating general stats for each list in data_by_label
descriptives = { }
static = []

for i in range(len( timedata_keys )):
    key = timedata_keys[i]
    timedata_list = [ item[1] for item in timedata_by_label[ key ] ]
    
    if sum(timedata_list) == 0:
        static.append( key )
    else:
        stats = get_stats( timedata_list )
        descriptives[ key ] = stats

len(descriptives)
# Out:
# 5923

# %%
descriptives[ timedata_keys[2] ]
# Out:
# {'Count': 7585,
#  'Min': 17432,
#  'Max': 171816728,
#  'Mode': 27074360,
#  'Quartiles': array([  820194.,  8557785., 27074360.]),
#  'Mean': 22129970.74528675,
#  'Std. Dev': 35249062.212975614,
#  'Skew': 2.8416897649987107}

# %%
# SAVE descriptive stat compilation for continued use
save_thing = descriptives
f = open("LF_desc_stats.pkl","wb")
pickle.dump( save_thing,f )
f.close()

# read in search_out from saved dict in src_file
#save_thing = pickle.load( open( "save_thing_name.pkl", "rb" ) )
#keys = list(save_thing.keys())
#len(keys)

# %% [markdown]
# ### Cpicore Check Across All Labels

# %%
#dict_of_timelys = {}
#count = 0
#
#for i in range(len(keys)):
#    try:
#        key = keys[i]
#        dict_of_timelys[ count ] = search_out[key]['Host Info']['Timely Data']
#        count += 1
#    except:
#        next

# %%
# search for metrics used in previously tested cpicore() measure
#for i in range(len( dict_of_timelys )):
#    test_list = dict_of_timelys[i]
#    
#    for item in test_list:
#        for val in item:
#            try:
#                if 'CLOCKS_UNHALTED_CORE' in val or 'INSTRUCTIONS_RETIRED' in val:
#                    print(item)
#            except:
#                next

# %% [markdown]
# Required metrics do not appear in dataset

# %% [markdown]
# ### Standard Deviation for each Label

# %%
all_devs = []

for label,stat_dict in descriptives.items():
    all_devs.append( (label,stat_dict['Std. Dev']) )

all_devs

# %%
#test_sort = all_devs.sort(key=lambda tup: tup[1], reverse=True)
#find quartiles

# %% [markdown]
# ### Occurences for each Label

# %%
all_counts = []

for label,stat_dict in descriptives.items():
    all_counts.append( (label,stat_dict['Count']) )

all_counts

# %%
# any distinctive occurences?

# %% [markdown]
# ### Label Behavior across time

# %%
# go through timely data lists 
# keys: labels, values: (timestamp,value)
#use lambda to sort by timestamp?

# %%
target = 'block'

# %%
test_dict = { key:val for key,val in timedata_by_label.items() if target in key[0] }

for key,val in test_dict.items():
    print( key, ':\t', len(val) )
# Out:
# ('block', 'io_ticks(U=ms)', 'md0') :	 7585
# ('block', 'io_ticks(U=ms)', 'md1') :	 7585
# ('block', 'io_ticks(U=ms)', 'sda') :	 7585
# ('block', 'io_ticks(U=ms)', 'sdb') :	 7585
# ('block', 'io_ticks(U=ms)', 'zd0') :	 133
# ('block', 'io_ticks(U=ms)', 'dm-0') :	 133
# ('block', 'io_ticks(U=ms)', 'sdd') :	 144
# ('block', 'io_ticks(U=ms)', 'sdc') :	 144

# %%
preset_a = [ 'md0', 'md1', 'sda', 'sdb' ] # md0,md1 are static, all 0
preset_b = [ 'zd0', 'dm-0' ] # both are static across time
preset_c = [ 'sdd', 'sdc' ] # both are static across time

# %%
desc_ai  = descriptives[ ('block', 'io_ticks(U=ms)', 'sda') ]
desc_aj = descriptives[ ('block', 'io_ticks(U=ms)', 'sdb') ]

# %%
desc_ai
# Out:
# {'Count': 7585,
#  'Min': 17432,
#  'Max': 171816728,
#  'Mode': 27074360,
#  'Quartiles': array([  820194.,  8557785., 27074360.]),
#  'Mean': 22129970.74528675,
#  'Std. Dev': 35249062.212975614,
#  'Skew': 2.8416897649987107}

# %%
desc_aj
# Out:
# {'Count': 7585,
#  'Min': 22209,
#  'Max': 172456547,
#  'Mode': 27383544,
#  'Quartiles': array([  806240.,  8603837., 27383544.]),
#  'Mean': 22237056.575477917,
#  'Std. Dev': 35283712.03987915,
#  'Skew': 2.844457114823878}

# %%
test_set = []

for i in range(len(list_of_timelys)):
    timely = list_of_timelys[i]
    
    for j in range(len(timely)):
        line = timely[j]
        label = line[:3]
        
        if label in test_dict.keys():
            test_set.append( line[2:] )

# %%
test_df = pd.DataFrame(test_set)
test_df.head(10)
# Out:
#      0         1                    2
# 0  md0         0  2017-04-04T16:37:31
# 1  md1         0  2017-04-04T16:37:31
# 2  sda  47379147  2017-04-04T16:37:31
# 3  sdb  47371705  2017-04-04T16:37:31
# 4  md0         0  2017-04-04T16:47:31
# 5  md1         0  2017-04-04T16:47:31
# 6  sda  47379147  2017-04-04T16:47:31
# 7  sdb  47371705  2017-04-04T16:47:31
# 8  md0         0  2017-04-04T16:57:31
# 9  md1         0  2017-04-04T16:57:31

# %%
test_df = test_df.pivot( index=0, columns=2, values=1 )
test_df
# Out:
# 2     2016-12-16T18:42:08  2016-12-16T18:52:08  2016-12-16T19:02:09  \
# 0
# dm-0                  NaN                  NaN                  NaN
# md0                   0.0                  0.0                  0.0
# md1                   0.0                  0.0                  0.0
# sda            13477966.0           13477966.0           13477966.0
# sdb            13472632.0           13472632.0           13472632.0
# sdc                   NaN                  NaN                  NaN
# sdd                   NaN                  NaN                  NaN
# zd0                   NaN                  NaN                  NaN
#
# 2     2016-12-16T19:12:09  2016-12-16T19:22:09  2016-12-16T19:32:09  \
# 0
# dm-0                  NaN                  NaN                  NaN
# md0                   0.0                  0.0                  0.0
# md1                   0.0                  0.0                  0.0
# sda            13477966.0           13477966.0           13477966.0
# sdb            13472632.0           13472632.0           13472632.0
# sdc                   NaN                  NaN                  NaN
# sdd                   NaN                  NaN                  NaN
# zd0                   NaN                  NaN                  NaN
#
# 2     2016-12-16T19:42:09  2016-12-16T19:52:10  2016-12-16T20:02:10  \
# 0
# dm-0                  NaN                  NaN                  NaN
# md0                   0.0                  0.0                  0.0
# md1                   0.0                  0.0                  0.0
# sda            13477966.0           13477966.0           13477966.0
# sdb            13472632.0           13472632.0           13472632.0
# sdc                   NaN                  NaN                  NaN
# sdd                   NaN                  NaN                  NaN
# zd0                   NaN                  NaN                  NaN
#
# 2     2016-12-16T20:12:10         ...           2019-11-28T18:55:46  \
# 0                                 ...
# dm-0                  NaN         ...                           NaN
# md0                   0.0         ...                           0.0
# md1                   0.0         ...                           0.0
# sda            13477966.0         ...                      995189.0
# sdb            13472632.0         ...                     1006814.0
# sdc                   NaN         ...                     1530747.0
# sdd                   NaN         ...                     1707175.0
# zd0                   NaN         ...                           NaN
#
# 2     2019-11-28T19:05:46  2019-11-28T19:15:46  2019-11-28T19:25:46  \
# 0
# dm-0                  NaN                  NaN                  NaN
# md0                   0.0                  0.0                  0.0
# md1                   0.0                  0.0                  0.0
# sda              995189.0             995189.0             995189.0
# sdb             1006814.0            1006814.0            1006814.0
# sdc             1530747.0            1530747.0            1530747.0
# sdd             1707175.0            1707175.0            1707175.0
# zd0                   NaN                  NaN                  NaN
#
# 2     2019-11-28T19:35:46  2019-11-28T19:45:47  2019-11-28T19:55:47  \
# 0
# dm-0                  NaN                  NaN                  NaN
# md0                   0.0                  0.0                  0.0
# md1                   0.0                  0.0                  0.0
# sda              995189.0             995189.0             995189.0
# sdb             1006814.0            1006814.0            1006814.0
# sdc             1530747.0            1530747.0            1530747.0
# sdd             1707175.0            1707175.0            1707175.0
# zd0                   NaN                  NaN                  NaN
#
# 2     2019-11-28T20:05:47  2019-11-28T20:15:47  2019-11-28T20:25:48
# 0
# dm-0                  NaN                  NaN                  NaN
# md0                   0.0                  0.0                  0.0
# md1                   0.0                  0.0                  0.0
# sda              995189.0             995189.0             995189.0
# sdb             1006814.0            1006814.0            1006814.0
# sdc             1530747.0            1530747.0            1530747.0
# sdd             1707175.0            1707175.0            1707175.0
# zd0                   NaN                  NaN                  NaN
#
# [8 rows x 7585 columns]

# %%
#df_a = test_df.loc[[ 'md0', 'md1', 'sda', 'sdb' ]].dropna( axis=1 )
#df_b = test_df.loc[[ 'zd0', 'dm-0' ]].dropna( axis=1 )
#df_c = test_df.loc[[ 'sdd', 'sdc' ]].dropna( axis=1 )

# %%
df_a = test_df.loc[[ 'sda', 'sdb' ]].dropna( axis=1 )
norm_df_a = norm_df( df_a )
minmax_df_a = minmax_df( df_a )

# %%
df_a
# Out:
# 2    2016-12-16T18:42:08  2016-12-16T18:52:08  2016-12-16T19:02:09  \
# 0
# sda           13477966.0           13477966.0           13477966.0
# sdb           13472632.0           13472632.0           13472632.0
#
# 2    2016-12-16T19:12:09  2016-12-16T19:22:09  2016-12-16T19:32:09  \
# 0
# sda           13477966.0           13477966.0           13477966.0
# sdb           13472632.0           13472632.0           13472632.0
#
# 2    2016-12-16T19:42:09  2016-12-16T19:52:10  2016-12-16T20:02:10  \
# 0
# sda           13477966.0           13477966.0           13477966.0
# sdb           13472632.0           13472632.0           13472632.0
#
# 2    2016-12-16T20:12:10         ...           2019-11-28T18:55:46  \
# 0                                ...
# sda           13477966.0         ...                      995189.0
# sdb           13472632.0         ...                     1006814.0
#
# 2    2019-11-28T19:05:46  2019-11-28T19:15:46  2019-11-28T19:25:46  \
# 0
# sda             995189.0             995189.0             995189.0
# sdb            1006814.0            1006814.0            1006814.0
#
# 2    2019-11-28T19:35:46  2019-11-28T19:45:47  2019-11-28T19:55:47  \
# 0
# sda             995189.0             995189.0             995189.0
# sdb            1006814.0            1006814.0            1006814.0
#
# 2    2019-11-28T20:05:47  2019-11-28T20:15:47  2019-11-28T20:25:48
# 0
# sda             995189.0             995189.0             995189.0
# sdb            1006814.0            1006814.0            1006814.0
#
# [2 rows x 7585 columns]

# %%
norm_df_a
# Out:
# 2    2016-12-16T18:42:08  2016-12-16T18:52:08  2016-12-16T19:02:09  \
# 0
# sda             0.707107             0.707107             0.707107
# sdb            -0.707107            -0.707107            -0.707107
#
# 2    2016-12-16T19:12:09  2016-12-16T19:22:09  2016-12-16T19:32:09  \
# 0
# sda             0.707107             0.707107             0.707107
# sdb            -0.707107            -0.707107            -0.707107
#
# 2    2016-12-16T19:42:09  2016-12-16T19:52:10  2016-12-16T20:02:10  \
# 0
# sda             0.707107             0.707107             0.707107
# sdb            -0.707107            -0.707107            -0.707107
#
# 2    2016-12-16T20:12:10         ...           2019-11-28T18:55:46  \
# 0                                ...
# sda             0.707107         ...                     -0.707107
# sdb            -0.707107         ...                      0.707107
#
# 2    2019-11-28T19:05:46  2019-11-28T19:15:46  2019-11-28T19:25:46  \
# 0
# sda            -0.707107            -0.707107            -0.707107
# sdb             0.707107             0.707107             0.707107
#
# 2    2019-11-28T19:35:46  2019-11-28T19:45:47  2019-11-28T19:55:47  \
# 0
# sda            -0.707107            -0.707107            -0.707107
# sdb             0.707107             0.707107             0.707107
#
# 2    2019-11-28T20:05:47  2019-11-28T20:15:47  2019-11-28T20:25:48
# 0
# sda            -0.707107            -0.707107            -0.707107
# sdb             0.707107             0.707107             0.707107
#
# [2 rows x 7585 columns]

# %%
minmax_df_a
# Out:
# 2    2016-12-16T18:42:08  2016-12-16T18:52:08  2016-12-16T19:02:09  \
# 0
# sda                  1.0                  1.0                  1.0
# sdb                  0.0                  0.0                  0.0
#
# 2    2016-12-16T19:12:09  2016-12-16T19:22:09  2016-12-16T19:32:09  \
# 0
# sda                  1.0                  1.0                  1.0
# sdb                  0.0                  0.0                  0.0
#
# 2    2016-12-16T19:42:09  2016-12-16T19:52:10  2016-12-16T20:02:10  \
# 0
# sda                  1.0                  1.0                  1.0
# sdb                  0.0                  0.0                  0.0
#
# 2    2016-12-16T20:12:10         ...           2019-11-28T18:55:46  \
# 0                                ...
# sda                  1.0         ...                           0.0
# sdb                  0.0         ...                           1.0
#
# 2    2019-11-28T19:05:46  2019-11-28T19:15:46  2019-11-28T19:25:46  \
# 0
# sda                  0.0                  0.0                  0.0
# sdb                  1.0                  1.0                  1.0
#
# 2    2019-11-28T19:35:46  2019-11-28T19:45:47  2019-11-28T19:55:47  \
# 0
# sda                  0.0                  0.0                  0.0
# sdb                  1.0                  1.0                  1.0
#
# 2    2019-11-28T20:05:47  2019-11-28T20:15:47  2019-11-28T20:25:48
# 0
# sda                  0.0                  0.0                  0.0
# sdb                  1.0                  1.0                  1.0
#
# [2 rows x 7585 columns]

# %%
grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws)
ax = sns.heatmap( final_df_a, vmin=0, vmax=200000000, ax=ax, cbar_ax=cbar_ax, cbar_kws={"orientation": "horizontal"} )
