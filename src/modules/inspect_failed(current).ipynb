# %% [markdown]
# # Performance Data Lookup

# %%
# System dependencies
from os import listdir
import time as clock
from datetime import timedelta
from IPython.display import clear_output

# %%
import pickle
import gzip
import re

# %%
# Data manipulation dependencies
import pandas as pd
import numpy as np
import datetime as dt

# %%
import prep_IO

# %%
# Directory to save to
save_dir = '../data/continued/'

# Directory of prev job scans
id_dir = '../data/labels/IDs/'

# %%
# Directory of recent saved comet jobs
source_dir = '/oasis/projects/nsf/sys200/stats/xsede_stats/'

# %%
contents = listdir(source_dir)
contents
# Out:
# ['archive_of_archive',
#  'gordon_hostfile_logs',
#  'gordon_pickles',
#  'comet_accounting',
#  'gordon_accounting',
#  'comet_pickles',
#  'archive',
#  '.htaccess',
#  'comet_hostfile_logs']

# %%
possible = [ source_dir+file_name for file_name in listdir(source_dir) ]

for item in possible:
    try:
        listdir(item)
    except:
        print(item)
# Out:
# /oasis/projects/nsf/sys200/stats/xsede_stats/gordon_hostfile_logs
# /oasis/projects/nsf/sys200/stats/xsede_stats/gordon_pickles
# /oasis/projects/nsf/sys200/stats/xsede_stats/gordon_accounting
# /oasis/projects/nsf/sys200/stats/xsede_stats/comet_pickles
# /oasis/projects/nsf/sys200/stats/xsede_stats/.htaccess
# /oasis/projects/nsf/sys200/stats/xsede_stats/comet_hostfile_logs

# %%
locs = { 'aofa': source_dir+'archive_of_archive',
         'job_info': source_dir+'comet_accounting',
         'arc': source_dir+'archive'
         #'host_info': source_dir+'comet_hostfile_logs',
         #'old_pickles': source_dir+'comet_pickles'
       }

# %%
for key,loc in locs.items():
    print(loc)
# Out:
# /oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive
# /oasis/projects/nsf/sys200/stats/xsede_stats/comet_accounting
# /oasis/projects/nsf/sys200/stats/xsede_stats/archive

# %%
arc_data = [ locs['arc']+'/'+host_dir+'/'+stamp 
            for host_dir in listdir(locs['arc'])
            for stamp in listdir(locs['arc']+'/'+host_dir)  ]

aofa_data = [ locs['aofa']+'/'+host_dir+'/'+stamp 
            for host_dir in listdir(locs['aofa'])
            for stamp in listdir(locs['aofa']+'/'+host_dir)  ]

# %%
acct_info_locs = [ locs['job_info']+'/'+stamp for stamp in listdir(locs['job_info']) ]
dates = [ loc[-14:-4] for loc in acct_info_locs ]

# %%
len(arc_data)
# Out:
# 299014

# %%
len(aofa_data)
# Out:
# 1809956

# %%
len(acct_info_locs)
# Out:
# 1228

# %% [markdown]
# ### temporary munging

# %%
def info_dict( rules, info ):
    rules_list = rules.split("|")
    info_list = info.split("|")
    
    if len(rules_list) != len(info_list):
        return {}
    
    else:
        if '\n' in info_list[-1]:
            saved = info_list[:-1]
            extra = info_list[-1]
            cut = extra[:-1]
            
            info_list = saved.append(cut)
            
        return { rules_list[i]:info_list[i] for i in range(len(rules_list)) }

def job_to_info_dict( txt_file_list, target=False ):
    nodes_by_date = {}
    unsaved = []

    for date in txt_file_list:
        try:
            # skip alt files
            #check_stamp = int( date[-14] )
            #if (target) and (check_stamp == target):
            
            # read in file contents
            contents = open_txt( date )
            
            # formatting
            label = date[-14:-4]
            rules = contents[0]
            jobs = contents[1:]
            
            # template to save
            nodes_by_date[ label ] = {}
            nodes_by_date[ label ]["multiple"] = {}
            nodes_by_date[ label ]["rules"] = rules
            
            # run through lines in file
            for job in jobs:
                line = job.split("|")
                node = line[-1]
                info = info_dict( rules, line )
                
                # save multiple node jobs to specified loc
                if len(node) > 12:
                    nodes = format_nodelist( info )
                    for node in nodes:
                        nodes_by_date[ label ][ "multiple" ][ node ] = info
                
                else:
                    nodes_by_date[ label ][ node[:11] ] = info
        except:
            unsaved.append(date)
            continue
            
    
    return nodes_by_date, unsaved

def failed_search( collected_dict_list ):
    
    for i in range( collected_dict_list ):
        temp = collected_dict_list[i]
        nodelist = temp['NodeList']
        s = temp['Start']
        e = temp['End']
        jobid = temp['JobID']

# %% [markdown]
# #### Pre-process available data

# %%
### Process all ###
#arc_hosts = [ prep_IO.host_to_info_dict( host_file ) for host_file in arc_data[:100] ]
#aofa_hosts = [ host_to_info_dict( host_file ) for host_file in aofa_data ]
#acct_dates = [ prep_IO.job_to_info_dict( acct_info_locs )

# %% [markdown]
# # Compile failed

# %%
chunky_list = []

for i in range(10):
    failed = prep_IO.collect_failed( acct_info_locs[i] )
    rules = prep_IO.open_txt( acct_info_locs[i] )[0]
    
    for j in range(len( failed )):
        chunky_list.append( prep_IO.info_dict( rules, failed[j] ))

chunky_list
# Out:
# [{'JobID': '26753815',
#   'User': 'niloo',
#   'Account': 'mqt102',
#   'Start': '2019-09-17T08:56:01',
#   'End': '2019-09-19T00:38:37',
#   'Submit': '2019-09-17T08:55:58',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'g_TSA-thiolate-pcm-5watersv2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-10-36\n'},
#  {'JobID': '26753954',
#   'User': 'niloo',
#   'Account': 'mqt102',
#   'Start': '2019-09-17T09:02:11',
#   'End': '2019-09-19T05:17:58',
#   'Submit': '2019-09-17T09:02:08',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'g_TSA-hyb5.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-04-60\n'},
#  {'JobID': '26755181',
#   'User': 'imsaid2',
#   'Account': 'uic346',
#   'Start': '2019-09-17T10:25:48',
#   'End': '2019-09-19T05:15:10',
#   'Submit': '2019-09-17T10:25:22',
#   'Partition': 'compute',
#   'Timelimit': '3-00:00:00',
#   'JobName': 'job5-86',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-21-58\n'},
#  {'JobID': '26758774',
#   'User': 'kovacevt',
#   'Account': 'uoc108',
#   'Start': '2019-09-19T00:43:18',
#   'End': '2019-09-19T00:43:21',
#   'Submit': '2019-09-17T15:38:04',
#   'Partition': 'compute',
#   'Timelimit': '13:00:00',
#   'JobName': 'n140_f17',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-28-62\n'},
#  {'JobID': '26759701',
#   'User': 'yuezhang',
#   'Account': 'ucd114',
#   'Start': '2019-09-19T01:29:26',
#   'End': '2019-09-19T02:04:32',
#   'Submit': '2019-09-17T16:38:20',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'Res-19_4-right.job',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-14-46\n'},
#  {'JobID': '26760292',
#   'User': 'yuezhang',
#   'Account': 'ucd114',
#   'Start': '2019-09-19T01:36:26',
#   'End': '2019-09-19T02:10:29',
#   'Submit': '2019-09-17T17:06:54',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'Res-19_5-right.job',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-27-18\n'},
#  {'JobID': '26761100',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T08:38:03',
#   'Submit': '2019-09-17T17:55:17',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '39f0.7',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-29-01\n'},
#  {'JobID': '26761160',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T12:29:08',
#   'Submit': '2019-09-17T18:01:03',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '2b0.9PMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-10-63\n'},
#  {'JobID': '26761176',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T12:28:33',
#   'Submit': '2019-09-17T18:02:04',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '2b0.8PMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-17-44\n'},
#  {'JobID': '26761191',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T12:17:25',
#   'Submit': '2019-09-17T18:03:15',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '2b0.6PMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-17-45\n'},
#  {'JobID': '26761298',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T07:14:40',
#   'Submit': '2019-09-17T18:11:45',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '5b0.1LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-22-25\n'},
#  {'JobID': '26761303',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T06:53:54',
#   'Submit': '2019-09-17T18:12:21',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '9b0.1LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-22-45\n'},
#  {'JobID': '26761308',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T07:18:18',
#   'Submit': '2019-09-17T18:12:54',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '11b0.1LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-22-46\n'},
#  {'JobID': '26761314',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T07:06:27',
#   'Submit': '2019-09-17T18:13:23',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '18b0.1LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-22-47\n'},
#  {'JobID': '26761320',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T06:58:10',
#   'Submit': '2019-09-17T18:14:01',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '24b0.1LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-22-48\n'},
#  {'JobID': '26761332',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T07:04:55',
#   'Submit': '2019-09-17T18:14:34',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '31b0.1LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-22-49\n'},
#  {'JobID': '26761340',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T07:07:45',
#   'Submit': '2019-09-17T18:15:13',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '58b0.1LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-22-50\n'},
#  {'JobID': '26761348',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T07:13:56',
#   'Submit': '2019-09-17T18:15:43',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '68b0.1LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-22-51\n'},
#  {'JobID': '26761525',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:04:11',
#   'Submit': '2019-09-17T18:30:48',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '3b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-05\n'},
#  {'JobID': '26761527',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:11:57',
#   'Submit': '2019-09-17T18:31:06',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '4b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-06\n'},
#  {'JobID': '26761531',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:15:25',
#   'Submit': '2019-09-17T18:31:18',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '5b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-12\n'},
#  {'JobID': '26761535',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:11:45',
#   'Submit': '2019-09-17T18:31:29',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '6b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-14\n'},
#  {'JobID': '26761538',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:11:27',
#   'Submit': '2019-09-17T18:31:41',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '7b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-18\n'},
#  {'JobID': '26761539',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T01:52:30',
#   'Submit': '2019-09-17T18:31:50',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '8b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-23\n'},
#  {'JobID': '26761545',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:11:16',
#   'Submit': '2019-09-17T18:32:01',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '9b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-25\n'},
#  {'JobID': '26761549',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:04:32',
#   'Submit': '2019-09-17T18:32:12',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '10b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-26\n'},
#  {'JobID': '26761551',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:11:35',
#   'Submit': '2019-09-17T18:32:29',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '11b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-28\n'},
#  {'JobID': '26761555',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T01:52:23',
#   'Submit': '2019-09-17T18:32:40',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '12b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-29\n'},
#  {'JobID': '26761556',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:11:16',
#   'Submit': '2019-09-17T18:32:51',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '13b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-30\n'},
#  {'JobID': '26761558',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:05:38',
#   'Submit': '2019-09-17T18:33:00',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '14b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-31\n'},
#  {'JobID': '26761559',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:38:45',
#   'Submit': '2019-09-17T18:33:13',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '15b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-39\n'},
#  {'JobID': '26761565',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:16:57',
#   'Submit': '2019-09-17T18:33:22',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '16b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-41\n'},
#  {'JobID': '26761570',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:30:18',
#   'Submit': '2019-09-17T18:33:32',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '17b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-42\n'},
#  {'JobID': '26761572',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:35:09',
#   'Submit': '2019-09-17T18:33:44',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '18b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-43\n'},
#  {'JobID': '26761574',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:36:41',
#   'Submit': '2019-09-17T18:33:55',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '19b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-44\n'},
#  {'JobID': '26761579',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:10:59',
#   'Submit': '2019-09-17T18:34:12',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '20b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-45\n'},
#  {'JobID': '26761581',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:07:00',
#   'Submit': '2019-09-17T18:34:19',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '21b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-46\n'},
#  {'JobID': '26761583',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:14:41',
#   'Submit': '2019-09-17T18:34:26',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '22b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-12-49\n'},
#  {'JobID': '26761588',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T07:38:43',
#   'Submit': '2019-09-17T18:34:37',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '23b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-17\n'},
#  {'JobID': '26761591',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:11:16',
#   'Submit': '2019-09-17T18:34:47',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '24b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-18\n'},
#  {'JobID': '26761594',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:07:26',
#   'Submit': '2019-09-17T18:35:02',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '25b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-19\n'},
#  {'JobID': '26761598',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T04:44:17',
#   'Submit': '2019-09-17T18:35:12',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '26b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-20\n'},
#  {'JobID': '26761601',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:06:31',
#   'Submit': '2019-09-17T18:35:24',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '27b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-21\n'},
#  {'JobID': '26761602',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:16:39',
#   'Submit': '2019-09-17T18:35:34',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '28b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-22\n'},
#  {'JobID': '26761607',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:00:22',
#   'Submit': '2019-09-17T18:35:47',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '29b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-23\n'},
#  {'JobID': '26761609',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T04:58:38',
#   'Submit': '2019-09-17T18:35:59',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '30b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-24\n'},
#  {'JobID': '26761612',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T01:52:37',
#   'Submit': '2019-09-17T18:36:11',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '31b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-25\n'},
#  {'JobID': '26761617',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T04:44:38',
#   'Submit': '2019-09-17T18:36:21',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '32b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-26\n'},
#  {'JobID': '26761618',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:07:05',
#   'Submit': '2019-09-17T18:36:30',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '33b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-27\n'},
#  {'JobID': '26761622',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T01:56:35',
#   'Submit': '2019-09-17T18:36:40',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '34b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-29\n'},
#  {'JobID': '26761626',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:09:56',
#   'Submit': '2019-09-17T18:36:49',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '35b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-30\n'},
#  {'JobID': '26761632',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:10:10',
#   'Submit': '2019-09-17T18:36:59',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '36b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-31\n'},
#  {'JobID': '26761635',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:10:40',
#   'Submit': '2019-09-17T18:37:11',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '37b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-33\n'},
#  {'JobID': '26761636',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:13:26',
#   'Submit': '2019-09-17T18:37:21',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '38b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-34\n'},
#  {'JobID': '26761637',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:11:17',
#   'Submit': '2019-09-17T18:37:31',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '39b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-35\n'},
#  {'JobID': '26761642',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T04:53:44',
#   'Submit': '2019-09-17T18:37:44',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '40b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-37\n'},
#  {'JobID': '26761645',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T04:58:08',
#   'Submit': '2019-09-17T18:37:56',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '41b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-38\n'},
#  {'JobID': '26761646',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:13:14',
#   'Submit': '2019-09-17T18:38:07',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '42b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-50\n'},
#  {'JobID': '26761649',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:11:37',
#   'Submit': '2019-09-17T18:38:18',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '43b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-63\n'},
#  {'JobID': '26761650',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:06:54',
#   'Submit': '2019-09-17T18:38:28',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '44b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-65\n'},
#  {'JobID': '26761652',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:11:16',
#   'Submit': '2019-09-17T18:38:40',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '45b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-68\n'},
#  {'JobID': '26761655',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:13:00',
#   'Submit': '2019-09-17T18:38:50',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '46b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-69\n'},
#  {'JobID': '26761656',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T02:11:40',
#   'Submit': '2019-09-17T18:39:01',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '47b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-70\n'},
#  {'JobID': '26761657',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:11:13',
#   'Submit': '2019-09-17T18:39:13',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '48b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-71\n'},
#  {'JobID': '26761659',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T01:50:27',
#   'End': '2019-09-19T05:13:55',
#   'Submit': '2019-09-17T18:39:23',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '49b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-72\n'},
#  {'JobID': '26761662',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T08:05:29',
#   'Submit': '2019-09-17T18:39:36',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '50b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-02-31\n'},
#  {'JobID': '26761665',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:26:48',
#   'Submit': '2019-09-17T18:39:47',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '51b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-02-58\n'},
#  {'JobID': '26761666',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:27:48',
#   'Submit': '2019-09-17T18:39:57',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '52b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-28-43\n'},
#  {'JobID': '26761669',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:28:41',
#   'Submit': '2019-09-17T18:40:08',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '53b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-28-52\n'},
#  {'JobID': '26761670',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:30:31',
#   'Submit': '2019-09-17T18:40:18',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '54b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-27-18\n'},
#  {'JobID': '26761676',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:29:00',
#   'Submit': '2019-09-17T18:40:30',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '55b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-27-34\n'},
#  {'JobID': '26761678',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:31:52',
#   'Submit': '2019-09-17T18:40:40',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '56b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-27-52\n'},
#  {'JobID': '26761679',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:31:37',
#   'Submit': '2019-09-17T18:40:55',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '57b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-10-16\n'},
#  {'JobID': '26761683',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:32:36',
#   'Submit': '2019-09-17T18:41:01',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '58b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-10-24\n'},
#  {'JobID': '26761684',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:33:20',
#   'Submit': '2019-09-17T18:41:12',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '59b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-10-51\n'},
#  {'JobID': '26761686',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:36:36',
#   'Submit': '2019-09-17T18:41:23',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '60b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-10-68\n'},
#  {'JobID': '26761689',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:28:11',
#   'Submit': '2019-09-17T18:41:34',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '61b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-18\n'},
#  {'JobID': '26761692',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:28:38',
#   'Submit': '2019-09-17T18:41:43',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '62b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-25\n'},
#  {'JobID': '26761694',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:30:53',
#   'Submit': '2019-09-17T18:41:54',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '63b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-29\n'},
#  {'JobID': '26761697',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:25:49',
#   'Submit': '2019-09-17T18:42:03',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '64b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-68\n'},
#  {'JobID': '26761699',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:27:58',
#   'Submit': '2019-09-17T18:42:13',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '65b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-18-70\n'},
#  {'JobID': '26761700',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:36:26',
#   'Submit': '2019-09-17T18:42:22',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '66b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-14-14\n'},
#  {'JobID': '26761701',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:35:13',
#   'Submit': '2019-09-17T18:42:32',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '67b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-14-33\n'},
#  {'JobID': '26761704',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:33:01',
#   'Submit': '2019-09-17T18:42:41',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '68b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-14-35\n'},
#  {'JobID': '26761709',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T05:30:06',
#   'Submit': '2019-09-17T18:42:52',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '69b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-14-46\n'},
#  {'JobID': '26761710',
#   'User': 'llzhao',
#   'Account': 'mit168',
#   'Start': '2019-09-19T02:15:50',
#   'End': '2019-09-19T07:57:14',
#   'Submit': '2019-09-17T18:43:04',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '70b0.4LIPMF',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-14-47\n'},
#  {'JobID': '26761759',
#   'User': 'mholekev',
#   'Account': 'csd450',
#   'Start': '2019-09-19T01:36:26',
#   'End': '2019-09-19T01:36:29',
#   'Submit': '2019-09-17T18:47:10',
#   'Partition': 'compute',
#   'Timelimit': '1-00:00:00',
#   'JobName': 'CsCuBr3',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-19-45\n'},
#  {'JobID': '26762306',
#   'User': 'hpaudya1',
#   'Account': 'sbi116',
#   'Start': '2019-09-18T21:50:48',
#   'End': '2019-09-19T08:44:42',
#   'Submit': '2019-09-17T19:28:22',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': '1t6-epw',
#   'State': 'FAILED',
#   'NNodes': '24',
#   'ReqCPUS': '576',
#   'NodeList\n': 'comet-11-[01,03,19-22,25-26,36-37,63-64,66-68,70],comet-13-[22,24-25,27-28,30,34,36]\n'},
#  {'JobID': '26771036',
#   'User': 'qiyunzhu',
#   'Account': 'csd465',
#   'Start': '2019-09-19T00:43:19',
#   'End': '2019-09-19T00:43:21',
#   'Submit': '2019-09-18T01:29:09',
#   'Partition': 'compute',
#   'Timelimit': '1-00:00:00',
#   'JobName': 'p0064',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-27-59\n'},
#  {'JobID': '26771092',
#   'User': 'qiyunzhu',
#   'Account': 'csd465',
#   'Start': '2019-09-19T01:29:26',
#   'End': '2019-09-19T01:29:28',
#   'Submit': '2019-09-18T01:32:25',
#   'Partition': 'compute',
#   'Timelimit': '1-00:00:00',
#   'JobName': 'p0064',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-13-64\n'},
#  {'JobID': '26773149',
#   'User': 'fj62',
#   'Account': 'nwu151',
#   'Start': '2019-09-19T06:53:16',
#   'End': '2019-09-19T10:47:37',
#   'Submit': '2019-09-18T04:44:51',
#   'Partition': 'compute',
#   'Timelimit': '08:00:00',
#   'JobName': 'sr-na-cl',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-26-67\n'},
#  {'JobID': '26774282',
#   'User': 'hpaudya1',
#   'Account': 'sbi116',
#   'Start': '2019-09-19T04:29:46',
#   'End': '2019-09-19T20:33:35',
#   'Submit': '2019-09-18T06:22:00',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'td0-soc2',
#   'State': 'FAILED',
#   'NNodes': '24',
#   'ReqCPUS': '576',
#   'NodeList\n': 'comet-10-[59,65,67],comet-17-[60,66,72],comet-21-[16,57],comet-27-[15,21,25,30,35-38,40-41,43,45,47,55,62,69]\n'},
#  {'JobID': '26774783',
#   'User': 'dferg',
#   'Account': 'pen148',
#   'Start': '2019-09-19T01:29:26',
#   'End': '2019-09-19T01:29:30',
#   'Submit': '2019-09-18T07:12:26',
#   'Partition': 'compute',
#   'Timelimit': '1-00:00:00',
#   'JobName': 'precessing_comp',
#   'State': 'FAILED',
#   'NNodes': '5',
#   'ReqCPUS': '5',
#   'NodeList\n': 'comet-14-[12,15-16,20,25]\n'},
#  {'JobID': '26774791',
#   'User': 'rshen',
#   'Account': 'crl231',
#   'Start': '2019-09-19T05:19:52',
#   'End': '2019-09-19T08:36:21',
#   'Submit': '2019-09-18T07:14:20',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'namdph5new',
#   'State': 'FAILED',
#   'NNodes': '20',
#   'ReqCPUS': '480',
#   'NodeList\n': 'comet-17-[06,35-37],comet-18-[04-06,22,30-31,33-35,37-38,50,63,69,71-72]\n'},
#  {'JobID': '26775941',
#   'User': 'qadir',
#   'Account': 'mqt102',
#   'Start': '2019-09-19T03:13:31',
#   'End': '2019-09-19T03:13:34',
#   'Submit': '2019-09-18T08:40:09',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'l.log',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-16-33\n'},
#  {'JobID': '26775942',
#   'User': 'qadir',
#   'Account': 'mqt102',
#   'Start': '2019-09-19T03:13:31',
#   'End': '2019-09-19T03:13:34',
#   'Submit': '2019-09-18T08:40:09',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'll.log',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-18-39\n'},
#  {'JobID': '26776118',
#   'User': 'lapsheva',
#   'Account': 'upa122',
#   'Start': '2019-09-18T08:42:57',
#   'End': '2019-09-19T09:19:08',
#   'Submit': '2019-09-18T08:42:55',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'tbu',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '16',
#   'NodeList\n': 'comet-06-35\n'},
#  {'JobID': '26776361',
#   'User': 'mrotella',
#   'Account': 'mda125',
#   'Start': '2019-09-18T08:51:00',
#   'End': '2019-09-19T03:55:23',
#   'Submit': '2019-09-18T08:50:38',
#   'Partition': 'shared',
#   'Timelimit': '20:00:00',
#   'JobName': 'Lee_MCBD_2_TS_3_Me_Ph_NoMod_Ph_modred_NoMod',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '16',
#   'NodeList\n': 'comet-02-06\n'},
#  {'JobID': '26776572',
#   'User': 'tj257',
#   'Account': 'how104',
#   'Start': '2019-09-19T03:44:45',
#   'End': '2019-09-19T03:44:55',
#   'Submit': '2019-09-18T09:07:12',
#   'Partition': 'compute',
#   'Timelimit': '08:30:00',
#   'JobName': 'bulk-200atm-q0',
#   'State': 'FAILED',
#   'NNodes': '6',
#   'ReqCPUS': '144',
#   'NodeList\n': 'comet-23-[33-35,46,50,54]\n'},
#  {'JobID': '26776962',
#   'User': 'niloo',
#   'Account': 'mqt102',
#   'Start': '2019-09-18T09:31:02',
#   'End': '2019-09-19T16:29:20',
#   'Submit': '2019-09-18T09:30:55',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'g_TSA-thiolate-pcm-5waters.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-04-10\n'},
#  {'JobID': '26776982',
#   'User': 'niloo',
#   'Account': 'mqt102',
#   'Start': '2019-09-18T09:33:21',
#   'End': '2019-09-19T07:01:02',
#   'Submit': '2019-09-18T09:33:20',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'g_TSA-acetate-pcm-5waters.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-06-11\n'},
#  {'JobID': '26777011',
#   'User': 'niloo',
#   'Account': 'mqt102',
#   'Start': '2019-09-18T09:36:11',
#   'End': '2019-09-19T11:19:42',
#   'Submit': '2019-09-18T09:36:09',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'g_TSA-hyb5v2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-03-22\n'},
#  {'JobID': '26777162',
#   'User': 'yz393',
#   'Account': 'csd497',
#   'Start': '2019-09-18T09:52:22',
#   'End': '2019-09-19T01:28:23',
#   'Submit': '2019-09-18T09:52:15',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'b-e-e',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '12',
#   'NodeList\n': 'comet-06-60\n'},
#  {'JobID': '26777170',
#   'User': 'yz393',
#   'Account': 'csd497',
#   'Start': '2019-09-18T09:54:39',
#   'End': '2019-09-19T05:26:48',
#   'Submit': '2019-09-18T09:54:35',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'f-f',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '12',
#   'NodeList\n': 'comet-07-55\n'},
#  {'JobID': '26777174',
#   'User': 'yz393',
#   'Account': 'csd497',
#   'Start': '2019-09-18T09:55:55',
#   'End': '2019-09-19T01:06:08',
#   'Submit': '2019-09-18T09:55:54',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'b-f-f',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '12',
#   'NodeList\n': 'comet-06-13\n'},
#  {'JobID': '26777418',
#   'User': 'yxj135',
#   'Account': 'pen146',
#   'Start': '2019-09-19T06:14:13',
#   'End': '2019-09-19T15:40:32',
#   'Submit': '2019-09-18T10:20:48',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'read_v3.6_a0.010',
#   'State': 'FAILED',
#   'NNodes': '40',
#   'ReqCPUS': '600',
#   'NodeList\n': 'comet-02-[08,13,53],comet-10-[08,16,20,24-25,32,34-35,51],comet-14-[14,33,35,46],comet-16-[36,54-55,60,67-68,71],comet-17-[38,51,59],comet-19-[04,08-09,11-12,16,25,44,58,63,65],comet-26-[16,29,66]\n'},
#  {'JobID': '26777797',
#   'User': 'andrewk',
#   'Account': 'csd467',
#   'Start': '2019-09-18T11:50:21',
#   'End': '2019-09-19T11:31:56',
#   'Submit': '2019-09-18T10:53:45',
#   'Partition': 'gpu-shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'E_PDTSTPD',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '14',
#   'NodeList\n': 'comet-33-07\n'},
#  {'JobID': '26777992',
#   'User': 'niloo',
#   'Account': 'mqt102',
#   'Start': '2019-09-18T11:12:03',
#   'End': '2019-09-19T07:14:27',
#   'Submit': '2019-09-18T11:11:57',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'g_NMR-TSA-thiolate-pcm-5waters.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-03-22\n'},
#  {'JobID': '26778729',
#   'User': 'kovacevt',
#   'Account': 'uoc108',
#   'Start': '2019-09-19T12:03:55',
#   'End': '2019-09-19T12:03:57',
#   'Submit': '2019-09-18T12:08:26',
#   'Partition': 'compute',
#   'Timelimit': '13:00:00',
#   'JobName': 'p125_f17',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-28-21\n'},
#  {'JobID': '26778730',
#   'User': 'kovacevt',
#   'Account': 'uoc108',
#   'Start': '2019-09-19T12:03:55',
#   'End': '2019-09-19T12:03:57',
#   'Submit': '2019-09-18T12:08:27',
#   'Partition': 'compute',
#   'Timelimit': '13:00:00',
#   'JobName': 'p135_f17',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-26-36\n'},
#  {'JobID': '26778731',
#   'User': 'kovacevt',
#   'Account': 'uoc108',
#   'Start': '2019-09-19T12:03:55',
#   'End': '2019-09-19T12:03:57',
#   'Submit': '2019-09-18T12:08:27',
#   'Partition': 'compute',
#   'Timelimit': '13:00:00',
#   'JobName': 'p145_f17',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-26-38\n'},
#  {'JobID': '26778792',
#   'User': 'taoyu',
#   'Account': 'uic355',
#   'Start': '2019-09-18T16:42:59',
#   'End': '2019-09-19T00:11:39',
#   'Submit': '2019-09-18T12:15:24',
#   'Partition': 'compute',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'gauss',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '16',
#   'NodeList\n': 'comet-04-51\n'},
#  {'JobID': '26779058',
#   'User': 'yz393',
#   'Account': 'csd497',
#   'Start': '2019-09-18T12:34:23',
#   'End': '2019-09-19T09:47:12',
#   'Submit': '2019-09-18T12:34:22',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': '4_e07',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '12',
#   'NodeList\n': 'comet-06-09\n'},
#  {'JobID': '26779182',
#   'User': 'qiyunzhu',
#   'Account': 'csd465',
#   'Start': '2019-09-19T23:37:20',
#   'End': '2019-09-19T23:37:21',
#   'Submit': '2019-09-18T12:43:51',
#   'Partition': 'large-shared',
#   'Timelimit': '04:00:00',
#   'JobName': 'iq.nocpr.rand',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '32',
#   'NodeList\n': 'comet-30-01\n'},
#  {'JobID': '26779185',
#   'User': 'qiyunzhu',
#   'Account': 'csd465',
#   'Start': '2019-09-19T23:37:20',
#   'End': '2019-09-19T23:37:21',
#   'Submit': '2019-09-18T12:44:18',
#   'Partition': 'large-shared',
#   'Timelimit': '04:00:00',
#   'JobName': 'iq.nocpr.cons',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '32',
#   'NodeList\n': 'comet-31-02\n'},
#  {'JobID': '26779219',
#   'User': 'kovacevt',
#   'Account': 'uoc108',
#   'Start': '2019-09-19T12:28:59',
#   'End': '2019-09-19T12:29:03',
#   'Submit': '2019-09-18T12:46:42',
#   'Partition': 'compute',
#   'Timelimit': '13:00:00',
#   'JobName': 'us0_f17',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-26-55\n'},
#  {'JobID': '26779428',
#   'User': 'agnanase',
#   'Account': 'csd616',
#   'Start': '2019-09-19T01:29:26',
#   'End': '2019-09-19T01:29:28',
#   'Submit': '2019-09-18T13:04:29',
#   'Partition': 'compute',
#   'Timelimit': '17:00:00',
#   'JobName': 'HNSCbamtofastq1',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-28-60\n'},
#  {'JobID': '26779429',
#   'User': 'agnanase',
#   'Account': 'csd616',
#   'Start': '2019-09-19T01:29:26',
#   'End': '2019-09-19T01:29:28',
#   'Submit': '2019-09-18T13:04:34',
#   'Partition': 'compute',
#   'Timelimit': '17:00:00',
#   'JobName': 'HNSCbamtofastq2',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-28-61\n'},
#  {'JobID': '26779431',
#   'User': 'agnanase',
#   'Account': 'csd616',
#   'Start': '2019-09-19T01:29:26',
#   'End': '2019-09-19T01:29:29',
#   'Submit': '2019-09-18T13:04:37',
#   'Partition': 'compute',
#   'Timelimit': '17:00:00',
#   'JobName': 'HNSCbamtofastq3',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-28-62\n'},
#  {'JobID': '26779433',
#   'User': 'agnanase',
#   'Account': 'csd616',
#   'Start': '2019-09-19T01:29:26',
#   'End': '2019-09-19T01:29:28',
#   'Submit': '2019-09-18T13:04:39',
#   'Partition': 'compute',
#   'Timelimit': '17:00:00',
#   'JobName': 'HNSCbamtofastq4',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-14-29\n'},
#  {'JobID': '26779434',
#   'User': 'agnanase',
#   'Account': 'csd616',
#   'Start': '2019-09-19T01:29:26',
#   'End': '2019-09-19T01:29:29',
#   'Submit': '2019-09-18T13:04:42',
#   'Partition': 'compute',
#   'Timelimit': '17:00:00',
#   'JobName': 'HNSCbamtofastq5',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '24',
#   'NodeList\n': 'comet-14-31\n'},
#  {'JobID': '26779531',
#   'User': 'rkarugu1',
#   'Account': 'mis119',
#   'Start': '2019-09-18T13:19:05',
#   'End': '2019-09-19T09:17:50',
#   'Submit': '2019-09-18T13:16:27',
#   'Partition': 'shared',
#   'Timelimit': '1-00:00:00',
#   'JobName': 'aldol2c-2',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '16',
#   'NodeList\n': 'comet-08-28\n'},
#  {'JobID': '26779703',
#   'User': 'tsuik',
#   'Account': 'ucd114',
#   'Start': '2019-09-18T13:32:29',
#   'End': '2019-09-19T06:28:11',
#   'Submit': '2019-09-18T13:32:22',
#   'Partition': 'shared',
#   'Timelimit': '1-00:00:00',
#   'JobName': 'contsmallerscandihesigmaconf10stereotestsplitcharge02XU9.job',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '8',
#   'NodeList\n': 'comet-06-06\n'},
#  {'JobID': '26779946',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:55:48',
#   'End': '2019-09-19T04:32:52',
#   'Submit': '2019-09-18T13:55:46',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00007_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-04-46\n'},
#  {'JobID': '26779948',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:55:55',
#   'End': '2019-09-19T16:10:55',
#   'Submit': '2019-09-18T13:55:50',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00011_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-07\n'},
#  {'JobID': '26779949',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:55:55',
#   'End': '2019-09-19T08:58:33',
#   'Submit': '2019-09-18T13:55:53',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00026_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-12\n'},
#  {'JobID': '26779950',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:01',
#   'End': '2019-09-19T03:09:56',
#   'Submit': '2019-09-18T13:55:55',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00032_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-04-02\n'},
#  {'JobID': '26779951',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:01',
#   'End': '2019-09-19T02:50:56',
#   'Submit': '2019-09-18T13:55:58',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00037_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-13\n'},
#  {'JobID': '26779953',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:06',
#   'End': '2019-09-19T06:54:44',
#   'Submit': '2019-09-18T13:56:03',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00049_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-23\n'},
#  {'JobID': '26779954',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:06',
#   'End': '2019-09-19T01:51:35',
#   'Submit': '2019-09-18T13:56:05',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00050_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-23\n'},
#  {'JobID': '26779956',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:11',
#   'End': '2019-09-19T13:00:38',
#   'Submit': '2019-09-18T13:56:10',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00056_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-27\n'},
#  {'JobID': '26779957',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:13',
#   'End': '2019-09-19T19:27:14',
#   'Submit': '2019-09-18T13:56:12',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00059_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-27\n'},
#  {'JobID': '26779958',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:19',
#   'End': '2019-09-19T12:30:13',
#   'Submit': '2019-09-18T13:56:14',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00064_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-02-05\n'},
#  {'JobID': '26779961',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:25',
#   'End': '2019-09-19T03:19:15',
#   'Submit': '2019-09-18T13:56:24',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00071_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-38\n'},
#  {'JobID': '26779962',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:33',
#   'End': '2019-09-19T02:18:14',
#   'Submit': '2019-09-18T13:56:26',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00072_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-04-11\n'},
#  {'JobID': '26779963',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:33',
#   'End': '2019-09-19T08:59:32',
#   'Submit': '2019-09-18T13:56:29',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00073_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-04-29\n'},
#  {'JobID': '26779964',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:33',
#   'End': '2019-09-19T15:34:24',
#   'Submit': '2019-09-18T13:56:31',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00111_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-38\n'},
#  {'JobID': '26779965',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:42',
#   'End': '2019-09-19T14:35:14',
#   'Submit': '2019-09-18T13:56:34',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00118_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-04-65\n'},
#  {'JobID': '26779967',
#   'User': 'cruzeiro',
#   'Account': 'slc103',
#   'Start': '2019-09-18T13:56:42',
#   'End': '2019-09-19T07:38:59',
#   'Submit': '2019-09-18T13:56:38',
#   'Partition': 'shared',
#   'Timelimit': '2-00:00:00',
#   'JobName': 'struc00129_td2.com',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '4',
#   'NodeList\n': 'comet-08-39\n'},
#  {'JobID': '26779968',
# ...
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-04\n'},
#  {'JobID': '26795186',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:16',
#   'End': '2019-09-19T08:29:18',
#   'Submit': '2019-09-19T08:29:11',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-06\n'},
#  {'JobID': '26795187',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:16',
#   'End': '2019-09-19T08:29:18',
#   'Submit': '2019-09-19T08:29:12',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-07\n'},
#  {'JobID': '26795188',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:16',
#   'End': '2019-09-19T08:29:18',
#   'Submit': '2019-09-19T08:29:12',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-07\n'},
#  {'JobID': '26795189',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:16',
#   'End': '2019-09-19T08:29:18',
#   'Submit': '2019-09-19T08:29:13',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-08\n'},
#  {'JobID': '26795190',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:16',
#   'End': '2019-09-19T08:29:18',
#   'Submit': '2019-09-19T08:29:13',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-10\n'},
#  {'JobID': '26795191',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:16',
#   'End': '2019-09-19T08:29:18',
#   'Submit': '2019-09-19T08:29:14',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-12\n'},
#  {'JobID': '26795192',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:16',
#   'End': '2019-09-19T08:29:18',
#   'Submit': '2019-09-19T08:29:15',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-12\n'},
#  {'JobID': '26795193',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:16',
#   'End': '2019-09-19T08:29:18',
#   'Submit': '2019-09-19T08:29:15',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-14\n'},
#  {'JobID': '26795194',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:16',
#   'End': '2019-09-19T08:29:18',
#   'Submit': '2019-09-19T08:29:16',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-16\n'},
#  {'JobID': '26795195',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:16',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-27\n'},
#  {'JobID': '26795196',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:17',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-28\n'},
#  {'JobID': '26795197',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:18',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-31\n'},
#  {'JobID': '26795198',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:30',
#   'Submit': '2019-09-19T08:29:18',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-34\n'},
#  {'JobID': '26795199',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:19',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-34\n'},
#  {'JobID': '26795200',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:19',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-02\n'},
#  {'JobID': '26795201',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:20',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-04\n'},
#  {'JobID': '26795202',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:30',
#   'Submit': '2019-09-19T08:29:21',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-04\n'},
#  {'JobID': '26795203',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:21',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-06\n'},
#  {'JobID': '26795204',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:22',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-07\n'},
#  {'JobID': '26795205',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:30',
#   'Submit': '2019-09-19T08:29:22',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-07\n'},
#  {'JobID': '26795206',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:23',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-08\n'},
#  {'JobID': '26795207',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:23',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-10\n'},
#  {'JobID': '26795208',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:24',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-12\n'},
#  {'JobID': '26795209',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:30',
#   'Submit': '2019-09-19T08:29:25',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-12\n'},
#  {'JobID': '26795210',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:25',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-14\n'},
#  {'JobID': '26795211',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:26',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-16\n'},
#  {'JobID': '26795212',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:26',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-40\n'},
#  {'JobID': '26795213',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:27',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-42\n'},
#  {'JobID': '26795214',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:27',
#   'End': '2019-09-19T08:29:29',
#   'Submit': '2019-09-19T08:29:27',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-53\n'},
#  {'JobID': '26795215',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:38',
#   'Submit': '2019-09-19T08:29:28',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-27\n'},
#  {'JobID': '26795216',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:38',
#   'Submit': '2019-09-19T08:29:28',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-28\n'},
#  {'JobID': '26795217',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:29',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-31\n'},
#  {'JobID': '26795218',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:30',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-34\n'},
#  {'JobID': '26795219',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:40',
#   'Submit': '2019-09-19T08:29:31',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-34\n'},
#  {'JobID': '26795220',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:31',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-02\n'},
#  {'JobID': '26795221',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:32',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-04\n'},
#  {'JobID': '26795222',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:32',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-04\n'},
#  {'JobID': '26795223',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:33',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-06\n'},
#  {'JobID': '26795224',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:34',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-07\n'},
#  {'JobID': '26795225',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:34',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-07\n'},
#  {'JobID': '26795226',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:35',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-08\n'},
#  {'JobID': '26795227',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:35',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-10\n'},
#  {'JobID': '26795228',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:40',
#   'Submit': '2019-09-19T08:29:36',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-12\n'},
#  {'JobID': '26795229',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:39',
#   'Submit': '2019-09-19T08:29:36',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-12\n'},
#  {'JobID': '26795230',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:37',
#   'End': '2019-09-19T08:29:38',
#   'Submit': '2019-09-19T08:29:37',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-04-14\n'},
#  {'JobID': '26795231',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:45',
#   'End': '2019-09-19T08:29:47',
#   'Submit': '2019-09-19T08:29:37',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-27\n'},
#  {'JobID': '26795232',
#   'User': 'xyao',
#   'Account': 'jan100',
#   'Start': '2019-09-19T08:29:45',
#   'End': '2019-09-19T08:29:47',
#   'Submit': '2019-09-19T08:29:38',
#   'Partition': 'shared',
#   'Timelimit': '23:00:00',
#   'JobName': 'GDC2Cloud.KIRC',
#   'State': 'FAILED',
#   'NNodes': '1',
#   'ReqCPUS': '2',
#   'NodeList\n': 'comet-01-28\n'},
#  ...]

# %%
len(chunky_list)
# Out:
# 22608

# %%
sample = chunky_list[0]['NodeList\n']
'\n' in sample
# Out:
# True

# %%
sample[:-1]
# Out:
# 'comet-10-36'

# %% [markdown]
# ### Previous host processing

# %%
job_host_pairs_a = []
job_host_pairs_b = []

for i in range(len(arc_hosts)):
    avail_hosts = list(arc_hosts[i].keys())
    
    for j in range( len( avail_hosts ) ):
        host_i_name = avail_hosts[j]
        timely_list = arc_hosts[i][ host_i_name ][ "Timely Data" ]
        
        for k in range( len( timely_list ) ):
            try_job_info = arc_hosts[i][ host_i_name ][ timely_list[k][4] ][ "Job" ]
            
            # check each tup in timely_data list for a jobid
            if len( timely_list[k] ) > 5:
                save_tup = ( host_i_name,timely_list[j][5] )
                if save_tup not in job_host_pairs_a:
                    job_host_pairs_a.append( save_tup )
                
            if type(try_job_info) is dict and "Jobid" in try_job_info:
                save_tup = ( host_i_name,try_job_info[ "Jobid" ] )
                if save_tup not in job_host_pairs_b:
                    job_host_pairs_b.append( save_tup )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-de9f9489f345> in <module>
#       2 job_host_pairs_b = []
#       3
# ----> 4 for i in range(len(arc_hosts)):
#       5     avail_hosts = list(arc_hosts[i].keys())
#       6
#
# NameError: name 'arc_hosts' is not defined

# %%
len(job_host_pairs_a)

# %%
len(job_host_pairs_b)

# %%
timely_list

# %% [markdown]
# ### View

# %%
arc_hosts[0]['comet-10-14']["Timely Data"]
