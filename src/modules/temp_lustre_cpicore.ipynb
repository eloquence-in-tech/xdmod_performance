# %%
# File dependencies
from os import listdir

# %%
import pickle

# %%
# Data manipulation dependencies
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from collections import OrderedDict

# %%
# Directory of all pickled jobs via comet
source_dir = '../data/raw/'
save_dir_jpg = '../data/cpicore/images'

# List of date directories in source_dir
slice_files = listdir( source_dir )

# %%
cpiset_out = '../data/summary_stats/cpicore/cpicore_set.pkl'

# %%
len(slice_files)
# Out:
# 5398

# %% [markdown]
# # Setup

# %%
def check_len ( df, num ):
    return len(df.columns.values.tolist()) > num

def purge_str ( df ):
    for row,col in df.iterrows():
        for i in range(len(col.values)):
            val = col.values[i]
            time = col.index[i]
            
            # certain numeric responses are recorded as str
            if type(val) is str:
                try:
                    df.at[row,time] = np.float64( val )
                except:
                    df.at[row,time] = np.float64(0)
                else:
                    df.at[row,time] = np.float64(0)
                    
    return df
    
def get_host_id ( file_name ):
    host,jobid = file_name.split('_')
    return host[:11] , jobid[:7]

def get_dfs ( file_list, min_jobs, min_cycles=0 ):
    job_dfs = {}
    count = 0
    
    for i in range( len(file_list) ):
        
        if count < min_jobs:
            job_file = file_list[i]
            df = purge_str( pd.read_csv( source_dir+job_file, index_col=[0,1,2], low_memory=False ) )
            host,jobid = get_host_id( job_file )
        
            if check_len( df, min_cycles ):
                job_dfs[jobid] = {}
                job_dfs[jobid][host] = df
            else:
                next
            
            count += 1
            
    return job_dfs
        
def sort_hosts ( file_list ):
    hosts = {}
    
    for job_file in file_list:
        host,jobid = job_file.split('_')
        
        if host in hosts:
            hosts[host].append( jobid[:7] )
        else:
            hosts[host] = [ jobid[:7] ]
            
    return hosts
            
def sort_jobs ( file_list, job_dfs ):
    jobs = {}
    
    for job_file in file_list:
        host,jobid = get_id( job_file )
        
        if jobid in job_dfs.keys():
            if jobid in jobs:
                jobs[jobid].append( host )
            else:
                jobs[jobid] = [ host ]
            
    return jobs, multiple_hosts(jobs)

def multiple_hosts ( jobs_dict ):
    return any( len(host) > 1 for job,host in jobs_dict.items() )

# %%
def cpicore_simple ( job_df, monitor=False ):
    data = job_df.loc['intel_hsw']
    times = job_df.columns.tolist()
    cpicore_list = []
    
    for i in range(1, len(times)):
        chunk = data[times[:i+1]]
        devices = { row : np.mean(col.values) for row,col in chunk.iterrows() }
        avg_c = { key[0]:0 for key,val in devices.items() }
        sum_avgs = 0
        
        for key,val in avg_c.items():
            avg_c[ key ] = devices[ (key, 'CLOCKS_UNHALTED_CORE') ] / devices[ (key, 'INSTRUCTIONS_RETIRED') ]
    
        for key,val in avg_c.items():
            sum_avgs += val
            
        cpicore_list.append(sum_avgs/24)
    
    if monitor:
        return cpicore_list
    
    return sum_avgs/24

def cpicore ( job_df, monitor=False ):
    data = job_df.loc['intel_hsw']
    times = job_df.columns.tolist()
    cpicore_dict = OrderedDict( )
    
    for t in times:
        cpicore_dict[t] = 0
    
    for i in range(1, len(times)):
        chunk = data[times[:i+1]]
        devices = { row : np.mean(col.values) for row,col in chunk.iterrows() }
        avg_c = { key[0]:0 for key,val in devices.items() }
        sum_avgs = 0
        current = times[i]
        
        for key,val in avg_c.items():
            avg_c[ key ] = devices[ (key, 'CLOCKS_UNHALTED_CORE') ] / devices[ (key, 'INSTRUCTIONS_RETIRED') ]
    
        for key,val in avg_c.items():
            sum_avgs += val
            
        cpicore_dict[current] = sum_avgs/24
    
    if monitor:
        return cpicore_dict
    
    return sum_avgs/24

def cpiref ( devices_dict ):
    avg_d = { key[0]:0 for key,val in devices_dict.items() }
    sum_avgs = 0
    
    for key,val in avg_d.items():
        avg_d[ key ] = devices_dict[ (key, 'CLOCKS_UNHALTED_REF') ] / devices_dict[ (key, 'INSTRUCTIONS_RETIRED') ]
        
    for key,val in avg_d.items():
        sum_avgs += val
        
    return sum_avgs/24

# %%
#def find_notable( cpi_set ):
#    notable = []
#    
#    for jobid,data_dict in cpi_set.items():
#        vals = [ val for val in data_dict.values()[1:] ]
#        
#        if not all():
#            notable.append( jobid )

def get_stats( cpi_set, outliers=False ):
    data = []
    outliers = []
    
    for jobid,cpi_dict in cpicore_set.items():
        for val in cpi_dict.values():
            if (val > 0):
                data.append(np.float64(val))
            else:
                outliers.append(val)   
                
    stats = {
        'Max' : max(data),
        'Min' : min(data),
        'Mean' : np.mean(data),
        'Std. Dev' : np.std(data),
        'Count' : len(data),
        'Excluded' : len(outliers)
    }
    
    if outliers:
        return stats,outliers
    
    return stats

# %% [markdown]
# # Pull Data

# %%
job_dfs = get_dfs( slice_files, len(slice_files), 6 )

# %%
jobids = job_dfs.keys()
len(jobids)
# Out:
# 607

# %% [markdown]
# # Compiling CPICORE

# %%
cpicore_set = {}

for jobid in job_dfs.keys():
    for host in job_dfs[jobid].keys():
        cpicore_set[jobid] = {}
        cpicore_set[jobid][host] = cpicore_simple( job_dfs[jobid][host], monitor=True )

# %%
out_file = open(cpiset_out, 'wb')
pickle.dump(cpicore_set, out_file)
check_cpicore_set = pickle.load(open(cpiset_out, 'rb'))

check = check_cpicore_set.keys()
orig = cpicore_set.keys()
for key in check:
    if key not in orig:
        print key
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-14-83bc2027816f> in <module>()
#       1 out_file = open(cpiset_out, 'wb')
#       2 pickle.dump(cpicore_set, out_file)
# ----> 3 check_cpicore_set = pickle.load(open(cpiset_out, 'rb'))
#       4
#       5 check = check_cpicore_set.keys()
#
# /usr/lib/python2.7/pickle.pyc in load(file)
#    1382
#    1383 def load(file):
# -> 1384     return Unpickler(file).load()
#    1385
#    1386 def loads(str):
#
# /usr/lib/python2.7/pickle.pyc in load(self)
#     862             while 1:
#     863                 key = read(1)
# --> 864                 dispatch[key](self)
#     865         except _Stop, stopinst:
#     866             return stopinst.value
#
# /usr/lib/python2.7/pickle.pyc in load_eof(self)
#     884
#     885     def load_eof(self):
# --> 886         raise EOFError
#     887     dispatch[''] = load_eof
#     888
#
# EOFError:

# %%
multiples = []

for job_id in cpicore_set.items():
    if len(job_id[1].keys()) > 1:
        multiples.append()
        print(job_id[0])
        print(job_id[1].keys())
    else:
        next

# %% [markdown]
# ## Can cpicore be accurately predicted at t_1?

# %%
overview = {}
total = 0
count = 0

for job_tup in cpicore_set.items():
    for host_name,cpi_list in job_tup[1].items():
        final = cpi_list[-1]
        t1 = cpi_list[0]                                          # Note: t1 is intentionally placed at i=0 here
        label = (job_tup[0], host_name)
        std_dev = np.std(cpi_list)
        error = ( final / t1 )
        total += 1
        
        if error > 0.99:
            count += 1
        
        overview[label] = {
            "Standard Deviation" : std_dev,
            "t1 Accuracy" : error,
            "Cycles" : len(cpi_list),
            "Final" : final,
            "Data" : cpi_list
        }

        print "---------------------------------------------------------------------------------------------------------------------"
        print "Job:\t\t", label
        print "---------------------------------------------------------------------------------------------------------------------"
        print "Final cpicore:\t\t{:.3}".format(final)
        print "Length of Job:\t\t", len(cpi_list)
        print "Standard Deviation:\t{:.3}".format(std_dev)
        print "t1 Accuracy:\t\t{:.1%}".format(error)
        print "Data:"
        print
        print cpi_list
        print
# Out:
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715660', 'comet-02-24')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.89
# Length of Job:		2
# Standard Deviation:	0.00496
# t1 Accuracy:		99.5%
# Data:
#
# [1.9011233513040293, 1.8912020352105332]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4704908', 'comet-05-36')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.43
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.4273341440582885]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4705003', 'comet-07-11')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.55
# Length of Job:		2
# Standard Deviation:	0.00127
# t1 Accuracy:		99.8%
# Data:
#
# [1.5514301835127318, 1.5488989902720383]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4721008', 'comet-04-08')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3.65
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [3.6475827023315914]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4704160', 'comet-07-54')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.96
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.9576608148705743]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4680301', 'comet-12-33')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.54
# Length of Job:		8
# Standard Deviation:	0.0474
# t1 Accuracy:		94.5%
# Data:
#
# [2.683745395398276, 2.6536896897043754, 2.627960496977765, 2.605265937340238, 2.5855925324053435, 2.568754755347618, 2.553844820367104, 2.536829206191461]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4680307', 'comet-21-13')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.55
# Length of Job:		8
# Standard Deviation:	0.0716
# t1 Accuracy:		92.0%
# Data:
#
# [2.7749924613823858, 2.724637420648714, 2.6834857640341503, 2.6493391339670262, 2.621183595019916, 2.597256535144195, 2.5762043085295177, 2.551779812437855]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4680304', 'comet-14-72')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.52
# Length of Job:		9
# Standard Deviation:	0.0496
# t1 Accuracy:		94.2%
# Data:
#
# [2.6808293194740576, 2.6607511337420693, 2.638480196880564, 2.6179422412817277, 2.5993477524707767, 2.5827154900312466, 2.568489386946232, 2.543788401405677, 2.524461190418244]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4710618', 'comet-04-52')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.65
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.6543530277612302]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4728383', 'comet-04-11')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3.33
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [3.3259627663329563]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715067', 'comet-07-11')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.56
# Length of Job:		2
# Standard Deviation:	0.00269
# t1 Accuracy:		99.7%
# Data:
#
# [1.5669297542366885, 1.5615584521297305]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4721174', 'comet-02-01')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.07
# Length of Job:		5
# Standard Deviation:	0.023
# t1 Accuracy:		97.1%
# Data:
#
# [2.1350689270637258, 2.077089414862482, 2.086930531459082, 2.077346518538413, 2.0735885224562787]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4729492', 'comet-04-08')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3.4
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [3.39713787398184]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4713373', 'comet-10-31')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.54
# Length of Job:		2
# Standard Deviation:	0.00435
# t1 Accuracy:		100.6%
# Data:
#
# [1.5278622465769442, 1.5365636781960144]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4697632', 'comet-02-05')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.52
# Length of Job:		5
# Standard Deviation:	0.0116
# t1 Accuracy:		98.8%
# Data:
#
# [2.5504389883881395, 2.5420153800985577, 2.5274197796347133, 2.5220747612748067, 2.5210633695202658]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4708645', 'comet-07-54')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.72
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.7167790255154298]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4705169', 'comet-07-48')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.21
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.2084800596397796]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715488', 'comet-06-20')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.18
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.1811261512856848]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715489', 'comet-06-21')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.18
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.1812012037640494]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4722479', 'comet-06-05')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.13
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.1260155346029546]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715484', 'comet-06-08')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.37
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.370489570141769]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715485', 'comet-06-10')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.23
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.231089745505046]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715486', 'comet-06-16')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.1
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.0985579232302545]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4709657', 'comet-10-63')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.86
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.8561732326780134]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4705167', 'comet-07-29')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.2
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.2040583271779517]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715483', 'comet-06-06')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.89
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.8873675064548205]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4680276', 'comet-12-33')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.59
# Length of Job:		2
# Standard Deviation:	0.00679
# t1 Accuracy:		100.5%
# Data:
#
# [2.5743964456563346, 2.5879683406675]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4710532', 'comet-07-41')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3.34
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [3.3385140553481993]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4707925', 'comet-08-06')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.63
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.6330275785241566]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715249', 'comet-05-36')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.31
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.314196388772648]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715245', 'comet-05-30')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.64
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.636193018983703]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715241', 'comet-10-27')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.88
# Length of Job:		2
# Standard Deviation:	0.00283
# t1 Accuracy:		99.8%
# Data:
#
# [2.882329326955837, 2.876671888032586]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4712757', 'comet-06-21')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.69
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.6893628857649332]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4720977', 'comet-22-24')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.72
# Length of Job:		9
# Standard Deviation:	0.0669
# t1 Accuracy:		88.8%
# Data:
#
# [1.9400835359482793, 1.8579601782742392, 1.8118501046212991, 1.7837403014791813, 1.7646098146449585, 1.7509136205888505, 1.7401928275958436, 1.7306505462809094, 1.7233976221502016]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4704431', 'comet-07-24')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.08
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.080220609068816]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4711007', 'comet-07-41')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.11
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.1115722615064865]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4703007', 'comet-07-11')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.56
# Length of Job:		2
# Standard Deviation:	0.000776
# t1 Accuracy:		99.9%
# Data:
#
# [1.5571368124978957, 1.5555847319520357]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4712596', 'comet-06-05')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.83
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.8262212015427959]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4712594', 'comet-06-16')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.03
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.034950814215284]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4712591', 'comet-06-24')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.25
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.248282352962955]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4715398', 'comet-05-30')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.68
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.6815516969415025]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4721394', 'comet-10-63')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.51
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.5081516685908853]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4729389', 'comet-10-46')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.81
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.8138453165572666]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4703008', 'comet-07-24')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.87
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.8692539140439626]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4678353', 'comet-02-01')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.47
# Length of Job:		23
# Standard Deviation:	0.156
# t1 Accuracy:		84.4%
# Data:
#
# [2.9315492378590977, 2.8659297170145517, 2.869073361831612, 2.883289121449893, 2.8914777412210544, 2.896191634258298, 2.9005560433541646, 2.9061538730474616, 2.9095116506610257, 2.9065407314224854, 2.9052335869465638, 2.9050651473797173, 2.8604291143334226, 2.800268118506984, 2.7447903805177236, 2.695942663739776, 2.6542072737400955, 2.6147361366474793, 2.580333080462576, 2.550283105897244, 2.518681106394787, 2.4941853829909766, 2.4748928216315167]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4718522', 'comet-21-70')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		30.6
# Length of Job:		12
# Standard Deviation:	0.243
# t1 Accuracy:		102.4%
# Data:
#
# [29.854750880912974, 30.41204341335667, 30.782370337972896, 30.831974556536853, 30.762139394371644, 30.689906621645903, 30.632601694363817, 30.58653734955836, 30.56486587311227, 30.562127090516196, 30.5667826717244, 30.57388955872469]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4722589', 'comet-02-05')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.42
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.4174529028631118]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4704588', 'comet-07-13')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.06
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.058730169012081]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4714537', 'comet-05-68')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.02
# Length of Job:		3
# Standard Deviation:	0.00372
# t1 Accuracy:		100.4%
# Data:
#
# [2.0139018971061744, 2.022103271477653, 2.021424155425436]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4705501', 'comet-04-23')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4716671', 'comet-03-02')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.8
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.799369968533453]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4706529', 'comet-07-11')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.53
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.5257572718127463]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4731841', 'comet-25-27')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.91
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.913872554497931]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4721070', 'comet-04-15')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.04
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.0376321142513087]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4729813', 'comet-02-39')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.6
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.5978486235256892]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4708820', 'comet-05-68')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.81
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.8107357684485208]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4634411', 'comet-04-35')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.43
# Length of Job:		2
# Standard Deviation:	0.0119
# t1 Accuracy:		98.4%
# Data:
#
# [1.4567205515427595, 1.4328911107407576]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4713455', 'comet-03-18')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.07
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.0657739631651664]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4726805', 'comet-06-05')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.82
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.817940485710746]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4711481', 'comet-03-30')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3.47
# Length of Job:		12
# Standard Deviation:	0.0115
# t1 Accuracy:		100.3%
# Data:
#
# [3.454609367997458, 3.467789831784182, 3.477488144178199, 3.485129414575377, 3.491149363617836, 3.4923877507219157, 3.49078618432813, 3.4876799652569184, 3.4841216256439136, 3.476502324319713, 3.4702702814000506, 3.465528395217057]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4726591', 'comet-06-05')
# ...
# Job:		('4723425', 'comet-03-43')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.35
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.3501042822895486]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4689518', 'comet-10-44')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.22
# Length of Job:		21
# Standard Deviation:	0.731
# t1 Accuracy:		48.2%
# Data:
#
# [4.612017597736583, 4.310290130478763, 4.115132198380435, 3.8884028586820154, 3.6649154830263346, 3.4504320069302046, 3.277996653607141, 3.12007386906345, 2.970766318137788, 2.8337366874672765, 2.718896882705207, 2.621616864429565, 2.539927368340416, 2.4709682314440005, 2.4144865125583252, 2.3672708405493097, 2.32822706116283, 2.2951663072057276, 2.266962428774072, 2.2425436222339896, 2.221496963730172]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4680869', 'comet-06-16')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3.41
# Length of Job:		2
# Standard Deviation:	0.0393
# t1 Accuracy:		97.7%
# Data:
#
# [3.4924049973037765, 3.4137392081508255]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4707330', 'comet-05-36')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.47
# Length of Job:		3
# Standard Deviation:	0.00486
# t1 Accuracy:		99.6%
# Data:
#
# [2.4777058086609265, 2.4667817411536332, 2.4681511020330977]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4726104', 'comet-02-01')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.12
# Length of Job:		9
# Standard Deviation:	0.00422
# t1 Accuracy:		100.3%
# Data:
#
# [2.1104239246380345, 2.1063095115577606, 2.1115240310857266, 2.114665521479333, 2.1178368109039525, 2.1189880408672956, 2.118517108010694, 2.1181561826423407, 2.1173140296695565]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4709537', 'comet-07-19')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.3
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.3010439409187735]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4710834', 'comet-04-52')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.66
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.664066448647559]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4707447', 'comet-07-11')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.53
# Length of Job:		4
# Standard Deviation:	0.00111
# t1 Accuracy:		99.8%
# Data:
#
# [1.528061262590958, 1.5260916629589072, 1.5257690796221635, 1.5250585520838469]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4707112', 'comet-07-54')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.69
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.6855717628372338]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4723553', 'comet-06-53')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.05
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.0479306825525057]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4707449', 'comet-07-13')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.92
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.919093322945006]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4720199', 'comet-06-10')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.6
# Length of Job:		31
# Standard Deviation:	0.278
# t1 Accuracy:		53.6%
# Data:
#
# [2.9771155108463354, 1.9394625330012287, 1.6460729488202557, 1.4724100116414256, 1.3998253780435033, 1.381034140401831, 1.3687836714614694, 1.374668336763711, 1.3894130958805968, 1.4057020387461654, 1.4247746250893805, 1.4449444819857347, 1.4659440281478056, 1.4859858933666474, 1.505598292286835, 1.5241422156391404, 1.540285908893723, 1.549691196183007, 1.5544524129075397, 1.5539265183856565, 1.5555624003047732, 1.5589463881041612, 1.5637240917277255, 1.567309375283199, 1.5719116991046966, 1.574926063844335, 1.5789124183728653, 1.5829350990367568, 1.5871637124363815, 1.5920180576837841, 1.5963597417500208]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4707119', 'comet-03-18')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.7
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.697766144737545]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4723556', 'comet-03-02')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.43
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.426566172462362]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4710838', 'comet-07-24')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.76
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.7551640967646198]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4731326', 'comet-03-10')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.74
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.737844367445704]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4707686', 'comet-05-68')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.84
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.8406721344537489]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4730108', 'comet-07-54')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.7
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.7047737519365025]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4706426', 'comet-07-48')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.76
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.7551750785240479]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4716286', 'comet-08-26')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3.0
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [3.0008461727036675]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4707688', 'comet-07-13')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.92
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.9241322934204426]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4706421', 'comet-07-29')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3.1
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [3.096889941401962]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4703592', 'comet-04-11')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.74
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.739276347214183]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4727184', 'comet-03-02')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.07
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.068772076640195]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4728762', 'comet-21-70')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.25
# Length of Job:		2
# Standard Deviation:	0.0533
# t1 Accuracy:		92.1%
# Data:
#
# [1.3562068713291484, 1.249515596581399]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4720519', 'comet-03-02')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.18
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.1811628692016747]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4697507', 'comet-07-11')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.55
# Length of Job:		4
# Standard Deviation:	0.00917
# t1 Accuracy:		98.5%
# Data:
#
# [1.5717756029287722, 1.55864219148529, 1.5515560689594066, 1.5477027454018553]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4724436', 'comet-03-43')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.17
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.167736822248678]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4727984', 'comet-03-02')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.43
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.433930418596944]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4680046', 'comet-22-24')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.59
# Length of Job:		2
# Standard Deviation:	0.00813
# t1 Accuracy:		99.4%
# Data:
#
# [2.605407017820169, 2.5891378442674164]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4712571', 'comet-06-08')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.95
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.9453204614602928]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4727989', 'comet-03-15')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		3.64
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [3.6412196307708853]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4686491', 'comet-07-48')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.07
# Length of Job:		6
# Standard Deviation:	0.118
# t1 Accuracy:		85.7%
# Data:
#
# [2.410003487751016, 2.2175358625089023, 2.1420941021278987, 2.1043924216649397, 2.080405627997347, 2.0665541234055977]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4720350', 'comet-12-57')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		4.44
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [4.442233104033063]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4714259', 'comet-08-06')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		1.78
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [1.7813203459383775]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4702357', 'comet-02-56')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.63
# Length of Job:		1
# Standard Deviation:	0.0
# t1 Accuracy:		100.0%
# Data:
#
# [2.6334765532393636]
#
# ---------------------------------------------------------------------------------------------------------------------
# Job:		('4682518', 'comet-14-45')
# ---------------------------------------------------------------------------------------------------------------------
# Final cpicore:		2.94
# Length of Job:		23
# Standard Deviation:	0.636
# t1 Accuracy:		68.2%
# Data:
#
# [4.317874564582779, 4.701541215552666, 4.742536540054712, 4.742381589013249, 4.69614400424716, 4.582119686002939, 4.4317105839542625, 4.270940809783489, 4.116637849776763, 3.975922161944055, 3.841506521891026, 3.7178257976812312, 3.602651005007847, 3.498030450088413, 3.4040364097157028, 3.3185824803768362, 3.2418827007612, 3.1747647191885395, 3.115339183389937, 3.063180487888715, 3.0174258570345867, 2.977250043664045, 2.942746714270901]

# %%
print "Total Jobs:\t\t", total
print "Outliers:\t\t", total - count
print "=============================="
print "Accurate t1 (%):\t{:.1%}".format(count/total)
# Out:
# Total Jobs:		2297
# Outliers:		297
# ==============================
# Accurate t1 (%):	0.0%

# %% [markdown]
# ## What is the typical behavior of cpicore?

# %%
all_cpi = []
all_cpi_data = []
high_cpi = []
med_cpi = []
low_cpi = []

for job_tup in overview.items():
    label = job_tup[0]
    info = job_tup[1]
    
    all_cpi.append( info['Final'] )
    all_cpi_data.append( (label,info['Final']) )
    
    if info['Final'] < 3:
        low_cpi.append( (label,info['Final']) )
    elif info['Final'] < 10:
        med_cpi.append( (label,info['Final']) )
    else:
        high_cpi.append( (label,info['Final']) )

# %%
first_q = np.quantile(all_cpi, 0.25)
second_q = np.quantile(all_cpi, 0.5)
third_q = np.quantile(all_cpi, 0.75)
fourth_q = np.quantile(all_cpi, 0.99)


print "----------------------"
print "\tQuartiles"
print "----------------------" 
print "First:\t\t", np.round(first_q, 4)
print "Second:\t\t", np.round(second_q, 4)
print "Third:\t\t", np.round(third_q, 4)
print "Fourth:\t\t", np.round(fourth_q, 4)
# Out:
# ----------------------
# 	Quartiles
# ----------------------
# First:		1.7146
# Second:		1.9624
# Third:		2.4735
# Fourth:		5.0981

# %%
print "Total Jobs:\t\t", total
print "High CPI:\t\t", len(high_cpi)
print "Med. CPI:\t\t", len(med_cpi)
print "Low CPI:\t\t", len(low_cpi)
print "=============================="
print "Unusual Jobs (%):\t{:.1%}".format((len(high_cpi))/total)
# Out:
# Total Jobs:		2297
# High CPI:		6
# Med. CPI:		247
# Low CPI:		2044
# ==============================
# Unusual Jobs (%):	0.0%

# %%
high_cpi
# Out:
# [(('4711272', 'comet-07-53'), 13.400145829553407),
#  (('4718522', 'comet-21-70'), 30.57388955872469),
#  (('4702365', 'comet-07-22'), 25030.569254107602),
#  (('4717632', 'comet-10-69'), 978.174678773496),
#  (('4720026', 'comet-07-22'), 13.236789002823942),
#  (('4714085', 'comet-26-21'), 21.716839497218484)]

# %%
med_cpi.sort(key=lambda tup: tup[1])

# %%
med_cpi[-2:]
# Out:
# [(('4719398', 'comet-04-08'), 7.991633346415882),
#  (('4712381', 'comet-06-05'), 9.173618165850725)]

# %%
low_cpi.sort(key=lambda tup: tup[1])

# %%
low_cpi[:5]
# Out:
# [(('4720087', 'comet-07-22'), 0.6212727016596244),
#  (('4720114', 'comet-06-54'), 0.6363775359515448),
#  (('4731646', 'comet-04-15'), 0.6657674632391879),
#  (('4720115', 'comet-26-29'), 0.6706806833123542),
#  (('4719865', 'comet-29-02'), 0.7907878122867514)]

# %% [markdown]
# # Displaying Data

# %%
jobids = cpicore_set.keys()

# %%
#for jobid,data_dict in cpicore_set.items():
focus = jobids[0]
data_dict = cpicore_set[ focus ]
x = [ i for i in range( len(data_dict.values()[0]) ) ]
y = [ val for val in data_dict.values()[0] ]
plt.scatter( x, y )
#plt.plot(x,y)
#plt.title('CPI Core Over Runtime')
#plt.xlabel('Time Interval')
#plt.ylabel('CPI Core')
plt.savefig("./src/data/summary_stats/cpicore/images/{}.png".format(jobid))
#plt.clf()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/baileyp/.local/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /home/baileyp/.local/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in _fetch_figure_metadata(fig)
#     172     """Get some metadata to help with displaying a figure."""
#     173     # determine if a background is needed for legibility
# --> 174     if _is_transparent(fig.get_facecolor()):
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
#
# /home/baileyp/.local/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in _is_transparent(color)
#     193 def _is_transparent(color):
#     194     """Determine transparency from alpha."""
# --> 195     rgba = colors.to_rgba(color)
#     196     return rgba[3] < .5
#
# AttributeError: 'module' object has no attribute 'to_rgba'
