# %%
# System dependencies
from os import listdir
import time as clock
from datetime import timedelta
from IPython.display import clear_output

# %%
# Data manipulation dependencies
import pandas as pd
import numpy as np
import datetime as dt

# %%
# Custom data handling methods
import prep_IO

# %%
# Directory of pre-determined lustre failed jobs
source_dir = './lustre_fail_set.txt'

# location of search contents
src = './lustre.failed.jobs2.txt'
acct_base = '/oasis/projects/nsf/sys200/stats/xsede_stats/comet_accounting/'

# %% [markdown]
# ## Temp A

# %%
# up to error:
chosen = [('comet-14-72,comet-19-19,comet-28-55', '2020-05-13T02:11:38', '2020-05-13T05:07:34', '33301074'),
         ('comet-30-10', '2020-05-13T10:50:08', '2020-05-13T10:50:12', '33321014'),
          ('comet-06-46,comet-12-52,comet-22-[39,64]', '2020-05-12T06:40:43', '2020-05-13T14:27:44', '33283100'),
          ('comet-21-07', '2020-05-27T08:49:26', '2020-05-28T01:27:49', '33637231'),
          ('comet-22-48', '2020-05-27T09:32:35', '2020-05-28T00:25:06', '33637422'),
         ]

# %% [markdown]
# ## Testing A

# %%
search_out = prep_IO.search( mode='l', from_list=chosen )

# %%
keys = list(search_out.keys())[1:]
len(keys)
# Out:
# 9

# %%
sample_key = keys[0]
sample = search_out[ sample_key ]
print( sample_key )
print( sample.keys() )
# Out:
# ('comet-19-19', 1589361098, 1589371654, '33301074')
# dict_keys(['Acct Info', 'Host Info', 'Source Files'])

# %%
sample['Acct Info']
# Out:
# '33301074|haqi|uic304|2020-05-13T02:11:38|2020-05-13T05:07:34|2020-05-12T02:50:25|compute|1-00:00:00|eq-5MN6-01_sim2|FAILED|3|6|comet-14-72,comet-19-19,comet-28-55\n'

# %%
sample['Host Info'].keys()
# Out:
# dict_keys(['Timely Data', 'Schemas', 'Specs'])

# %%
sample['Host Info']["Specs"]
# Out:
# ['tacc_stats 2.3.1',
#  'hostname comet-19-19.sdsc.edu',
#  'uname Linux x86_64 2.6.32-642.13.1.el6.x86_64 #1 SMP Wed Jan 11 20:56:24 UTC 2017',
#  'uptime 864119']

# %%
sample['Host Info']["Timely Data"]
# Out:
# [('block', 'io_ticks(U=ms)', 'md0', 0, '2017-02-24T20:43:45'),
#  ('block', 'io_ticks(U=ms)', 'md1', 0, '2017-02-24T20:43:45'),
#  ('block', 'io_ticks(U=ms)', 'sda', 20963407, '2017-02-24T20:43:45'),
#  ('block', 'io_ticks(U=ms)', 'sdb', 21027378, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '22', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '20', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '21', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '11', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '10', 1, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '13', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '12', 1, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '15', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '14', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '17', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '16', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '19', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '18', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '23', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '1', 8, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '0', 4042, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '3', 5, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '2', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '5', 2, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '4', 1, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '7', 1, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '6', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '9', 0, '2017-02-24T20:43:45'),
#  ('cpu', 'irq(U=cs)', '8', 1, '2017-02-24T20:43:45'),
#  ('ib', 'symbol_error(W=32)', 'mlx4_0.1', 0, '2017-02-24T20:43:45'),
#  ('ib_ext', 'port_multicast_xmit_pkts', 'mlx4_0/1', 90, '2017-02-24T20:43:45'),
#  ('ib_sw',
#   'tx_bytes(U=4B)',
#   'mlx4_0/1',
#   380150240154010,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '22',
#   66904728724041,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '20',
#   91451217699900,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '21',
#   67696592969267,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '11',
#   205479476999115,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '10',
#   203044625458457,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '13',
#   273584286734634,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '12',
#   249674175752863,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '15',
#   262165489075036,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '14',
#   272771731005211,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '17',
#   112881019796701,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '16',
#   121771864848984,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '19',
#   113583507242939,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '18',
#   116843911026102,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '23',
#   67767764930560,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '1',
#   262492499095088,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '0',
#   246316483027092,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '3',
#   258373975529909,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '2',
#   264926692421254,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '5',
#   250448340599024,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '4',
#   253543054734388,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '7',
#   249626704094989,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '6',
#   252647744692700,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '9',
#   206559611047997,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '8',
#   226191476285452,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/7', 25475310760214, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/6', 33060555756235, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/5', 29574044702378, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/4', 30081641277080, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/3', 30408024567804, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/2', 29500766774159, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/1', 32348852877580, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/0', 30851002508893, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/6', 33456742309653, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/7', 28561910606064, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/4', 30100290086385, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/5', 32133023596024, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/2', 29106694174727, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/3', 31277492624136, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/0', 31422811130999, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/1', 33708655979332, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '0/10',
#   37506397320119,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '0/11',
#   32455906611772,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/9', 25632643185297, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/8', 30647775792934, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/8', 31942608711935, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/9', 28414077351511, '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '1/11',
#   30371211298297,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '1/10',
#   36055273552093,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   'ff/12.5',
#   216045392472354,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   '7f/12.1',
#   180117603119148,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   'ff/12.1',
#   216045392574685,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   '7f/12.5',
#   180117602994385,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/14.1',
#   14985005872597,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/14.0',
#   15213184887731,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/17.1',
#   15659370925901,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/17.0',
#   15892229005624,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/14.0',
#   15903186436688,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/14.1',
#   15662340405288,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/17.0',
#   15203424992195,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/17.1',
#   14977358605601,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_pcu',
#   'FIXED_CTR0(W=64)',
#   '1',
#   2719061075550,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_pcu',
#   'FIXED_CTR0(W=64)',
#   '0',
#   2798017354225,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   'ff/08.2',
#   38037526727528,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   '7f/08.2',
#   38219302414328,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   '7f/09.2',
#   38573277238920,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   'ff/09.2',
#   37536813423096,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_r2pci',
#   'CTR2(W=44)',
#   '7f/10.1',
#   168514419192546,
#   '2017-02-24T20:43:45'),
#  ('intel_hsw_r2pci',
#   'CTR2(W=44)',
#   'ff/10.1',
#   169125329406856,
#   '2017-02-24T20:43:45'),
#  ('intel_rapl',
#   'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)',
#   '1',
#   0,
#   '2017-02-24T20:43:45'),
#  ('intel_rapl',
#   'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)',
#   '0',
#   0,
#   '2017-02-24T20:43:45'),
#  ('llite', 'mknod', 'wombat-clilov', 14, '2017-02-24T20:43:45'),
#  ('llite', 'mknod', 'panda-clilov', 0, '2017-02-24T20:43:45'),
#  ('lnet', 'rx_bytes(U=B)', '-', 144706247146, '2017-02-24T20:43:45'),
#  ('mdc', 'reqs', 'wombat-clilov', 206442, '2017-02-24T20:43:45'),
#  ('mdc', 'reqs', 'panda-clilov', 167703, '2017-02-24T20:43:45'),
#  ('mem', 'HugePages_Total', '1', 0, '2017-02-24T20:43:45'),
#  ('mem', 'HugePages_Total', '0', 0, '2017-02-24T20:43:45'),
#  ('net', 'tx_packets', 'ib0.8446', 46760785, '2017-02-24T20:43:45'),
#  ('net', 'tx_packets', 'ib0.9336', 221568835, '2017-02-24T20:43:45'),
#  ('net', 'tx_packets', 'ib0', 2993306, '2017-02-24T20:43:45'),
#  ('net', 'tx_packets', 'lo', 2004654, '2017-02-24T20:43:45'),
#  ('net', 'tx_packets', 'peth0', 9298832, '2017-02-24T20:43:45'),
#  ('net', 'tx_packets', 'eth0', 9101663, '2017-02-24T20:43:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/morad', 87, '2017-02-24T20:43:45'),
#  ('numa', 'local_node', '1', 8509753476, '2017-02-24T20:43:45'),
#  ('numa', 'local_node', '0', 9491487912, '2017-02-24T20:43:45'),
#  ('osc', 'reqs', 'wombat-clilov', 4863415, '2017-02-24T20:43:45'),
#  ('osc', 'reqs', 'panda-clilov', 3801967, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nscd/5552', 16777215, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/695', 4, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/711', 262144, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/693', 1, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/696', 8, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/705', 4096, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/697', 16, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/701', 256, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'munged/5644', 16777215, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpirun_rsh/584',
#   16777215,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/707', 16384, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/694', 2, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/715', 4194304, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/700', 128, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/709', 65536, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/708', 32768, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'slurm_script/576',
#   16777215,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/699', 64, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/698', 32, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'hald/5442', 16777215, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'hald-addon-acpi/5485',
#   16777215,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/710', 131072, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/702', 512, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/716', 8388608, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/704', 2048, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/714', 2097152, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/706', 8192, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/712', 524288, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/691',
#   16777215,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'perl/581', 16777215, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/713', 1048576, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/703', 1024, '2017-02-24T20:43:45'),
#  ('ps', 'nr_running', '-', 25, '2017-02-24T20:43:45'),
#  ('sysv_shm', 'mem_used(U=B)', '-', 0, '2017-02-24T20:43:45'),
#  ('tmpfs', 'bytes_used(U=B)', '/dev/shm', 132046848, '2017-02-24T20:43:45'),
#  ('vfs', 'file_use', '-', 1968, '2017-02-24T20:43:45'),
#  ('vm', 'allocstall', '-', 420, '2017-02-24T20:43:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/jjakowsk', 0, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17624', 262144, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17621', 32768, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17620', 16384, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17628', 4194304, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17627', 2097152, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17609', 8, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17608', 4, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17626', 1048576, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17607', 2, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17606', 1, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17625', 524288, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17612', 64, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17613', 128, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17610', 16, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17611', 32, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17623', 131072, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17617', 2048, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17614', 256, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17615', 512, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17616', 1024, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17618', 4096, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17619', 8192, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/17604',
#   16777215,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17629', 8388608, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17622', 65536, '2017-02-24T20:43:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/ruizm', 0, '2017-02-24T20:43:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/vpaschal', 4, '2017-02-24T20:43:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/share/apps', 0, '2017-02-24T20:43:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/dschaich', 0, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31117', 512, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31103', 4, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31119', 1024, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/31097',
#   16777215,
#   '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31118',
#   2097152,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31115', 256, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31116',
#   1048576,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31099', 1, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31114',
#   524288,
#   '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31106',
#   32768,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31107', 16, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31104',
#   16384,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31105', 8, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31102', 8192, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31122',
#   8388608,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31100', 4096, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31101', 2, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31111', 64, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31110',
#   131072,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31113', 128, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31112',
#   262144,
#   '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31120',
#   4194304,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31121', 2048, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31108',
#   65536,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31109', 32, '2017-02-24T20:43:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/vkotteda', 0, '2017-02-24T20:43:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/pmistani', 0, '2017-02-24T20:43:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/opt/intel/2016.3.210', 0, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1937', 131072, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1935', 32768, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1934', 16384, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1933', 8192, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1932', 4096, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1931', 2048, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1936', 65536, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1939', 524288, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1938', 262144, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1924', 16, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'pmi_proxy/1913',
#   16777215,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1923', 8, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1930', 1024, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1925', 32, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1928', 256, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1929', 512, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1926', 64, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1920', 1, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1921', 2, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1922', 4, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1941', 2097152, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1942', 4194304, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1943', 8388608, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1940', 1048576, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1927', 128, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7094',
#   524288,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7095', 256, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7096',
#   1048576,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7097', 512, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7090',
#   131072,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7091', 64, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7092',
#   262144,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7093', 128, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7089', 32, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7088', 65536, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7098',
#   2097152,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7099', 1024, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7080', 4096, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/7077',
#   16777215,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7081', 2, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7087', 16, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7083', 4, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7086', 32768, '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7102',
#   8388608,
#   '2017-02-24T20:43:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7100',
#   4194304,
#   '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7101', 2048, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7085', 8, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7079', 1, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7084', 16384, '2017-02-24T20:43:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7082', 8192, '2017-02-24T20:43:45'),
#  ('block', 'io_ticks(U=ms)', 'md0', 0, '2017-02-24T20:53:45'),
#  ('block', 'io_ticks(U=ms)', 'md1', 0, '2017-02-24T20:53:45'),
#  ('block', 'io_ticks(U=ms)', 'sda', 20963407, '2017-02-24T20:53:45'),
#  ('block', 'io_ticks(U=ms)', 'sdb', 21027378, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '22', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '20', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '21', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '11', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '10', 1, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '13', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '12', 1, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '15', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '14', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '17', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '16', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '19', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '18', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '23', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '1', 8, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '0', 4042, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '3', 5, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '2', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '5', 2, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '4', 1, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '7', 1, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '6', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '9', 0, '2017-02-24T20:53:45'),
#  ('cpu', 'irq(U=cs)', '8', 1, '2017-02-24T20:53:45'),
#  ('ib', 'symbol_error(W=32)', 'mlx4_0.1', 0, '2017-02-24T20:53:45'),
#  ('ib_ext', 'port_multicast_xmit_pkts', 'mlx4_0/1', 90, '2017-02-24T20:53:45'),
#  ('ib_sw',
#   'tx_bytes(U=4B)',
#   'mlx4_0/1',
#   380150240154010,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '22',
#   66904728724041,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '20',
#   91451217699900,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '21',
#   67696592969267,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '11',
#   205479476999115,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '10',
#   203044625458457,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '13',
#   273584286734634,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '12',
#   249674175752863,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '15',
#   262165489075036,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '14',
#   272771731005211,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '17',
#   112881019796701,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '16',
#   121771864848984,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '19',
#   113583507242939,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '18',
#   116843911026102,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '23',
#   67767764930560,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '1',
#   262492499095088,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '0',
#   246316483027092,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '3',
#   258373975529909,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '2',
#   264926692421254,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '5',
#   250448340599024,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '4',
#   253543054734388,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '7',
#   249626704094989,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '6',
#   252647744692700,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '9',
#   206559611047997,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '8',
#   226191476285452,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/7', 25475310760214, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/6', 33060555756235, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/5', 29574044702378, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/4', 30081641277080, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/3', 30408024567804, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/2', 29500766774159, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/1', 32348852877580, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/0', 30851002508893, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/6', 33456742309653, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/7', 28561910606064, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/4', 30100290086385, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/5', 32133023596024, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/2', 29106694174727, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/3', 31277492624136, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/0', 31422811130999, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/1', 33708655979332, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '0/10',
#   37506397320119,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '0/11',
#   32455906611772,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/9', 25632643185297, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/8', 30647775792934, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/8', 31942608711935, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/9', 28414077351511, '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '1/11',
#   30371211298297,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '1/10',
#   36055273552093,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   'ff/12.5',
#   216045392472354,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   '7f/12.1',
#   180117603119148,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   'ff/12.1',
#   216045392574685,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   '7f/12.5',
#   180117602994385,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/14.1',
#   14985005872597,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/14.0',
#   15213184887731,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/17.1',
#   15659370925901,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/17.0',
#   15892229005624,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/14.0',
#   15903186436688,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/14.1',
#   15662340405288,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/17.0',
#   15203424992195,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/17.1',
#   14977358605601,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_pcu',
#   'FIXED_CTR0(W=64)',
#   '1',
#   2719061075550,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_pcu',
#   'FIXED_CTR0(W=64)',
#   '0',
#   2798017354225,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   'ff/08.2',
#   38037526727528,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   '7f/08.2',
#   38219302414328,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   '7f/09.2',
#   38573277238920,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   'ff/09.2',
#   37536813423096,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_r2pci',
#   'CTR2(W=44)',
#   '7f/10.1',
#   168514419192546,
#   '2017-02-24T20:53:45'),
#  ('intel_hsw_r2pci',
#   'CTR2(W=44)',
#   'ff/10.1',
#   169125329406856,
#   '2017-02-24T20:53:45'),
#  ('intel_rapl',
#   'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)',
#   '1',
#   0,
#   '2017-02-24T20:53:45'),
#  ('intel_rapl',
#   'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)',
#   '0',
#   0,
#   '2017-02-24T20:53:45'),
#  ('llite', 'mknod', 'wombat-clilov', 14, '2017-02-24T20:53:45'),
#  ('llite', 'mknod', 'panda-clilov', 0, '2017-02-24T20:53:45'),
#  ('lnet', 'rx_bytes(U=B)', '-', 144706247146, '2017-02-24T20:53:45'),
#  ('mdc', 'reqs', 'wombat-clilov', 206442, '2017-02-24T20:53:45'),
#  ('mdc', 'reqs', 'panda-clilov', 167703, '2017-02-24T20:53:45'),
#  ('mem', 'HugePages_Total', '1', 0, '2017-02-24T20:53:45'),
#  ('mem', 'HugePages_Total', '0', 0, '2017-02-24T20:53:45'),
#  ('net', 'tx_packets', 'ib0.8446', 46760785, '2017-02-24T20:53:45'),
#  ('net', 'tx_packets', 'ib0.9336', 221568835, '2017-02-24T20:53:45'),
#  ('net', 'tx_packets', 'ib0', 2993306, '2017-02-24T20:53:45'),
#  ('net', 'tx_packets', 'lo', 2004654, '2017-02-24T20:53:45'),
#  ('net', 'tx_packets', 'peth0', 9298832, '2017-02-24T20:53:45'),
#  ('net', 'tx_packets', 'eth0', 9101663, '2017-02-24T20:53:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/morad', 87, '2017-02-24T20:53:45'),
#  ('numa', 'local_node', '1', 8509753476, '2017-02-24T20:53:45'),
#  ('numa', 'local_node', '0', 9491487912, '2017-02-24T20:53:45'),
#  ('osc', 'reqs', 'wombat-clilov', 4863415, '2017-02-24T20:53:45'),
#  ('osc', 'reqs', 'panda-clilov', 3801967, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nscd/5552', 16777215, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/695', 4, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/711', 262144, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/693', 1, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/696', 8, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/705', 4096, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/697', 16, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/701', 256, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'munged/5644', 16777215, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpirun_rsh/584',
#   16777215,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/707', 16384, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/694', 2, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/715', 4194304, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/700', 128, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/709', 65536, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/708', 32768, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'slurm_script/576',
#   16777215,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/699', 64, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/698', 32, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'hald/5442', 16777215, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'hald-addon-acpi/5485',
#   16777215,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/710', 131072, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/702', 512, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/716', 8388608, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/704', 2048, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/714', 2097152, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/706', 8192, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/712', 524288, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/691',
#   16777215,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'perl/581', 16777215, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/713', 1048576, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/703', 1024, '2017-02-24T20:53:45'),
#  ('ps', 'nr_running', '-', 25, '2017-02-24T20:53:45'),
#  ('sysv_shm', 'mem_used(U=B)', '-', 0, '2017-02-24T20:53:45'),
#  ('tmpfs', 'bytes_used(U=B)', '/dev/shm', 132046848, '2017-02-24T20:53:45'),
#  ('vfs', 'file_use', '-', 1968, '2017-02-24T20:53:45'),
#  ('vm', 'allocstall', '-', 420, '2017-02-24T20:53:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/jjakowsk', 0, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17624', 262144, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17621', 32768, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17620', 16384, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17628', 4194304, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17627', 2097152, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17609', 8, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17608', 4, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17626', 1048576, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17607', 2, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17606', 1, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17625', 524288, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17612', 64, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17613', 128, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17610', 16, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17611', 32, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17623', 131072, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17617', 2048, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17614', 256, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17615', 512, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17616', 1024, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17618', 4096, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17619', 8192, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/17604',
#   16777215,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17629', 8388608, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17622', 65536, '2017-02-24T20:53:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/ruizm', 0, '2017-02-24T20:53:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/vpaschal', 4, '2017-02-24T20:53:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/share/apps', 0, '2017-02-24T20:53:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/dschaich', 0, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31117', 512, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31103', 4, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31119', 1024, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/31097',
#   16777215,
#   '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31118',
#   2097152,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31115', 256, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31116',
#   1048576,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31099', 1, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31114',
#   524288,
#   '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31106',
#   32768,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31107', 16, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31104',
#   16384,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31105', 8, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31102', 8192, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31122',
#   8388608,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31100', 4096, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31101', 2, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31111', 64, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31110',
#   131072,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31113', 128, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31112',
#   262144,
#   '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31120',
#   4194304,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31121', 2048, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31108',
#   65536,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31109', 32, '2017-02-24T20:53:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/vkotteda', 0, '2017-02-24T20:53:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/pmistani', 0, '2017-02-24T20:53:45'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/opt/intel/2016.3.210', 0, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1937', 131072, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1935', 32768, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1934', 16384, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1933', 8192, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1932', 4096, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1931', 2048, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1936', 65536, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1939', 524288, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1938', 262144, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1924', 16, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'pmi_proxy/1913',
#   16777215,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1923', 8, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1930', 1024, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1925', 32, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1928', 256, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1929', 512, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1926', 64, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1920', 1, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1921', 2, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1922', 4, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1941', 2097152, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1942', 4194304, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1943', 8388608, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1940', 1048576, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'vasp/1927', 128, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7094',
#   524288,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7095', 256, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7096',
#   1048576,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7097', 512, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7090',
#   131072,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7091', 64, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7092',
#   262144,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7093', 128, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7089', 32, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7088', 65536, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7098',
#   2097152,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7099', 1024, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7080', 4096, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/7077',
#   16777215,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7081', 2, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7087', 16, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7083', 4, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7086', 32768, '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7102',
#   8388608,
#   '2017-02-24T20:53:45'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/7100',
#   4194304,
#   '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7101', 2048, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7085', 8, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7079', 1, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7084', 16384, '2017-02-24T20:53:45'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/7082', 8192, '2017-02-24T20:53:45'),
#  ('block', 'io_ticks(U=ms)', 'md0', 0, '2017-02-24T21:03:46'),
#  ('block', 'io_ticks(U=ms)', 'md1', 0, '2017-02-24T21:03:46'),
#  ('block', 'io_ticks(U=ms)', 'sda', 20963407, '2017-02-24T21:03:46'),
#  ('block', 'io_ticks(U=ms)', 'sdb', 21027378, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '22', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '20', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '21', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '11', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '10', 1, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '13', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '12', 1, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '15', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '14', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '17', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '16', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '19', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '18', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '23', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '1', 8, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '0', 4042, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '3', 5, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '2', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '5', 2, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '4', 1, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '7', 1, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '6', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '9', 0, '2017-02-24T21:03:46'),
#  ('cpu', 'irq(U=cs)', '8', 1, '2017-02-24T21:03:46'),
#  ('ib', 'symbol_error(W=32)', 'mlx4_0.1', 0, '2017-02-24T21:03:46'),
#  ('ib_ext', 'port_multicast_xmit_pkts', 'mlx4_0/1', 90, '2017-02-24T21:03:46'),
#  ('ib_sw',
#   'tx_bytes(U=4B)',
#   'mlx4_0/1',
#   380150240154010,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '22',
#   66904728724041,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '20',
#   91451217699900,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '21',
#   67696592969267,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '11',
#   205479476999115,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '10',
#   203044625458457,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '13',
#   273584286734634,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '12',
#   249674175752863,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '15',
#   262165489075036,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '14',
#   272771731005211,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '17',
#   112881019796701,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '16',
#   121771864848984,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '19',
#   113583507242939,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '18',
#   116843911026102,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '23',
#   67767764930560,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '1',
#   262492499095088,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '0',
#   246316483027092,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '3',
#   258373975529909,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '2',
#   264926692421254,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '5',
#   250448340599024,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '4',
#   253543054734388,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '7',
#   249626704094989,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '6',
#   252647744692700,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '9',
#   206559611047997,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '8',
#   226191476285452,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/7', 25475310760214, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/6', 33060555756235, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/5', 29574044702378, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/4', 30081641277080, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/3', 30408024567804, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/2', 29500766774159, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/1', 32348852877580, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/0', 30851002508893, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/6', 33456742309653, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/7', 28561910606064, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/4', 30100290086385, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/5', 32133023596024, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/2', 29106694174727, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/3', 31277492624136, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/0', 31422811130999, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/1', 33708655979332, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '0/10',
#   37506397320119,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '0/11',
#   32455906611772,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/9', 25632643185297, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/8', 30647775792934, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/8', 31942608711935, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/9', 28414077351511, '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '1/11',
#   30371211298297,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '1/10',
#   36055273552093,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   'ff/12.5',
#   216045392472354,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   '7f/12.1',
#   180117603119148,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   'ff/12.1',
#   216045392574685,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   '7f/12.5',
#   180117602994385,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/14.1',
#   14985005872597,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/14.0',
#   15213184887731,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/17.1',
#   15659370925901,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/17.0',
#   15892229005624,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/14.0',
#   15903186436688,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/14.1',
#   15662340405288,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/17.0',
#   15203424992195,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/17.1',
#   14977358605601,
#   '2017-02-24T21:03:46'),
#  ('intel_hsw_pcu',
# ...
#  ('block', 'io_ticks(U=ms)', 'sda', 20963407, '2017-02-24T21:13:46'),
#  ('block', 'io_ticks(U=ms)', 'sdb', 21027378, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '22', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '20', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '21', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '11', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '10', 1, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '13', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '12', 1, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '15', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '14', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '17', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '16', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '19', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '18', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '23', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '1', 8, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '0', 4042, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '3', 5, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '2', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '5', 2, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '4', 1, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '7', 1, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '6', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '9', 0, '2017-02-24T21:13:46'),
#  ('cpu', 'irq(U=cs)', '8', 1, '2017-02-24T21:13:46'),
#  ('ib', 'symbol_error(W=32)', 'mlx4_0.1', 0, '2017-02-24T21:13:46'),
#  ('ib_ext', 'port_multicast_xmit_pkts', 'mlx4_0/1', 90, '2017-02-24T21:13:46'),
#  ('ib_sw',
#   'tx_bytes(U=4B)',
#   'mlx4_0/1',
#   380150240154010,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '22',
#   66904728724041,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '20',
#   91451217699900,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '21',
#   67696592969267,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '11',
#   205479476999115,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '10',
#   203044625458457,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '13',
#   273584286734634,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '12',
#   249674175752863,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '15',
#   262165489075036,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '14',
#   272771731005211,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '17',
#   112881019796701,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '16',
#   121771864848984,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '19',
#   113583507242939,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '18',
#   116843911026102,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '23',
#   67767764930560,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '1',
#   262492499095088,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '0',
#   246316483027092,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '3',
#   258373975529909,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '2',
#   264926692421254,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '5',
#   250448340599024,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '4',
#   253543054734388,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '7',
#   249626704094989,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '6',
#   252647744692700,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '9',
#   206559611047997,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw',
#   'FIXED_CTR1(W=48)',
#   '8',
#   226191476285452,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/7', 25475310760214, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/6', 33060555756235, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/5', 29574044702378, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/4', 30081641277080, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/3', 30408024567804, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/2', 29500766774159, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/1', 32348852877580, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/0', 30851002508893, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/6', 33456742309653, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/7', 28561910606064, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/4', 30100290086385, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/5', 32133023596024, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/2', 29106694174727, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/3', 31277492624136, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/0', 31422811130999, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/1', 33708655979332, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '0/10',
#   37506397320119,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '0/11',
#   32455906611772,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/9', 25632643185297, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '1/8', 30647775792934, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/8', 31942608711935, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo', 'CTR2(W=48)', '0/9', 28414077351511, '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '1/11',
#   30371211298297,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_cbo',
#   'CTR2(W=48)',
#   '1/10',
#   36055273552093,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   'ff/12.5',
#   216045392472354,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   '7f/12.1',
#   180117603119148,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   'ff/12.1',
#   216045392574685,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_hau',
#   'CTR2(W=48)',
#   '7f/12.5',
#   180117602994385,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/14.1',
#   14985005872597,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/14.0',
#   15213184887731,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/17.1',
#   15659370925901,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/17.0',
#   15892229005624,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/14.0',
#   15903186436688,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   '7f/14.1',
#   15662340405288,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/17.0',
#   15203424992195,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_imc',
#   'CTR3(W=48)',
#   'ff/17.1',
#   14977358605601,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_pcu',
#   'FIXED_CTR0(W=64)',
#   '1',
#   2719061075550,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_pcu',
#   'FIXED_CTR0(W=64)',
#   '0',
#   2798017354225,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   'ff/08.2',
#   38037526727528,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   '7f/08.2',
#   38219302414328,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   '7f/09.2',
#   38573277238920,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_qpi',
#   'CTR2(U=flt(W=48)',
#   'ff/09.2',
#   37536813423096,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_r2pci',
#   'CTR2(W=44)',
#   '7f/10.1',
#   168514419192546,
#   '2017-02-24T21:13:46'),
#  ('intel_hsw_r2pci',
#   'CTR2(W=44)',
#   'ff/10.1',
#   169125329406856,
#   '2017-02-24T21:13:46'),
#  ('intel_rapl',
#   'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)',
#   '1',
#   0,
#   '2017-02-24T21:13:46'),
#  ('intel_rapl',
#   'MSR_PP0_ENERGY_STATUS(U=mJ(W=32)',
#   '0',
#   0,
#   '2017-02-24T21:13:46'),
#  ('llite', 'mknod', 'wombat-clilov', 14, '2017-02-24T21:13:46'),
#  ('llite', 'mknod', 'panda-clilov', 0, '2017-02-24T21:13:46'),
#  ('lnet', 'rx_bytes(U=B)', '-', 144706247146, '2017-02-24T21:13:46'),
#  ('mdc', 'reqs', 'wombat-clilov', 206442, '2017-02-24T21:13:46'),
#  ('mdc', 'reqs', 'panda-clilov', 167703, '2017-02-24T21:13:46'),
#  ('mem', 'HugePages_Total', '1', 0, '2017-02-24T21:13:46'),
#  ('mem', 'HugePages_Total', '0', 0, '2017-02-24T21:13:46'),
#  ('net', 'tx_packets', 'ib0.8446', 46760785, '2017-02-24T21:13:46'),
#  ('net', 'tx_packets', 'ib0.9336', 221568835, '2017-02-24T21:13:46'),
#  ('net', 'tx_packets', 'ib0', 2993306, '2017-02-24T21:13:46'),
#  ('net', 'tx_packets', 'lo', 2004654, '2017-02-24T21:13:46'),
#  ('net', 'tx_packets', 'peth0', 9298832, '2017-02-24T21:13:46'),
#  ('net', 'tx_packets', 'eth0', 9101663, '2017-02-24T21:13:46'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/morad', 87, '2017-02-24T21:13:46'),
#  ('numa', 'local_node', '1', 8509753476, '2017-02-24T21:13:46'),
#  ('numa', 'local_node', '0', 9491487912, '2017-02-24T21:13:46'),
#  ('osc', 'reqs', 'wombat-clilov', 4863415, '2017-02-24T21:13:46'),
#  ('osc', 'reqs', 'panda-clilov', 3801967, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nscd/5552', 16777215, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/695', 4, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/711', 262144, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/693', 1, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/696', 8, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/705', 4096, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/697', 16, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/701', 256, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'munged/5644', 16777215, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpirun_rsh/584',
#   16777215,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/707', 16384, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/694', 2, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/715', 4194304, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/700', 128, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/709', 65536, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/708', 32768, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'slurm_script/576',
#   16777215,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/699', 64, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/698', 32, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'hald/5442', 16777215, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'hald-addon-acpi/5485',
#   16777215,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/710', 131072, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/702', 512, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/716', 8388608, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/704', 2048, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/714', 2097152, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/706', 8192, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/712', 524288, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/691',
#   16777215,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'perl/581', 16777215, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/713', 1048576, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'NavStk/703', 1024, '2017-02-24T21:13:46'),
#  ('ps', 'nr_running', '-', 25, '2017-02-24T21:13:46'),
#  ('sysv_shm', 'mem_used(U=B)', '-', 0, '2017-02-24T21:13:46'),
#  ('tmpfs', 'bytes_used(U=B)', '/dev/shm', 132046848, '2017-02-24T21:13:46'),
#  ('vfs', 'file_use', '-', 1968, '2017-02-24T21:13:46'),
#  ('vm', 'allocstall', '-', 420, '2017-02-24T21:13:46'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/jjakowsk', 0, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17624', 262144, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17621', 32768, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17620', 16384, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17628', 4194304, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17627', 2097152, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17609', 8, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17608', 4, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17626', 1048576, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17607', 2, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17606', 1, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17625', 524288, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17612', 64, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17613', 128, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17610', 16, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17611', 32, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17623', 131072, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17617', 2048, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17614', 256, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17615', 512, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17616', 1024, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17618', 4096, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17619', 8192, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/17604',
#   16777215,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17629', 8388608, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'nwchem/17622', 65536, '2017-02-24T21:13:46'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/ruizm', 0, '2017-02-24T21:13:46'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/vpaschal', 4, '2017-02-24T21:13:46'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/share/apps', 0, '2017-02-24T21:13:46'),
#  ('nfs', 'WRITE_rtt(U=ms)', '/home/dschaich', 0, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31117', 512, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31103', 4, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31119', 1024, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'mpispawn/31097',
#   16777215,
#   '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31118',
#   2097152,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31115', 256, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31116',
#   1048576,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31099', 1, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31114',
#   524288,
#   '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31106',
#   32768,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31107', 16, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31104',
#   16384,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31105', 8, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31102', 8192, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31122',
#   8388608,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31100', 4096, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31101', 2, '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31111', 64, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31110',
#   131072,
#   '2017-02-24T21:13:46'),
#  ('proc', 'Cpus_allowed_list', 'su3_Wflow/31113', 128, '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31112',
#   262144,
#   '2017-02-24T21:13:46'),
#  ('proc',
#   'Cpus_allowed_list',
#   'su3_Wflow/31120',
#   4194304,
#   '2017-02-24T21:13:46'),
#  ...]

# %% [markdown]
# ## Temp B

# %%
def check_len ( df, num ):
    return len(df.columns.values.tolist()) > num

def purge_str ( df ):
    for row,col in df.iterrows():
        for i in range(len(col.values)):
            val = col.values[i]
            time = col.index[i]
            
            # certain numeric responses are recorded as str
            if type(val) is str:
                try:
                    df.at[row,time] = np.float64( val )
                except:
                    df.at[row,time] = np.float64(0)
                else:
                    df.at[row,time] = np.float64(0)
                    
    return df
    
def get_host_id ( file_name ):
    host,jobid = file_name.split('_')
    return host[:11] , jobid[:7]

def get_dfs ( file_list, min_jobs, min_cycles=0 ):
    job_dfs = {}
    count = 0
    
    for i in range( len(file_list) ):
        
        if count < min_jobs:
            job_file = file_list[i]
            df = purge_str( pd.read_csv( source_dir+job_file, index_col=[0,1,2], low_memory=False ) )
            host,jobid = get_host_id( job_file )
        
            if check_len( df, min_cycles ):
                job_dfs[jobid] = {}
                job_dfs[jobid][host] = df
            else:
                next
            
            count += 1
            
    return job_dfs
        
def sort_hosts ( file_list ):
    hosts = {}
    
    for job_file in file_list:
        host,jobid = job_file.split('_')
        
        if host in hosts:
            hosts[host].append( jobid[:7] )
        else:
            hosts[host] = [ jobid[:7] ]
            
    return hosts
            
def sort_jobs ( file_list, job_dfs ):
    jobs = {}
    
    for job_file in file_list:
        host,jobid = get_id( job_file )
        
        if jobid in job_dfs.keys():
            if jobid in jobs:
                jobs[jobid].append( host )
            else:
                jobs[jobid] = [ host ]
            
    return jobs, multiple_hosts(jobs)

def multiple_hosts ( jobs_dict ):
    return any( len(host) > 1 for job,host in jobs_dict.items() )

def cpicore_simple ( job_df, monitor=False ):
    data = job_df.loc['intel_hsw']
    times = job_df.columns.tolist()
    cpicore_list = []
    
    for i in range(1, len(times)):
        chunk = data[times[:i+1]]
        devices = { row : np.mean(col.values) for row,col in chunk.iterrows() }
        avg_c = { key[0]:0 for key,val in devices.items() }
        sum_avgs = 0
        
        for key,val in avg_c.items():
            avg_c[ key ] = devices[ (key, 'CLOCKS_UNHALTED_CORE') ] / devices[ (key, 'INSTRUCTIONS_RETIRED') ]
    
        for key,val in avg_c.items():
            sum_avgs += val
            
        cpicore_list.append(sum_avgs/24)
    
    if monitor:
        return cpicore_list
    
    return sum_avgs/24

def cpicore ( job_df, monitor=False ):
    data = job_df.loc['intel_hsw']
    times = job_df.columns.tolist()
    cpicore_dict = OrderedDict( )
    
    for t in times:
        cpicore_dict[t] = 0
    
    for i in range(1, len(times)):
        chunk = data[times[:i+1]]
        devices = { row : np.mean(col.values) for row,col in chunk.iterrows() }
        avg_c = { key[0]:0 for key,val in devices.items() }
        sum_avgs = 0
        current = times[i]
        
        for key,val in avg_c.items():
            avg_c[ key ] = devices[ (key, 'CLOCKS_UNHALTED_CORE') ] / devices[ (key, 'INSTRUCTIONS_RETIRED') ]
    
        for key,val in avg_c.items():
            sum_avgs += val
            
        cpicore_dict[current] = sum_avgs/24
    
    if monitor:
        return cpicore_dict
    
    return sum_avgs/24

def cpiref ( devices_dict ):
    avg_d = { key[0]:0 for key,val in devices_dict.items() }
    sum_avgs = 0
    
    for key,val in avg_d.items():
        avg_d[ key ] = devices_dict[ (key, 'CLOCKS_UNHALTED_REF') ] / devices_dict[ (key, 'INSTRUCTIONS_RETIRED') ]
        
    for key,val in avg_d.items():
        sum_avgs += val
        
    return sum_avgs/24

#def find_notable( cpi_set ):
#    notable = []
#    
#    for jobid,data_dict in cpi_set.items():
#        vals = [ val for val in data_dict.values()[1:] ]
#        
#        if not all():
#            notable.append( jobid )

def get_stats( cpi_set, outliers=False ):
    data = []
    outliers = []
    
    for jobid,cpi_dict in cpicore_set.items():
        for val in cpi_dict.values():
            if (val > 0):
                data.append(np.float64(val))
            else:
                outliers.append(val)   
                
    stats = {
        'Max' : max(data),
        'Min' : min(data),
        'Mean' : np.mean(data),
        'Std. Dev' : np.std(data),
        'Count' : len(data),
        'Excluded' : len(outliers)
    }
    
    if outliers:
        return stats,outliers
    
    return stats

# %% [markdown]
# ## Testing B
