# %% [markdown]
# # Performance Data Lookup

# %%
# System dependencies
from os import listdir
import time as clock
from datetime import timedelta
from IPython.display import clear_output

# %%
import pickle
import gzip
import re

# %%
# Data manipulation dependencies
import pandas as pd
import numpy as np
import datetime as dt

# %%
# Directory to save to
save_dir = '../data/continued/'

# Directory of prev job scans
id_dir = '../data/labels/IDs/'

# %%
# Directory of recent saved comet jobs
source_dir = '/oasis/projects/nsf/sys200/stats/xsede_stats/'

# %%
contents = listdir(source_dir)
contents
# Out:
# ['archive_of_archive',
#  'gordon_hostfile_logs',
#  'gordon_pickles',
#  'comet_accounting',
#  'gordon_accounting',
#  'comet_pickles',
#  'archive',
#  '.htaccess',
#  'comet_hostfile_logs']

# %%
possible = [ source_dir+file_name for file_name in listdir(source_dir) ]

for item in possible:
    try:
        listdir(item)
    except:
        print(item)
# Out:
# /oasis/projects/nsf/sys200/stats/xsede_stats/gordon_hostfile_logs
# /oasis/projects/nsf/sys200/stats/xsede_stats/gordon_pickles
# /oasis/projects/nsf/sys200/stats/xsede_stats/gordon_accounting
# /oasis/projects/nsf/sys200/stats/xsede_stats/comet_pickles
# /oasis/projects/nsf/sys200/stats/xsede_stats/.htaccess
# /oasis/projects/nsf/sys200/stats/xsede_stats/comet_hostfile_logs

# %%
locs = { 'aofa': source_dir+'archive_of_archive',
         'job_info': source_dir+'comet_accounting',
         'arc': source_dir+'archive'
         #'host_info': source_dir+'comet_hostfile_logs',
         #'old_pickles': source_dir+'comet_pickles'
       }

# %%
for key,loc in locs.items():
    print(loc)
# Out:
# /oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive
# /oasis/projects/nsf/sys200/stats/xsede_stats/comet_accounting
# /oasis/projects/nsf/sys200/stats/xsede_stats/archive

# %%
arc_data = [ locs['arc']+'/'+host_dir+'/'+stamp 
            for host_dir in listdir(locs['arc'])
            for stamp in listdir(locs['arc']+'/'+host_dir)  ]

aofa_data = [ locs['aofa']+'/'+host_dir+'/'+stamp 
            for host_dir in listdir(locs['aofa'])
            for stamp in listdir(locs['aofa']+'/'+host_dir)  ]

# %%
acct_info_locs = [ locs['job_info']+'/'+stamp for stamp in listdir(locs['job_info']) ]
dates = [ loc[-14:-4] for loc in acct_info_locs ]

# %%
len(arc_data)
# Out:
# 298673

# %%
len(aofa_data)
# Out:
# 1809956

# %%
len(acct_info_locs)
# Out:
# 1194

# %% [markdown]
# #### Pre-process available data

# %%
### Process all ###
arc_hosts = [ host_to_info_dict( host_file ) for host_file in arc_data ]
#aofa_hosts = [ host_to_info_dict( host_file ) for host_file in aofa_data ]
#acct_dates = job_to_info_dict( acct_info_locs )

# %%
len(arc_hosts)

# %% [markdown]
# ## Target(s)

# %%
chosen = [('comet-27-[23,27,29-33,35,41-42]', '2020-01-03T20:34:47', '2020-01-05T08:15:18', '30598034'),
         ('comet-15-[01-05,08-10,62,64]', '2020-01-03T07:26:50', '2020-01-05T07:28:31', '30644440'),
         ('comet-19-[06,11-14,17-19,22,24]', '2020-01-03T20:34:47', '2020-01-05T08:11:53', '30598030'),
         ('comet-15-[10,14,66,69,71],comet-18-09,comet-20-[46,48,50,56,59,61]', '2019-08-23T01:06:50', '2019-08-23T06:00:27', '25918189'),
         ('comet-01-[26,32-33],comet-05-72,comet-07-[47-48],comet-23-[08,18-19,33,39,69]', '2019-08-23T02:34:38', '2019-08-23T08:07:04', '25920563')
         ]

# %%
#diff = get_stamp(chosen[0][2]) - get_stamp(chosen[0][1])

# %%
#diff / 60000

# %% [markdown]
# ### Prep Cleaning

# %%
def get_time( spec=None ):
    if type(spec) is str:
        spec = float( spec )
    
    return clock.strftime("%Y-%d-%mT%H:%M:%S", clock.localtime( spec ))

# %%
def get_stamp( spec ):
    try:
        sf = "%Y-%d-%mT%H:%M:%S"
        return int(clock.mktime( clock.strptime( spec, sf ) ))
    except:
        try:
            sf = "'%Y-%d-%mT%H:%M:%S'"
            return int(clock.mktime( clock.strptime( spec, sf ) ))
        except:
            return 0

# %%
def check_static( alist ):
    return alist[1:] == alist[:-1]

# %%
def check_header( line ):
    if line.find(" ") < 0:
        try:
            return line[0] == '%'
        except:
            return False
        
    else:
        chunks = line.split(" ")
        try:
            return (chunks[0][0] == '%') or ( chunks[2].find("comet") >= 0 )
        except:
            return False

# %%
#def group_from_txt(  ):
#

# %%
def check_job( chunk ):
    return chunk.find("-") == -1

# %%
def open_txt( txt_file ):
    
    with open( txt_file, "rt" ) as f:
        lines = f.readlines()
        f.close()
    
    return lines

# %%
def unzip_txt( gzipped ):
    
    with gzip.open( gzipped, 'rt') as f:
        lines = f.readlines()
        f.close()
    
    return lines

# %%
def group_from_txt( txt_file ):
    lines = open_txt( txt_file )
    group = []
    
    for line in lines:
        chunks = line.split(" ")
        nodelist_r = chunks[0]
        nodelist = format_nodelist( chunks[0] )
        start = get_stamp( chunks[1] )
        end = get_stamp( chunks[2] )
        
        item = ( nodelist, start, end )
        group.append(item)
        
    return group

# %%
def quick_save( obj, label=get_time() ):
    
    try:
        out_file = open( label, 'wb')
        pickle.dump( obj, out_file)
        
        # double check save
        check_cpicore_set = pickle.load(open(cpiset_out, 'rb'))
        check_cpicore_set = None
        
    except:
        "There was a problem pickling the object - Save manually."

# %% [markdown]
# Data Munging

# %%
def info_dict( rules, info ):
    rules_list = rules.split("|")
    
    if len(rules_list) != len(info):
        return {}
    
    else:
        return { rules_list[i]:info[i] for i in range(len(rules_list)) }

# %%
def host_to_info_dict( zip_txt ):
    contents = unzip_txt( zip_txt )
    host_name = contents[1].partition(" ")[2][:11]
    out_dict = { host_name: {} }
    host_info = {}
    info_dict = { "Data":{},
                    "Job":"N/A",
                    "Schemas":{},
                    "Specs":[]
                }
    
    for line in contents:
            
        if line[0] == "$":
            info_dict["Specs"].append( format_spec( line ) )
            
        elif line[0] == "!":
            info_dict["Schemas"].update( format_schema( line ) )
        
        else:
            
            if (len(line) > 0) and (len(line) < 3 or check_header( line )):
                header_dict = format_header( line )
                
                if header_dict:
                    t = header_dict["Timestamp"]
                    host_info[ t ] = {}
                    
                    if check_job( header_dict["Jobid"] ):
                        info_dict["Job"] = { "Jobid": header_dict["Jobid"] } 
                    
            else:
                incoming = format_data( line )
                info_dict["Data"].update(incoming)
                
                host_info[t].update( info_dict )
                
    out_dict[host_name].update( host_info )
    
    return out_dict

# %%
def job_to_info_dict( txt_file_list ):
    nodes_by_date = {}
    unsaved = []

    for date in txt_file_list:
        try:
            # skip alt files
            #check_stamp = int( date[-14] )
            
            # read in file contents
            contents = open_txt( date )
            
            # formatting
            label = date[-14:-4]
            rules = contents[0]
            jobs = contents[1:]
            
            # template to save
            nodes_by_date[ label ] = {}
            nodes_by_date[ label ]["multiple"] = {}
            nodes_by_date[ label ]["rules"] = rules
            
            # run through lines in file
            for job in jobs:
                line = job.split("|")
                node = line[-1]
                info = info_dict( rules, line )
                
                # save multiple node jobs to specified loc
                if len(node) > 12:
                    nodes = format_nodelist( info )
                    for node in nodes:
                        nodes_by_date[ label ][ "multiple" ][ node ] = info
                
                else:
                    nodes_by_date[ label ][ node[:11] ] = info
        except:
            unsaved.append(date)
            
    
    return nodes_by_date, unsaved

# %% [markdown]
# Formatting

# %%
def format_header( line ):
    chunks = line.split(" ")
    
    try:
        if chunks[0][0] == '%':
            return {}
        else:
            return { "Timestamp": get_time( chunks[0] ), 
                     "Jobid": chunks[1],
                     "Host": chunks[2][:11] }
        
    except:
        return {}

# %%
def format_nodelist( nodelist ):
    purged = nodelist.replace('[','').replace(']','').replace(',','-').replace('-','').split("comet")[1:]
    nodes = []
    
    for item in purged:
        base = item[:2]
        prev = 2
        
        for i in range( 4,len(item)+1,2 ):
            node = 'comet' + '-' + base + '-' + item[ prev:i ]
            nodes.append(node)
            prev = i
    return nodes

# %%
def format_spec( line ):
    return line[1:-1]

# %%
def format_data( line ):
    chunks = line.split(" ")
    
    stat = chunks[0]
    dev = chunks[1]
    data = chunks[2:-1]
    
    return { (stat,dev): data }

# %%
def format_schema( line ):
    chunks = line.partition(" ")
    stat = chunks[0][1:]
    
    temp_sch = chunks[2:][0][:-1].replace(",E","").replace(",C","").split(" ")
    fin_sch = []
    
    for item in temp_sch:
        
        if item.find("=") > -1:
            new = item.replace(",","(") + ")"
            fin_sch.append( new )
        
        else:
            fin_sch.append( item )
    
    return { stat:fin_sch }

# %% [markdown]
# Data analysis

# %%
def timely_dict( host_data, host_name ):
    stamps = list(host_data[ host_name ].keys())
    schemas = host_data[ host_name ][ stamps[0] ]["Schemas"]
    timely_data = []
    
    for stamp in stamps:
        for key,data in host_data[ host_name ][ stamp ]["Data"].items():
            
            stat = key[0]
            dev = key[1]
            
            for i in range(len(data)):
                metric = schemas[stat][i]
            
            info = (stat, metric, dev, int(data[i]), stamp)
            timely_data.append( info )
    
    return timely_data

# %%
# PARAMETERS:
# 's/e' single search from start/end (manual)
#       ie) "Start, End: 2020-01-03T20:34:47, 2020-01-05T08:15:18"
# 's' single search from nodelist%start%end (manual)
#       ie) "NL, Start, End: comet-05-12 2020-03-03T20:34:47 2020-03-05T08:15:18"
#       ie) "NL, Start, End: comet-05-[12,16] 2020-03-03T20:34:47 2020-03-05T08:15:18"
# 'l' repeated search from nodelist%start%end strings or (nodelist,start,end) tuples (from list)
#       ie) myJobList = [ "comet-05-12 2020-03-03T20:34:47 2020-03-05T08:15:18",
#                          (comet-05-12, 2020-03-03T20:34:47, 2020-03-05T08:15:18)   ]
#           search( mode='l', myJobList )
# 'f' repeated search from nodelist%start%end (from file)
#       ie) "Text file: your_search_file.txt"  (Note: Mismatched file contents ignored)
def search( mode=['s/e', 's', 'l','f'], job_list=False ):
    
    if mode == 's/e':
        t_0,t_n = input("Start, End:").replace(",", "").split(" ")
        start = get_stamp( t_0 )
        end=get_stamp( t_n )
        return (start,end)
    
    if mode == 's':
        nl,t_0,t_n = input("NL, Start, End:").replace(",", "").split(" ")
        nodelist = format_nodelist( nl )
        start = get_stamp( t_0 )
        end=get_stamp( t_n )
        return (nodelist,start,end)

    if mode == 'l' and job_list:
        try:
            out_list = []
            for item in job_list:
                if len(item.split(" ")) > 1:
                    item = item.split(" ")
                else:
                    nodelist = format_nodelist( item[0] )
                    start = get_stamp( item[1] )
                    end = get_stamp( item[2] )
                    out_list.append( (nodelist,start,end) )
            return out_list
        except:
            "Unable to process variable passed to function. All items in list should be in"
    
    if mode == 'f':
        search_list = group_from_text( input("Text file:") )
        return search_list
    
    else:
        return 1

# %%
def sort_search_tup( in_tup ):
    nl_i = in_tup.index("comet")
    nl = in_tup[ nl_i ]
    t_n = ''
    
    if nl_i == 0:
        t_0 = in_tup[1]
    else:
        t_0 = in_tup[0]
    
    try:
        for i in range(len(in_tup)):
            if in_tup[ i ] < t_0:
                t_0 = in_tup[ i ]
            elif in_tup[ i ] > t_0 and (t_n == '' or t_n < in_tup[ i ]):
                t_n = in_tup[ i ]                          
    except:
        next
    
    return (nl, t_0, t_n)

# %%
def format_search_tup( line ):
    
    if len(line) > 1:
        nl,t_0,t_n = sort_search_tup( line )
        
        nodelist = format_nodelist( nl )
        start = get_stamp( t_0 )
        end = get_stamp( t_n )
    
    elif len( line.split(" ") ) > 1:
        next

# %% [markdown]
# # TEST

# %%
#print(search(mode='l',chosen))

# %% [markdown]
# # Accessing Info

# %%
keys = []

for item in chosen:
    jobid = item[3]
    nodelist = format_nodelist( item[0] )
    start = str(get_stamp( item[1] ))
    end = str(get_stamp( item[2] ))
    
    for node in nodelist:
        keys.append( ( node, start, end, jobid) )
    
    #print("Jobid:\t", jobid)
    #print("Hosts:\t", nodelist)
    #print("Start(ep):\t", start)
    #print()

# %%
keys
# Out:
# [('comet-27-23', '1583123687', '1588346118', '30598034'),
#  ('comet-27-27', '1583123687', '1588346118', '30598034'),
#  ('comet-27-29', '1583123687', '1588346118', '30598034'),
#  ('comet-27-33', '1583123687', '1588346118', '30598034'),
#  ('comet-27-35', '1583123687', '1588346118', '30598034'),
#  ('comet-27-41', '1583123687', '1588346118', '30598034'),
#  ('comet-27-42', '1583123687', '1588346118', '30598034'),
#  ('comet-15-01', '1583076410', '1588343311', '30644440'),
#  ('comet-15-05', '1583076410', '1588343311', '30644440'),
#  ('comet-15-08', '1583076410', '1588343311', '30644440'),
#  ('comet-15-10', '1583076410', '1588343311', '30644440'),
#  ('comet-15-62', '1583076410', '1588343311', '30644440'),
#  ('comet-15-64', '1583076410', '1588343311', '30644440'),
#  ('comet-19-06', '1583123687', '1588345913', '30598030'),
#  ('comet-19-11', '1583123687', '1588345913', '30598030'),
#  ('comet-19-14', '1583123687', '1588345913', '30598030'),
#  ('comet-19-17', '1583123687', '1588345913', '30598030'),
#  ('comet-19-19', '1583123687', '1588345913', '30598030'),
#  ('comet-19-22', '1583123687', '1588345913', '30598030'),
#  ('comet-19-24', '1583123687', '1588345913', '30598030'),
#  ('comet-15-10', '0', '0', '25918189'),
#  ('comet-15-14', '0', '0', '25918189'),
#  ('comet-15-66', '0', '0', '25918189'),
#  ('comet-15-69', '0', '0', '25918189'),
#  ('comet-15-71', '0', '0', '25918189'),
#  ('comet-18-09', '0', '0', '25918189'),
#  ('comet-20-46', '0', '0', '25918189'),
#  ('comet-20-48', '0', '0', '25918189'),
#  ('comet-20-50', '0', '0', '25918189'),
#  ('comet-20-56', '0', '0', '25918189'),
#  ('comet-20-59', '0', '0', '25918189'),
#  ('comet-20-61', '0', '0', '25918189'),
#  ('comet-01-26', '0', '0', '25920563'),
#  ('comet-01-32', '0', '0', '25920563'),
#  ('comet-01-33', '0', '0', '25920563'),
#  ('comet-05-72', '0', '0', '25920563'),
#  ('comet-07-47', '0', '0', '25920563'),
#  ('comet-07-48', '0', '0', '25920563'),
#  ('comet-23-08', '0', '0', '25920563'),
#  ('comet-23-18', '0', '0', '25920563'),
#  ('comet-23-19', '0', '0', '25920563'),
#  ('comet-23-33', '0', '0', '25920563'),
#  ('comet-23-39', '0', '0', '25920563'),
#  ('comet-23-69', '0', '0', '25920563')]

# %%
chosen_locs = []

for loc in aofa_data:
    for key in keys:
        host = key[0]
        t_n = key[2]
        
        if (host in loc) and t_n is not '0':
            if t_n in loc or t_n[:-2] in loc:
                chosen_locs.append(loc)

for loc in arc_data:
    for key in keys:
        host = key[0]
        t_n = key[2]
        
        if (host in loc) and t_n is not '0':
            if t_n in loc or t_n[:-2] in loc:
                chosen_locs.append(loc)

# %%
len(chosen_locs)
# Out:
# 25494

# %% [markdown]
# ### Formatting Info

# %%
chosen_locs
# Out:
# ['/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1559382640.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1562233841.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1528079608.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1573760448.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1482953869.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1498256864.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1490653658.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1527215611.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1564442950.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1484509069.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1526956407.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1532373712.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1561974641.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1497220063.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1493332060.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1503086700.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1486679255.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1550608412.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1479670666.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1519526008.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1538598792.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1564529350.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1481917068.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1572723647.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1536957190.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1548966809.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1527734009.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1558727897.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1571600446.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1557345496.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1495232862.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1480361874.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1519785215.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1502827500.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1488666457.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1520649208.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1518748406.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1533928913.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1519698806.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1550867612.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1494800861.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1571082046.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1496788063.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1490048858.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1545510803.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1539030792.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1484854669.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1505160302.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1506283503.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1563319750.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1525314807.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1560160240.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1490740058.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1538080391.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1532028112.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1541795597.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1502049900.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1538944392.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1558555097.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1562801349.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1559209839.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1502741100.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1557172696.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1529090510.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1522463605.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1521513210.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1553630293.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1561456241.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1490826458.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1507094203.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1495578462.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1541968397.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1573414847.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1486938455.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1533756113.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1504382701.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1485718670.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1551818014.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1547670807.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1480793867.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1485459470.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1479584266.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1568749244.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1483990669.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1520822013.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1496096863.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1565047751.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1568835644.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1490135258.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1521945217.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1481053067.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1570563645.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1487456856.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1563492550.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1481312267.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1536438789.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1559814640.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1544733202.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1522118020.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1498602464.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1492900060.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1508563004.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1573674048.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1489357657.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1538857992.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1544128401.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1550954012.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1562714949.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1565393351.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1534792172.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1545424403.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1574797249.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1517020403.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1494282461.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1554321494.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1522636405.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1529608910.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1539894793.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1567539643.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1526870008.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1565306951.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1521858806.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1505505902.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1525401206.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1502913900.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1526092406.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1506801903.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1488752857.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1554062293.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1560505840.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1534360913.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1503691501.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1572637247.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1491517659.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1523846007.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1489703257.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1571254846.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1479497866.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1533064913.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1555099094.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1539376393.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1548448408.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1564874951.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1570736445.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1569094844.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1529954510.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1523327605.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1542313998.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1574278848.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1545683604.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/1495405662.gz',
#  '/oasis/projects/nsf/sys200/stats/xsede_stats/archive_of_archive/comet-15-14.sdsc.edu/